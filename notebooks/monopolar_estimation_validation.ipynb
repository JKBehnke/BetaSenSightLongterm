# %% [markdown]
# # Monopolar beta power estimation methods, validated by externalized beta power

# %%
import plotly
import plotly.graph_objs as go

# Importing Python and external packages


import os
import sys
import importlib
from importlib import reload 
from dataclasses import dataclass, field, fields
from itertools import compress
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler

import scipy
from scipy import stats
from scipy import signal
from scipy.signal import spectrogram, hann, butter, filtfilt, freqz

import seaborn as sns
import pingouin as pg
from itertools import combinations
from statannotations.Annotator import Annotator

import openpyxl
from openpyxl import Workbook, load_workbook
# import xlrd
import pickle
import json
import csv
import h5py
import fooof
from fooof.plts.spectra import plot_spectrum

#mne
from pathlib import Path
import mne_bids
from mne_bids import (
    BIDSPath,
    inspect_dataset,
    mark_channels)
import mne
from mne.time_frequency import tfr_morlet 

#######################     USE THIS DIRECTORY FOR IMPORTING PYPERCEIVE REPO  #######################

# create a path to the BetaSenSightLongterm folder 
# and a path to the code folder within the BetaSenSightLongterm Repo
BetaSenSightLongterm_path = os.getcwd()
while BetaSenSightLongterm_path[-16:] != 'ResearchProjects':
    BetaSenSightLongterm_path = os.path.dirname(BetaSenSightLongterm_path)

# directory to PyPerceive code folder
PyPerceive_path = os.path.join(BetaSenSightLongterm_path,'PyPerceive_project', 'code', 'PyPerceive', 'code')
sys.path.append(PyPerceive_path)

# # change directory to PyPerceive code path within BetaSenSightLongterm Repo
os.chdir(PyPerceive_path)
os.getcwd()
from PerceiveImport.classes import (
    main_class, modality_class, metadata_class,
    session_class, condition_class, task_class,
    contact_class, run_class
)
import PerceiveImport.methods.load_rawfile as load_rawfile
import PerceiveImport.methods.find_folders as find_folders
import PerceiveImport.methods.metadata_helpers as metaHelpers

importlib.reload(main_class)
importlib.reload(session_class)
importlib.reload(task_class)
importlib.reload(condition_class)
importlib.reload(contact_class)
importlib.reload(metadata_class)
importlib.reload(modality_class)
importlib.reload(load_rawfile)
importlib.reload(find_folders)
importlib.reload(run_class)
importlib.reload(metaHelpers)
#######################     USE THIS DIRECTORY FOR WORKING WITH FOLDERS INSIDE OF CODE FOLDER OF BETASENSIGHTLONGTERM REPO  #######################


# create a path to the BetaSenSightLongterm folder 
# and a path to the code folder within the BetaSenSightLongterm Repo
current_path = os.getcwd()
while current_path[-16:] != 'ResearchProjects':
    current_path = os.path.dirname(current_path)

# directory to code folder
code_path = os.path.join(current_path, 'BetaSenSightLongterm','code', 'meet')
sys.path.append(code_path)

# # change directory to code path within BetaSenSightLongterm Repo
os.chdir(code_path)
os.getcwd()

import meet as meet
#######################     USE THIS DIRECTORY FOR WORKING WITH FOLDERS INSIDE OF CODE FOLDER OF BETASENSIGHTLONGTERM REPO  #######################


# create a path to the BetaSenSightLongterm folder 
# and a path to the code folder within the BetaSenSightLongterm Repo
current_path = os.getcwd()
while current_path[-16:] != 'ResearchProjects':
    current_path = os.path.dirname(current_path)

# directory to code folder
code_path = os.path.join(current_path, 'BetaSenSightLongterm','code', 'BetaSenSightLongterm')
sys.path.append(code_path)

# # change directory to code path within BetaSenSightLongterm Repo
os.chdir(code_path)
os.getcwd()
# tfr, processing
import src.bssu.tfr.BSSuPsd as BSSuPsd
import src.bssu.tfr.FastFourierPSD as FFpsd

# bipolar Channel Analysis
import src.bssu.bipolar.power_spectra_plots as power_spectra_plots
import src.bssu.bipolar.PeakFrequencies_PSD as PeakFrequency_psd
import src.bssu.bipolar.BIP_channelGroups as BIP_channelGroups
import src.bssu.bipolar.BIP_perChannelAnalysis as BIP_perChannel


# monopolar Referencing
import src.bssu.monopolar.MonoRef_JLB as MonoRefJLB
import src.bssu.monopolar.GroupMonopolarPSD as groupMonopol
import src.bssu.monopolar.monoRef_weightPsdAverageByCoordinateDistance as MonoRefWeightedCoordinateDistance
import src.bssu.monopolar.externalized_lfp as externalized
import src.bssu.monopolar.monopol_method_comparison as monopol_comparison
import src.bssu.monopolar.bssu_contacts_maximal_beta as bssu_contacts

# Ranking Order
import src.bssu.ranking.HighestRankedChannelPSD as highestRank
import src.bssu.ranking.monopolPSDaverage_withinSubject as PSDaverageMonopol
import src.bssu.ranking.BIPchannelGroups_ranks as BIP_ranks
import src.bssu.ranking.Permutation_rankings as Permute_ranks


# Clinical stimulation parameters
import src.bssu.stimulation.activeStimulationContacts as activeStimContacts

# utility functions
import src.bssu.utils.loadResults as loadResults
import src.bssu.utils.find_folders as find_folders
import src.bssu.utils.writeGroupDataframes as writeGroupDF
import src.bssu.utils.load_data_files as load_data

# import Classes
from src.bssu.classes import (metadataAnalysis_class, mainAnalysis_class, sessionAnalysis_class, 
                              channelAnalysis_class, featureAnalysis_class, frequencyBand_class)

# import mni coordinates
import src.bssu.mni.load_rotated_coordinates as load_mni


importlib.reload(BSSuPsd)
importlib.reload(MonoRefJLB)
importlib.reload(loadResults)
importlib.reload(highestRank)
importlib.reload(groupMonopol)
importlib.reload(PSDaverageMonopol)
importlib.reload(FFpsd)
importlib.reload(find_folders)
importlib.reload(metadataAnalysis_class)
importlib.reload(mainAnalysis_class)
importlib.reload(sessionAnalysis_class)
importlib.reload(channelAnalysis_class)
importlib.reload(featureAnalysis_class)
importlib.reload(frequencyBand_class)
importlib.reload(PeakFrequency_psd)
importlib.reload(power_spectra_plots)
importlib.reload(BIP_channelGroups)
importlib.reload(BIP_ranks)
importlib.reload(activeStimContacts)
importlib.reload(Permute_ranks)
importlib.reload(BIP_perChannel)
importlib.reload(load_mni)
importlib.reload(writeGroupDF)
importlib.reload(MonoRefWeightedCoordinateDistance)
importlib.reload(load_data)
importlib.reload(externalized)
importlib.reload(monopol_comparison)
importlib.reload(bssu_contacts)

# load if you want to see complete Dataframes
pd.set_option("display.max_rows", None)
# Out:
# Excel file loaded:  patient_metadata.xlsx
# loaded from:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/data

# %% [markdown]
# Load externalized fooofed beta power
# - 2 min
# - resampled sfreq = 250 Hz
# - notch-filtered 50 Hz
# - artefact-free
# - FOOOFed

# %%
# beta ranks only for directional contacts
# FOOOF version: high-pass 1 Hz filter
beta_ranks_directional_fooof = load_data.load_externalized_pickle(filename = "fooof_externalized_beta_ranks_directional_contacts_only_high_pass_filtered")

# %%
# beta ranks only for directional contacts
# SSD version: 
externalized_SSD_beta_ranks = load_data.load_externalized_pickle(filename="SSD_directional_externalized_channels")
externalized_SSD_beta_ranks_copy = externalized_SSD_beta_ranks.copy()
externalized_SSD_beta_ranks_copy["method"] = "externalized_SSD"
externalized_SSD_beta_ranks_copy["session"] = "postop"
externalized_SSD_beta_ranks_copy["estimated_monopolar_beta_psd"] = externalized_SSD_beta_ranks_copy["ssd_pattern"]

# drop columns
externalized_SSD_beta_ranks_copy.drop(
    columns=[
        'ssd_filtered_timedomain',
    ],
    inplace=True,
)

# %%
externalized_SSD_beta_ranks_copy.head()
# Out:
#     BIDS_id subject hemisphere subject_hemisphere contact  ssd_pattern  \
# 0  noBIDS24     024      Right          024_Right      1A     1.000000
# 1  noBIDS24     024      Right          024_Right      1B    -0.200554
# 2  noBIDS24     024      Right          024_Right      1C     0.503945
# 3  noBIDS24     024      Right          024_Right      2A     0.219320
# 4  noBIDS24     024      Right          024_Right      2B     0.073314
#
#    ssd_eigvals  beta_rank            method session  \
# 0     0.863632        1.0  externalized_SSD  postop
# 1     0.794252        6.0  externalized_SSD  postop
# 2     0.779942        2.0  externalized_SSD  postop
# 3     0.690067        4.0  externalized_SSD  postop
# 4     0.556732        5.0  externalized_SSD  postop
#
#    estimated_monopolar_beta_psd
# 0                      1.000000
# 1                     -0.200554
# 2                      0.503945
# 3                      0.219320
# 4                      0.073314

# %% [markdown]
# Load beta ranks of Euclidean method

# %%
monopolar_fooof_euclidean_segmental = loadResults.load_fooof_monopolar_weighted_psd(
    fooof_spectrum = "periodic_spectrum",
    segmental = "yes",
    similarity_calculation = "inverse_distance"
)

monopolar_fooof_euclidean_segmental = pd.concat([
    monopolar_fooof_euclidean_segmental["postop_monopolar_Dataframe"],
    monopolar_fooof_euclidean_segmental["fu3m_monopolar_Dataframe"],
    monopolar_fooof_euclidean_segmental["fu12m_monopolar_Dataframe"],
    monopolar_fooof_euclidean_segmental["fu18or24m_monopolar_Dataframe"],])

# %%
monopolar_fooof_euclidean_segmental.head()
# Out:
#      coord_z            coord_xy session subject_hemisphere  \
# 1A  2.0+0.0j  0.650000+0.000000j  postop          024_Right
# 1B  2.0+0.0j -0.325000+0.562917j  postop          024_Right
# 1C  2.0+0.0j -0.325000-0.562917j  postop          024_Right
# 2A  4.0+0.0j  0.650000+0.000000j  postop          024_Right
# 2B  4.0+0.0j -0.325000+0.562917j  postop          024_Right
#
#     estimated_monopolar_beta_psd contact  rank
# 1A                      0.154068      1A   1.0
# 1B                      0.148908      1B   2.0
# 1C                      0.133512      1C   3.0
# 2A                      0.089766      2A   4.0
# 2B                      0.085685      2B   5.0

# %% [markdown]
# Load beta ranks of JLB method

# %%
monopolar_fooof_JLB = loadResults.load_pickle_group_result(
    filename="MonoRef_JLB_fooof_beta"
)

# %%
monopolar_fooof_JLB.head()
# Out:
#                     session subject_hemisphere contact  \
# postop_024_Right_1A  postop          024_Right      1A
# postop_024_Right_1B  postop          024_Right      1B
# postop_024_Right_1C  postop          024_Right      1C
# postop_024_Right_2A  postop          024_Right      2A
# postop_024_Right_2B  postop          024_Right      2B
#
#                     estimated_monopolar_beta_psd  rank
# postop_024_Right_1A                     0.047044   1.0
# postop_024_Right_1B                     0.010281   3.0
# postop_024_Right_1C                      0.01491   2.0
# postop_024_Right_2A                     0.003125   4.0
# postop_024_Right_2B                     0.000683   6.0

# %% [markdown]
# Load the contact pair with maximal beta power (Binder et al. 2023)

# %%
best_bssu_directional_contacts = bssu_contacts.select_directional_contact_pair_from_bssu()
# Out:
# best_2_contacts_from_directional_bssu.pickle
# written in: /Users/jenniferbehnke/Dropbox/work/ResearchProjects/BetaSenSightLongterm/results

# %%
best_bssu_contacts = loadResults.load_pickle_group_result(
    filename="best_2_contacts_from_directional_bssu"
)

# %%
best_bssu_contacts.head()
# Out:
#                  session subject_hemisphere selected_2_contacts
# postop_024_Right  postop          024_Right            [1A, 1B]
# postop_024_Left   postop           024_Left            [1A, 2A]
# postop_025_Right  postop          025_Right            [1A, 2A]
# postop_025_Left   postop           025_Left            [1A, 2A]
# postop_028_Right  postop          028_Right            [1A, 2A]

# %% [markdown]
# ## Comparison between methods

# %% [markdown]
# ### Spearman correlation between methods

# %%
spearman_between_methods = monopol_comparison.spearman_monopol_fooof_beta_methods(
    method_1="euclidean_directional",
    method_2="JLB_directional"
)
# Out:
# file:  fooof_monopol_beta_correlations_per_stn_euclidean_directional_JLB_directionalxlsx
# written in:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/results

# %%
spearman_between_methods[0]
# Out:
#                                   method_1         method_2    session  \
# postop_024_Left      euclidean_directional  JLB_directional     postop
# postop_024_Right     euclidean_directional  JLB_directional     postop
# postop_025_Left      euclidean_directional  JLB_directional     postop
# postop_025_Right     euclidean_directional  JLB_directional     postop
# postop_028_Left      euclidean_directional  JLB_directional     postop
# postop_028_Right     euclidean_directional  JLB_directional     postop
# postop_029_Left      euclidean_directional  JLB_directional     postop
# postop_029_Right     euclidean_directional  JLB_directional     postop
# postop_030_Left      euclidean_directional  JLB_directional     postop
# postop_030_Right     euclidean_directional  JLB_directional     postop
# postop_031_Left      euclidean_directional  JLB_directional     postop
# postop_031_Right     euclidean_directional  JLB_directional     postop
# postop_032_Left      euclidean_directional  JLB_directional     postop
# postop_032_Right     euclidean_directional  JLB_directional     postop
# postop_047_Left      euclidean_directional  JLB_directional     postop
# postop_047_Right     euclidean_directional  JLB_directional     postop
# postop_048_Left      euclidean_directional  JLB_directional     postop
# postop_048_Right     euclidean_directional  JLB_directional     postop
# postop_049_Left      euclidean_directional  JLB_directional     postop
# postop_049_Right     euclidean_directional  JLB_directional     postop
# postop_052_Left      euclidean_directional  JLB_directional     postop
# postop_052_Right     euclidean_directional  JLB_directional     postop
# postop_055_Left      euclidean_directional  JLB_directional     postop
# postop_055_Right     euclidean_directional  JLB_directional     postop
# postop_059_Left      euclidean_directional  JLB_directional     postop
# postop_059_Right     euclidean_directional  JLB_directional     postop
# postop_060_Left      euclidean_directional  JLB_directional     postop
# postop_060_Right     euclidean_directional  JLB_directional     postop
# postop_061_Left      euclidean_directional  JLB_directional     postop
# postop_061_Right     euclidean_directional  JLB_directional     postop
# postop_062_Left      euclidean_directional  JLB_directional     postop
# postop_062_Right     euclidean_directional  JLB_directional     postop
# postop_063_Left      euclidean_directional  JLB_directional     postop
# postop_063_Right     euclidean_directional  JLB_directional     postop
# postop_065_Left      euclidean_directional  JLB_directional     postop
# postop_065_Right     euclidean_directional  JLB_directional     postop
# postop_066_Left      euclidean_directional  JLB_directional     postop
# postop_066_Right     euclidean_directional  JLB_directional     postop
# fu3m_017_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_017_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_019_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_019_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_021_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_021_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_024_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_024_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_025_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_025_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_029_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_029_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_030_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_030_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_031_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_031_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_032_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_032_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_033_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_033_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_040_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_040_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_041_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_041_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_045_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_045_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_050_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_050_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_059_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_059_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_060_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_060_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_061_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_061_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_062_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_062_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_063_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_063_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_065_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_065_Right       euclidean_directional  JLB_directional       fu3m
# fu3m_066_Left        euclidean_directional  JLB_directional       fu3m
# fu3m_066_Right       euclidean_directional  JLB_directional       fu3m
# fu12m_017_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_017_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_019_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_019_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_021_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_021_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_024_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_024_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_025_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_025_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_028_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_028_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_029_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_029_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_030_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_030_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_033_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_033_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_036_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_036_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_040_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_040_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_041_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_041_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_045_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_045_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_047_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_047_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_048_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_048_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_049_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_049_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_050_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_050_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_052_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_052_Right      euclidean_directional  JLB_directional      fu12m
# fu12m_055_Left       euclidean_directional  JLB_directional      fu12m
# fu12m_055_Right      euclidean_directional  JLB_directional      fu12m
# fu18or24m_019_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_019_Right  euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_021_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_021_Right  euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_024_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_024_Right  euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_028_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_028_Right  euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_029_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_029_Right  euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_030_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_030_Right  euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_033_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_033_Right  euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_036_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_036_Right  euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_041_Left   euclidean_directional  JLB_directional  fu18or24m
# fu18or24m_041_Right  euclidean_directional  JLB_directional  fu18or24m
#
#                     subject_hemisphere spearman_r      pval  \
# postop_024_Left               024_Left   0.714286  0.110787
# postop_024_Right             024_Right   0.885714  0.018845
# postop_025_Left               025_Left  -0.257143  0.622787
# postop_025_Right             025_Right   0.085714  0.871743
# postop_028_Left               028_Left   0.714286  0.110787
# postop_028_Right             028_Right   0.085714  0.871743
# postop_029_Left               029_Left        0.6     0.208
# postop_029_Right             029_Right   0.714286  0.110787
# postop_030_Left               030_Left   0.657143  0.156175
# postop_030_Right             030_Right   0.942857  0.004805
# postop_031_Left               031_Left        0.2     0.704
# postop_031_Right             031_Right  -0.657143  0.156175
# postop_032_Left               032_Left   0.828571  0.041563
# postop_032_Right             032_Right   0.657143  0.156175
# postop_047_Left               047_Left   0.942857  0.004805
# postop_047_Right             047_Right  -0.314286  0.544093
# postop_048_Left               048_Left   0.828571  0.041563
# postop_048_Right             048_Right  -0.885714  0.018845
# postop_049_Left               049_Left   0.085714  0.871743
# postop_049_Right             049_Right   0.828571  0.041563
# postop_052_Left               052_Left   0.828571  0.041563
# postop_052_Right             052_Right  -0.485714  0.328723
# postop_055_Left               055_Left  -0.085714  0.871743
# postop_055_Right             055_Right   0.942857  0.004805
# postop_059_Left               059_Left   0.771429  0.072397
# postop_059_Right             059_Right   0.085714  0.871743
# postop_060_Left               060_Left   0.771429  0.072397
# postop_060_Right             060_Right  -0.314286  0.544093
# postop_061_Left               061_Left        0.6     0.208
# postop_061_Right             061_Right   0.371429  0.468478
# postop_062_Left               062_Left  -0.314286  0.544093
# postop_062_Right             062_Right   0.657143  0.156175
# postop_063_Left               063_Left        0.6     0.208
# postop_063_Right             063_Right  -0.028571  0.957155
# postop_065_Left               065_Left        0.6     0.208
# postop_065_Right             065_Right   0.942857  0.004805
# postop_066_Left               066_Left   0.942857  0.004805
# postop_066_Right             066_Right   0.942857  0.004805
# fu3m_017_Left                 017_Left   0.485714  0.328723
# fu3m_017_Right               017_Right  -0.142857  0.787172
# fu3m_019_Left                 019_Left  -0.142857  0.787172
# fu3m_019_Right               019_Right   0.771429  0.072397
# fu3m_021_Left                 021_Left   0.942857  0.004805
# fu3m_021_Right               021_Right        0.6     0.208
# fu3m_024_Left                 024_Left        0.2     0.704
# fu3m_024_Right               024_Right       -0.6     0.208
# fu3m_025_Left                 025_Left  -0.142857  0.787172
# fu3m_025_Right               025_Right   0.428571  0.396501
# fu3m_029_Left                 029_Left   0.714286  0.110787
# fu3m_029_Right               029_Right   0.942857  0.004805
# fu3m_030_Left                 030_Left        0.6     0.208
# fu3m_030_Right               030_Right        0.6     0.208
# fu3m_031_Left                 031_Left   0.771429  0.072397
# fu3m_031_Right               031_Right  -0.257143  0.622787
# fu3m_032_Left                 032_Left   0.942857  0.004805
# fu3m_032_Right               032_Right  -0.085714  0.871743
# fu3m_033_Left                 033_Left   0.714286  0.110787
# fu3m_033_Right               033_Right  -0.542857  0.265703
# fu3m_040_Left                 040_Left   0.714286  0.110787
# fu3m_040_Right               040_Right  -0.771429  0.072397
# fu3m_041_Left                 041_Left   0.828571  0.041563
# fu3m_041_Right               041_Right   0.942857  0.004805
# fu3m_045_Left                 045_Left   0.828571  0.041563
# fu3m_045_Right               045_Right   0.828571  0.041563
# fu3m_050_Left                 050_Left  -0.028571  0.957155
# fu3m_050_Right               050_Right   0.942857  0.004805
# fu3m_059_Left                 059_Left   0.942857  0.004805
# fu3m_059_Right               059_Right  -0.028571  0.957155
# fu3m_060_Left                 060_Left  -0.085714  0.871743
# fu3m_060_Right               060_Right   0.885714  0.018845
# fu3m_061_Left                 061_Left  -0.142857  0.787172
# fu3m_061_Right               061_Right  -0.142857  0.787172
# fu3m_062_Left                 062_Left  -0.028571  0.957155
# fu3m_062_Right               062_Right  -0.085714  0.871743
# fu3m_063_Left                 063_Left  -0.142857  0.787172
# fu3m_063_Right               063_Right   0.085714  0.871743
# fu3m_065_Left                 065_Left  -0.028571  0.957155
# fu3m_065_Right               065_Right   0.714286  0.110787
# fu3m_066_Left                 066_Left  -0.257143  0.622787
# fu3m_066_Right               066_Right  -0.371429  0.468478
# fu12m_017_Left                017_Left  -0.657143  0.156175
# fu12m_017_Right              017_Right   0.885714  0.018845
# fu12m_019_Left                019_Left  -0.314286  0.544093
# fu12m_019_Right              019_Right        1.0       0.0
# fu12m_021_Left                021_Left   0.942857  0.004805
# fu12m_021_Right              021_Right   0.371429  0.468478
# fu12m_024_Left                024_Left  -0.028571  0.957155
# fu12m_024_Right              024_Right  -0.657143  0.156175
# fu12m_025_Left                025_Left  -0.257143  0.622787
# fu12m_025_Right              025_Right   0.085714  0.871743
# fu12m_028_Left                028_Left   0.485714  0.328723
# fu12m_028_Right              028_Right   0.428571  0.396501
# fu12m_029_Left                029_Left        0.2     0.704
# fu12m_029_Right              029_Right        1.0       0.0
# fu12m_030_Left                030_Left   0.771429  0.072397
# fu12m_030_Right              030_Right        1.0       0.0
# fu12m_033_Left                033_Left   0.828571  0.041563
# fu12m_033_Right              033_Right   0.771429  0.072397
# fu12m_036_Left                036_Left  -0.714286  0.110787
# fu12m_036_Right              036_Right       -0.6     0.208
# fu12m_040_Left                040_Left  -0.542857  0.265703
# fu12m_040_Right              040_Right  -0.542857  0.265703
# fu12m_041_Left                041_Left   0.542857  0.265703
# fu12m_041_Right              041_Right   0.485714  0.328723
# fu12m_045_Left                045_Left   0.828571  0.041563
# fu12m_045_Right              045_Right  -0.542857  0.265703
# fu12m_047_Left                047_Left        1.0       0.0
# fu12m_047_Right              047_Right   0.771429  0.072397
# fu12m_048_Left                048_Left  -0.314286  0.544093
# fu12m_048_Right              048_Right  -0.314286  0.544093
# fu12m_049_Left                049_Left  -0.880406  0.020599
# fu12m_049_Right              049_Right   0.428571  0.396501
# fu12m_050_Left                050_Left   0.485714  0.328723
# fu12m_050_Right              050_Right   0.885714  0.018845
# fu12m_052_Left                052_Left   0.942857  0.004805
# fu12m_052_Right              052_Right   0.714286  0.110787
# fu12m_055_Left                055_Left   0.771429  0.072397
# fu12m_055_Right              055_Right  -0.257143  0.622787
# fu18or24m_019_Left            019_Left  -0.314286  0.544093
# fu18or24m_019_Right          019_Right   0.828571  0.041563
# fu18or24m_021_Left            021_Left   0.828571  0.041563
# fu18or24m_021_Right          021_Right        0.6     0.208
# fu18or24m_024_Left            024_Left        0.2     0.704
# fu18or24m_024_Right          024_Right  -0.771429  0.072397
# fu18or24m_028_Left            028_Left   0.485714  0.328723
# fu18or24m_028_Right          028_Right   0.428571  0.396501
# fu18or24m_029_Left            029_Left   0.771429  0.072397
# fu18or24m_029_Right          029_Right   0.828571  0.041563
# fu18or24m_030_Left            030_Left   0.771429  0.072397
# fu18or24m_030_Right          030_Right   0.657143  0.156175
# fu18or24m_033_Left            033_Left   0.771429  0.072397
# fu18or24m_033_Right          033_Right   0.942857  0.004805
# fu18or24m_036_Left            036_Left  -0.542857  0.265703
# fu18or24m_036_Right          036_Right       -0.6     0.208
# fu18or24m_041_Left            041_Left   0.428571  0.396501
# fu18or24m_041_Right          041_Right   0.142857  0.787172
#
#                     contact_rank_1_method_1 contact_rank_1_method_2  \
# postop_024_Left                          1A                      1A
# postop_024_Right                         1A                      1A
# postop_025_Left                          1A                      2A
# postop_025_Right                         1A                      2A
# postop_028_Left                          2A                      1A
# postop_028_Right                         2A                      1A
# postop_029_Left                          1A                      1B
# postop_029_Right                         1A                      1A
# postop_030_Left                          1C                      2C
# postop_030_Right                         2B                      2B
# postop_031_Left                          2C                      1C
# postop_031_Right                         1A                      2A
# postop_032_Left                          2C                      2C
# postop_032_Right                         1B                      2B
# postop_047_Left                          1C                      1C
# postop_047_Right                         2B                      2A
# postop_048_Left                          1C                      1C
# postop_048_Right                         2C                      1B
# postop_049_Left                          2A                      1A
# postop_049_Right                         1C                      1C
# postop_052_Left                          2C                      2C
# postop_052_Right                         2A                      1B
# postop_055_Left                          2C                      1C
# postop_055_Right                         2A                      2A
# postop_059_Left                          1A                      1A
# postop_059_Right                         1B                      2B
# postop_060_Left                          2A                      2A
# postop_060_Right                         1A                      2A
# postop_061_Left                          1C                      1C
# postop_061_Right                         2A                      2B
# postop_062_Left                          2C                      1A
# postop_062_Right                         2A                      2A
# postop_063_Left                          2A                      2A
# postop_063_Right                         2A                      1A
# postop_065_Left                          1C                      1C
# postop_065_Right                         1A                      1A
# postop_066_Left                          1C                      1C
# postop_066_Right                         1B                      1B
# fu3m_017_Left                            2A                      2A
# fu3m_017_Right                           2A                      1A
# fu3m_019_Left                            1A                      2A
# fu3m_019_Right                           1A                      1A
# fu3m_021_Left                            1C                      1C
# fu3m_021_Right                           1A                      1A
# fu3m_024_Left                            1A                      2A
# fu3m_024_Right                           2C                      1C
# fu3m_025_Left                            1A                      2A
# fu3m_025_Right                           1A                      2A
# fu3m_029_Left                            1A                      1A
# fu3m_029_Right                           2A                      2A
# fu3m_030_Left                            2B                      2B
# fu3m_030_Right                           2B                      2B
# fu3m_031_Left                            1C                      1C
# fu3m_031_Right                           1C                      2C
# fu3m_032_Left                            2C                      2C
# fu3m_032_Right                           1B                      2B
# fu3m_033_Left                            2A                      2A
# fu3m_033_Right                           1B                      2B
# fu3m_040_Left                            2C                      2C
# fu3m_040_Right                           1B                      2C
# fu3m_041_Left                            2C                      2C
# fu3m_041_Right                           2B                      2B
# fu3m_045_Left                            1C                      1C
# fu3m_045_Right                           1A                      1A
# fu3m_050_Left                            1A                      2A
# fu3m_050_Right                           1B                      1B
# fu3m_059_Left                            1A                      1A
# fu3m_059_Right                           1B                      2B
# fu3m_060_Left                            1B                      2A
# fu3m_060_Right                           2A                      2A
# fu3m_061_Left                            2A                      1C
# fu3m_061_Right                           2A                      1A
# fu3m_062_Left                            2A                      1A
# fu3m_062_Right                           2A                      1C
# fu3m_063_Left                            2A                      1A
# fu3m_063_Right                           2A                      1A
# fu3m_065_Left                            1C                      2C
# fu3m_065_Right                           1C                      1C
# fu3m_066_Left                            2C                      1C
# fu3m_066_Right                           2C                      1B
# fu12m_017_Left                           1B                      2B
# fu12m_017_Right                          2C                      2A
# fu12m_019_Left                           1A                      2A
# fu12m_019_Right                          1A                      1A
# fu12m_021_Left                           1C                      1C
# fu12m_021_Right                          1A                      2A
# fu12m_024_Left                           1A                      2A
# fu12m_024_Right                          2A                      1C
# fu12m_025_Left                           1A                      2A
# fu12m_025_Right                          2A                      1A
# fu12m_028_Left                           1A                      2A
# fu12m_028_Right                          2A                      1A
# fu12m_029_Left                           1A                      2A
# fu12m_029_Right                          2A                      2A
# fu12m_030_Left                           1C                      2C
# fu12m_030_Right                          2B                      2B
# fu12m_033_Left                           2A                      2A
# fu12m_033_Right                          2B                      2B
# fu12m_036_Left                           1C                      2B
# fu12m_036_Right                          1C                      2C
# fu12m_040_Left                           2B                      1B
# fu12m_040_Right                          1A                      2C
# fu12m_041_Left                           2C                      2B
# fu12m_041_Right                          1B                      2B
# fu12m_045_Left                           1A                      1A
# fu12m_045_Right                          2A                      1A
# fu12m_047_Left                           2C                      2C
# fu12m_047_Right                          2C                      2B
# fu12m_048_Left                           1B                      2B
# fu12m_048_Right                          1B                      2B
# fu12m_049_Left                           2A                      1A
# fu12m_049_Right                          1C                      1C
# fu12m_050_Left                           1A                      2A
# fu12m_050_Right                          1B                      1B
# fu12m_052_Left                           2C                      2C
# fu12m_052_Right                          2B                      2B
# fu12m_055_Left                           2C                      2C
# fu12m_055_Right                          1C                      2C
# fu18or24m_019_Left                       1A                      2A
# fu18or24m_019_Right                      1C                      1C
# fu18or24m_021_Left                       1C                      1C
# fu18or24m_021_Right                      1A                      1A
# fu18or24m_024_Left                       1A                      2A
# fu18or24m_024_Right                      2C                      1C
# fu18or24m_028_Left                       1A                      2A
# fu18or24m_028_Right                      2A                      1A
# fu18or24m_029_Left                       1C                      1A
# fu18or24m_029_Right                      2A                      2A
# fu18or24m_030_Left                       2B                      2C
# fu18or24m_030_Right                      2B                      2B
# fu18or24m_033_Left                       2A                      2A
# fu18or24m_033_Right                      2B                      2B
# fu18or24m_036_Left                       1B                      2B
# fu18or24m_036_Right                      1C                      2C
# fu18or24m_041_Left                       2A                      2C
# fu18or24m_041_Right                      2B                      2B
#
#                     contacts_rank_1_2_method_1 contacts_rank_1_2_method_2  \
# postop_024_Left                       [1A, 1B]                   [1A, 2A]
# postop_024_Right                      [1A, 1B]                   [1A, 1C]
# postop_025_Left                       [1A, 1C]                   [2A, 2C]
# postop_025_Right                      [1A, 1C]                   [2A, 1A]
# postop_028_Left                       [2A, 2B]                   [1A, 2A]
# postop_028_Right                      [2A, 2C]                   [1A, 2A]
# postop_029_Left                       [1A, 2A]                   [1B, 1A]
# postop_029_Right                      [1A, 1B]                   [1A, 2A]
# postop_030_Left                       [1C, 2C]                   [2C, 2B]
# postop_030_Right                      [2B, 1B]                   [2B, 1B]
# postop_031_Left                       [2C, 1C]                   [1C, 1B]
# postop_031_Right                      [1A, 1C]                   [2A, 2B]
# postop_032_Left                       [2C, 1C]                   [2C, 2A]
# postop_032_Right                      [1B, 2B]                   [2B, 1B]
# postop_047_Left                       [1C, 2C]                   [1C, 2C]
# postop_047_Right                      [2B, 1A]                   [2A, 1A]
# postop_048_Left                       [1C, 1B]                   [1C, 1B]
# postop_048_Right                      [2C, 2A]                   [1B, 1C]
# postop_049_Left                       [2A, 2C]                   [1A, 2A]
# postop_049_Right                      [1C, 1B]                   [1C, 1B]
# postop_052_Left                       [2C, 1C]                   [2C, 1C]
# postop_052_Right                      [2A, 2B]                   [1B, 2B]
# postop_055_Left                       [2C, 2A]                   [1C, 2C]
# postop_055_Right                      [2A, 2C]                   [2A, 2C]
# postop_059_Left                       [1A, 1C]                   [1A, 1B]
# postop_059_Right                      [1B, 1A]                   [2B, 1B]
# postop_060_Left                       [2A, 2B]                   [2A, 2B]
# postop_060_Right                      [1A, 1C]                   [2A, 2B]
# postop_061_Left                       [1C, 1A]                   [1C, 1A]
# postop_061_Right                      [2A, 2B]                   [2B, 1B]
# postop_062_Left                       [2C, 2A]                   [1A, 1B]
# postop_062_Right                      [2A, 2B]                   [2A, 2C]
# postop_063_Left                       [2A, 2B]                   [2A, 1A]
# postop_063_Right                      [2A, 2B]                   [1A, 2A]
# postop_065_Left                       [1C, 1B]                   [1C, 2C]
# postop_065_Right                      [1A, 1B]                   [1A, 1C]
# postop_066_Left                       [1C, 1A]                   [1C, 1A]
# postop_066_Right                      [1B, 1A]                   [1B, 1A]
# fu3m_017_Left                         [2A, 2C]                   [2A, 1A]
# fu3m_017_Right                        [2A, 2C]                   [1A, 2A]
# fu3m_019_Left                         [1A, 1C]                   [2A, 2B]
# fu3m_019_Right                        [1A, 1C]                   [1A, 1C]
# fu3m_021_Left                         [1C, 1B]                   [1C, 1A]
# fu3m_021_Right                        [1A, 1B]                   [1A, 2A]
# fu3m_024_Left                         [1A, 1B]                   [2A, 1A]
# fu3m_024_Right                        [2C, 2A]                   [1C, 1A]
# fu3m_025_Left                         [1A, 1C]                   [2A, 2B]
# fu3m_025_Right                        [1A, 2A]                   [2A, 1A]
# fu3m_029_Left                         [1A, 1C]                   [1A, 2A]
# fu3m_029_Right                        [2A, 1A]                   [2A, 1A]
# fu3m_030_Left                         [2B, 2C]                   [2B, 1B]
# fu3m_030_Right                        [2B, 2C]                   [2B, 1B]
# fu3m_031_Left                         [1C, 2C]                   [1C, 1B]
# fu3m_031_Right                        [1C, 1A]                   [2C, 2A]
# fu3m_032_Left                         [2C, 2A]                   [2C, 2B]
# fu3m_032_Right                        [1B, 2A]                   [2B, 2A]
# fu3m_033_Left                         [2A, 2B]                   [2A, 1A]
# fu3m_033_Right                        [1B, 1A]                   [2B, 2A]
# fu3m_040_Left                         [2C, 2B]                   [2C, 1C]
# fu3m_040_Right                        [1B, 1C]                   [2C, 2A]
# fu3m_041_Left                         [2C, 2B]                   [2C, 2B]
# fu3m_041_Right                        [2B, 1B]                   [2B, 2C]
# fu3m_045_Left                         [1C, 1A]                   [1C, 1B]
# fu3m_045_Right                        [1A, 2A]                   [1A, 1B]
# fu3m_050_Left                         [1A, 1C]                   [2A, 1A]
# fu3m_050_Right                        [1B, 1C]                   [1B, 1A]
# fu3m_059_Left                         [1A, 1C]                   [1A, 1B]
# fu3m_059_Right                        [1B, 2B]                   [2B, 2C]
# fu3m_060_Left                         [1B, 1A]                   [2A, 2B]
# fu3m_060_Right                        [2A, 1A]                   [2A, 1A]
# fu3m_061_Left                         [2A, 2B]                   [1C, 2C]
# fu3m_061_Right                        [2A, 2B]                   [1A, 1C]
# fu3m_062_Left                         [2A, 2B]                   [1A, 1B]
# fu3m_062_Right                        [2A, 2C]                   [1C, 1A]
# fu3m_063_Left                         [2A, 2C]                   [1A, 1B]
# fu3m_063_Right                        [2A, 2B]                   [1A, 2A]
# fu3m_065_Left                         [1C, 1B]                   [2C, 1C]
# fu3m_065_Right                        [1C, 1A]                   [1C, 2C]
# fu3m_066_Left                         [2C, 2A]                   [1C, 1A]
# fu3m_066_Right                        [2C, 2A]                   [1B, 1C]
# fu12m_017_Left                        [1B, 1C]                   [2B, 2A]
# fu12m_017_Right                       [2C, 2A]                   [2A, 2C]
# fu12m_019_Left                        [1A, 1C]                   [2A, 2B]
# fu12m_019_Right                       [1A, 1C]                   [1A, 1C]
# fu12m_021_Left                        [1C, 1B]                   [1C, 1A]
# fu12m_021_Right                       [1A, 2A]                   [2A, 1A]
# fu12m_024_Left                        [1A, 1B]                   [2A, 2B]
# fu12m_024_Right                       [2A, 2C]                   [1C, 1A]
# fu12m_025_Left                        [1A, 1B]                   [2A, 2B]
# fu12m_025_Right                       [2A, 2B]                   [1A, 2A]
# fu12m_028_Left                        [1A, 1C]                   [2A, 1A]
# fu12m_028_Right                       [2A, 1A]                   [1A, 1B]
# fu12m_029_Left                        [1A, 1C]                   [2A, 1A]
# fu12m_029_Right                       [2A, 2C]                   [2A, 2C]
# fu12m_030_Left                        [1C, 2C]                   [2C, 2B]
# fu12m_030_Right                       [2B, 2A]                   [2B, 2A]
# fu12m_033_Left                        [2A, 2B]                   [2A, 2B]
# fu12m_033_Right                       [2B, 2C]                   [2B, 2A]
# fu12m_036_Left                        [1C, 1B]                   [2B, 2A]
# fu12m_036_Right                       [1C, 1B]                   [2C, 2A]
# fu12m_040_Left                        [2B, 2C]                   [1B, 1C]
# fu12m_040_Right                       [1A, 1B]                   [2C, 2A]
# fu12m_041_Left                        [2C, 2A]                   [2B, 2C]
# fu12m_041_Right                       [1B, 2B]                   [2B, 2C]
# fu12m_045_Left                        [1A, 1C]                   [1A, 1C]
# fu12m_045_Right                       [2A, 2B]                   [1A, 1B]
# fu12m_047_Left                        [2C, 2B]                   [2C, 2B]
# fu12m_047_Right                       [2C, 2B]                   [2B, 2A]
# fu12m_048_Left                        [1B, 1A]                   [2B, 2C]
# fu12m_048_Right                       [1B, 1C]                   [2B, 2A]
# fu12m_049_Left                        [2A, 2B]                   [1A, 1B]
# fu12m_049_Right                       [1C, 1A]                   [1C, 1B]
# fu12m_050_Left                        [1A, 2A]                   [2A, 1A]
# fu12m_050_Right                       [1B, 1C]                   [1B, 1A]
# fu12m_052_Left                        [2C, 2B]                   [2C, 2B]
# fu12m_052_Right                       [2B, 2A]                   [2B, 2C]
# fu12m_055_Left                        [2C, 2B]                   [2C, 1C]
# fu12m_055_Right                       [1C, 1A]                   [2C, 2A]
# fu18or24m_019_Left                    [1A, 1C]                   [2A, 2B]
# fu18or24m_019_Right                   [1C, 1A]                   [1C, 1A]
# fu18or24m_021_Left                    [1C, 1B]                   [1C, 2C]
# fu18or24m_021_Right                   [1A, 1C]                   [1A, 2A]
# fu18or24m_024_Left                    [1A, 1B]                   [2A, 1A]
# fu18or24m_024_Right                   [2C, 2A]                   [1C, 1B]
# fu18or24m_028_Left                    [1A, 2A]                   [2A, 2C]
# fu18or24m_028_Right                   [2A, 1A]                   [1A, 1B]
# fu18or24m_029_Left                    [1C, 1A]                   [1A, 1C]
# fu18or24m_029_Right                   [2A, 1A]                   [2A, 1A]
# fu18or24m_030_Left                    [2B, 2C]                   [2C, 2B]
# fu18or24m_030_Right                   [2B, 2C]                   [2B, 2A]
# fu18or24m_033_Left                    [2A, 2B]                   [2A, 2B]
# fu18or24m_033_Right                   [2B, 2C]                   [2B, 2A]
# fu18or24m_036_Left                    [1B, 1A]                   [2B, 2A]
# fu18or24m_036_Right                   [1C, 1B]                   [2C, 2A]
# fu18or24m_041_Left                    [2A, 2C]                   [2C, 2B]
# fu18or24m_041_Right                   [2B, 1B]                   [2B, 2C]
#
#                     compare_rank_1_contact compare_rank_1_and_2_contacts  \
# postop_024_Left                       same    at_least_one_contact_match
# postop_024_Right                      same    at_least_one_contact_match
# postop_025_Left                  different             no_contacts_match
# postop_025_Right                 different    at_least_one_contact_match
# postop_028_Left                  different    at_least_one_contact_match
# postop_028_Right                 different    at_least_one_contact_match
# postop_029_Left                  different    at_least_one_contact_match
# postop_029_Right                      same    at_least_one_contact_match
# postop_030_Left                  different    at_least_one_contact_match
# postop_030_Right                      same    at_least_one_contact_match
# postop_031_Left                  different    at_least_one_contact_match
# postop_031_Right                 different             no_contacts_match
# postop_032_Left                       same    at_least_one_contact_match
# postop_032_Right                 different    at_least_one_contact_match
# postop_047_Left                       same    at_least_one_contact_match
# postop_047_Right                 different    at_least_one_contact_match
# postop_048_Left                       same    at_least_one_contact_match
# postop_048_Right                 different             no_contacts_match
# postop_049_Left                  different    at_least_one_contact_match
# postop_049_Right                      same    at_least_one_contact_match
# postop_052_Left                       same    at_least_one_contact_match
# postop_052_Right                 different    at_least_one_contact_match
# postop_055_Left                  different    at_least_one_contact_match
# postop_055_Right                      same    at_least_one_contact_match
# postop_059_Left                       same    at_least_one_contact_match
# postop_059_Right                 different    at_least_one_contact_match
# postop_060_Left                       same    at_least_one_contact_match
# postop_060_Right                 different             no_contacts_match
# postop_061_Left                       same    at_least_one_contact_match
# postop_061_Right                 different    at_least_one_contact_match
# postop_062_Left                  different             no_contacts_match
# postop_062_Right                      same    at_least_one_contact_match
# postop_063_Left                       same    at_least_one_contact_match
# postop_063_Right                 different    at_least_one_contact_match
# postop_065_Left                       same    at_least_one_contact_match
# postop_065_Right                      same    at_least_one_contact_match
# postop_066_Left                       same    at_least_one_contact_match
# postop_066_Right                      same    at_least_one_contact_match
# fu3m_017_Left                         same    at_least_one_contact_match
# fu3m_017_Right                   different    at_least_one_contact_match
# fu3m_019_Left                    different             no_contacts_match
# fu3m_019_Right                        same    at_least_one_contact_match
# fu3m_021_Left                         same    at_least_one_contact_match
# fu3m_021_Right                        same    at_least_one_contact_match
# fu3m_024_Left                    different    at_least_one_contact_match
# fu3m_024_Right                   different             no_contacts_match
# fu3m_025_Left                    different             no_contacts_match
# fu3m_025_Right                   different    at_least_one_contact_match
# fu3m_029_Left                         same    at_least_one_contact_match
# fu3m_029_Right                        same    at_least_one_contact_match
# fu3m_030_Left                         same    at_least_one_contact_match
# fu3m_030_Right                        same    at_least_one_contact_match
# fu3m_031_Left                         same    at_least_one_contact_match
# fu3m_031_Right                   different             no_contacts_match
# fu3m_032_Left                         same    at_least_one_contact_match
# fu3m_032_Right                   different    at_least_one_contact_match
# fu3m_033_Left                         same    at_least_one_contact_match
# fu3m_033_Right                   different             no_contacts_match
# fu3m_040_Left                         same    at_least_one_contact_match
# fu3m_040_Right                   different             no_contacts_match
# fu3m_041_Left                         same    at_least_one_contact_match
# fu3m_041_Right                        same    at_least_one_contact_match
# fu3m_045_Left                         same    at_least_one_contact_match
# fu3m_045_Right                        same    at_least_one_contact_match
# fu3m_050_Left                    different    at_least_one_contact_match
# fu3m_050_Right                        same    at_least_one_contact_match
# fu3m_059_Left                         same    at_least_one_contact_match
# fu3m_059_Right                   different    at_least_one_contact_match
# fu3m_060_Left                    different             no_contacts_match
# fu3m_060_Right                        same    at_least_one_contact_match
# fu3m_061_Left                    different             no_contacts_match
# fu3m_061_Right                   different             no_contacts_match
# fu3m_062_Left                    different             no_contacts_match
# fu3m_062_Right                   different             no_contacts_match
# fu3m_063_Left                    different             no_contacts_match
# fu3m_063_Right                   different    at_least_one_contact_match
# fu3m_065_Left                    different    at_least_one_contact_match
# fu3m_065_Right                        same    at_least_one_contact_match
# fu3m_066_Left                    different             no_contacts_match
# fu3m_066_Right                   different             no_contacts_match
# fu12m_017_Left                   different             no_contacts_match
# fu12m_017_Right                  different    at_least_one_contact_match
# fu12m_019_Left                   different             no_contacts_match
# fu12m_019_Right                       same    at_least_one_contact_match
# fu12m_021_Left                        same    at_least_one_contact_match
# fu12m_021_Right                  different    at_least_one_contact_match
# fu12m_024_Left                   different             no_contacts_match
# fu12m_024_Right                  different             no_contacts_match
# fu12m_025_Left                   different             no_contacts_match
# fu12m_025_Right                  different    at_least_one_contact_match
# fu12m_028_Left                   different    at_least_one_contact_match
# fu12m_028_Right                  different    at_least_one_contact_match
# fu12m_029_Left                   different    at_least_one_contact_match
# fu12m_029_Right                       same    at_least_one_contact_match
# fu12m_030_Left                   different    at_least_one_contact_match
# fu12m_030_Right                       same    at_least_one_contact_match
# fu12m_033_Left                        same    at_least_one_contact_match
# fu12m_033_Right                       same    at_least_one_contact_match
# fu12m_036_Left                   different             no_contacts_match
# fu12m_036_Right                  different             no_contacts_match
# fu12m_040_Left                   different             no_contacts_match
# fu12m_040_Right                  different             no_contacts_match
# fu12m_041_Left                   different    at_least_one_contact_match
# fu12m_041_Right                  different    at_least_one_contact_match
# fu12m_045_Left                        same    at_least_one_contact_match
# fu12m_045_Right                  different             no_contacts_match
# fu12m_047_Left                        same    at_least_one_contact_match
# fu12m_047_Right                  different    at_least_one_contact_match
# fu12m_048_Left                   different             no_contacts_match
# fu12m_048_Right                  different             no_contacts_match
# fu12m_049_Left                   different             no_contacts_match
# fu12m_049_Right                       same    at_least_one_contact_match
# fu12m_050_Left                   different    at_least_one_contact_match
# fu12m_050_Right                       same    at_least_one_contact_match
# fu12m_052_Left                        same    at_least_one_contact_match
# fu12m_052_Right                       same    at_least_one_contact_match
# fu12m_055_Left                        same    at_least_one_contact_match
# fu12m_055_Right                  different             no_contacts_match
# fu18or24m_019_Left               different             no_contacts_match
# fu18or24m_019_Right                   same    at_least_one_contact_match
# fu18or24m_021_Left                    same    at_least_one_contact_match
# fu18or24m_021_Right                   same    at_least_one_contact_match
# fu18or24m_024_Left               different    at_least_one_contact_match
# fu18or24m_024_Right              different             no_contacts_match
# fu18or24m_028_Left               different    at_least_one_contact_match
# fu18or24m_028_Right              different    at_least_one_contact_match
# fu18or24m_029_Left               different    at_least_one_contact_match
# fu18or24m_029_Right                   same    at_least_one_contact_match
# fu18or24m_030_Left               different    at_least_one_contact_match
# fu18or24m_030_Right                   same    at_least_one_contact_match
# fu18or24m_033_Left                    same    at_least_one_contact_match
# fu18or24m_033_Right                   same    at_least_one_contact_match
# fu18or24m_036_Left               different             no_contacts_match
# fu18or24m_036_Right              different             no_contacts_match
# fu18or24m_041_Left               different    at_least_one_contact_match
# fu18or24m_041_Right                   same    at_least_one_contact_match
#
#                     significant_correlation
# postop_024_Left                          no
# postop_024_Right                        yes
# postop_025_Left                          no
# postop_025_Right                         no
# postop_028_Left                          no
# postop_028_Right                         no
# postop_029_Left                          no
# postop_029_Right                         no
# postop_030_Left                          no
# postop_030_Right                        yes
# postop_031_Left                          no
# postop_031_Right                         no
# postop_032_Left                         yes
# postop_032_Right                         no
# postop_047_Left                         yes
# postop_047_Right                         no
# postop_048_Left                         yes
# postop_048_Right                        yes
# postop_049_Left                          no
# postop_049_Right                        yes
# postop_052_Left                         yes
# postop_052_Right                         no
# postop_055_Left                          no
# postop_055_Right                        yes
# postop_059_Left                          no
# postop_059_Right                         no
# postop_060_Left                          no
# postop_060_Right                         no
# postop_061_Left                          no
# postop_061_Right                         no
# postop_062_Left                          no
# postop_062_Right                         no
# postop_063_Left                          no
# postop_063_Right                         no
# postop_065_Left                          no
# postop_065_Right                        yes
# postop_066_Left                         yes
# postop_066_Right                        yes
# fu3m_017_Left                            no
# fu3m_017_Right                           no
# fu3m_019_Left                            no
# fu3m_019_Right                           no
# fu3m_021_Left                           yes
# fu3m_021_Right                           no
# fu3m_024_Left                            no
# fu3m_024_Right                           no
# fu3m_025_Left                            no
# fu3m_025_Right                           no
# fu3m_029_Left                            no
# fu3m_029_Right                          yes
# fu3m_030_Left                            no
# fu3m_030_Right                           no
# fu3m_031_Left                            no
# fu3m_031_Right                           no
# fu3m_032_Left                           yes
# fu3m_032_Right                           no
# fu3m_033_Left                            no
# fu3m_033_Right                           no
# fu3m_040_Left                            no
# fu3m_040_Right                           no
# fu3m_041_Left                           yes
# fu3m_041_Right                          yes
# fu3m_045_Left                           yes
# fu3m_045_Right                          yes
# fu3m_050_Left                            no
# fu3m_050_Right                          yes
# fu3m_059_Left                           yes
# fu3m_059_Right                           no
# fu3m_060_Left                            no
# fu3m_060_Right                          yes
# fu3m_061_Left                            no
# fu3m_061_Right                           no
# fu3m_062_Left                            no
# fu3m_062_Right                           no
# fu3m_063_Left                            no
# fu3m_063_Right                           no
# fu3m_065_Left                            no
# fu3m_065_Right                           no
# fu3m_066_Left                            no
# fu3m_066_Right                           no
# fu12m_017_Left                           no
# fu12m_017_Right                         yes
# fu12m_019_Left                           no
# fu12m_019_Right                         yes
# fu12m_021_Left                          yes
# fu12m_021_Right                          no
# fu12m_024_Left                           no
# fu12m_024_Right                          no
# fu12m_025_Left                           no
# fu12m_025_Right                          no
# fu12m_028_Left                           no
# fu12m_028_Right                          no
# fu12m_029_Left                           no
# fu12m_029_Right                         yes
# fu12m_030_Left                           no
# fu12m_030_Right                         yes
# fu12m_033_Left                          yes
# fu12m_033_Right                          no
# fu12m_036_Left                           no
# fu12m_036_Right                          no
# fu12m_040_Left                           no
# fu12m_040_Right                          no
# fu12m_041_Left                           no
# fu12m_041_Right                          no
# fu12m_045_Left                          yes
# fu12m_045_Right                          no
# fu12m_047_Left                          yes
# fu12m_047_Right                          no
# fu12m_048_Left                           no
# fu12m_048_Right                          no
# fu12m_049_Left                          yes
# fu12m_049_Right                          no
# fu12m_050_Left                           no
# fu12m_050_Right                         yes
# fu12m_052_Left                          yes
# fu12m_052_Right                          no
# fu12m_055_Left                           no
# fu12m_055_Right                          no
# fu18or24m_019_Left                       no
# fu18or24m_019_Right                     yes
# fu18or24m_021_Left                      yes
# fu18or24m_021_Right                      no
# fu18or24m_024_Left                       no
# fu18or24m_024_Right                      no
# fu18or24m_028_Left                       no
# fu18or24m_028_Right                      no
# fu18or24m_029_Left                       no
# fu18or24m_029_Right                     yes
# fu18or24m_030_Left                       no
# fu18or24m_030_Right                      no
# fu18or24m_033_Left                       no
# fu18or24m_033_Right                     yes
# fu18or24m_036_Left                       no
# fu18or24m_036_Right                      no
# fu18or24m_041_Left                       no
# fu18or24m_041_Right                      no

# %%
spearman_between_methods[1]
# Out:
#              session sample_size spearman_mean spearman_median spearman_std  \
# postop        postop          38      0.407519        0.628571     0.514022
# fu3m            fu3m          42      0.295238        0.314286     0.510898
# fu12m          fu12m          38      0.263298        0.457143     0.614599
# fu18or24m  fu18or24m          18       0.35873        0.542857     0.538598
#
#           significant_count percentage_significant same_rank_1  \
# postop                   12               0.315789          19
# fu3m                     10               0.238095          20
# fu12m                    11               0.289474          13
# fu18or24m                 4               0.222222           8
#
#           precentage_same_rank_1 at_least_one_same_contact_rank_1_and_2  \
# postop                       0.5                                     33
# fu3m                     0.47619                                     28
# fu12m                   0.342105                                     24
# fu18or24m               0.444444                                     14
#
#           precentage_at_least_one_same_contact_rank_1_and_2
# postop                                             0.868421
# fu3m                                               0.666667
# fu12m                                              0.631579
# fu18or24m                                          0.777778

# %%
stn_comparison = spearman_between_methods[2]
stn_comparison
# Out:
#                          coord_z            coord_xy    session  \
# 1A                      2.0+0.0j  0.650000+0.000000j  fu18or24m
# 1B                      2.0+0.0j -0.325000+0.562917j  fu18or24m
# 1C                      2.0+0.0j -0.325000-0.562917j  fu18or24m
# 2A                      4.0+0.0j  0.650000+0.000000j  fu18or24m
# 2B                      4.0+0.0j -0.325000+0.562917j  fu18or24m
# 2C                      4.0+0.0j -0.325000-0.562917j  fu18or24m
# fu18or24m_041_Right_1A N000a000N N00000000a00000000N  fu18or24m
# fu18or24m_041_Right_1B N000a000N N00000000a00000000N  fu18or24m
# fu18or24m_041_Right_1C N000a000N N00000000a00000000N  fu18or24m
# fu18or24m_041_Right_2A N000a000N N00000000a00000000N  fu18or24m
# fu18or24m_041_Right_2B N000a000N N00000000a00000000N  fu18or24m
# fu18or24m_041_Right_2C N000a000N N00000000a00000000N  fu18or24m
#
#                        subject_hemisphere estimated_monopolar_beta_psd  \
# 1A                              041_Right                      8.49779
# 1B                              041_Right                     9.030681
# 1C                              041_Right                     8.821911
# 2A                              041_Right                     8.039029
# 2B                              041_Right                     9.040991
# 2C                              041_Right                     8.459341
# fu18or24m_041_Right_1A          041_Right                     0.087243
# fu18or24m_041_Right_1B          041_Right                     0.277539
# fu18or24m_041_Right_1C          041_Right                     0.142927
# fu18or24m_041_Right_2A          041_Right                      0.35742
# fu18or24m_041_Right_2B          041_Right                     1.137036
# fu18or24m_041_Right_2C          041_Right                     0.585548
#
#                        contact                 method  beta_rank
# 1A                          1A  euclidean_directional        4.0
# 1B                          1B  euclidean_directional        2.0
# 1C                          1C  euclidean_directional        3.0
# 2A                          2A  euclidean_directional        6.0
# 2B                          2B  euclidean_directional        1.0
# 2C                          2C  euclidean_directional        5.0
# fu18or24m_041_Right_1A      1A        JLB_directional        6.0
# fu18or24m_041_Right_1B      1B        JLB_directional        4.0
# fu18or24m_041_Right_1C      1C        JLB_directional        5.0
# fu18or24m_041_Right_2A      2A        JLB_directional        3.0
# fu18or24m_041_Right_2B      2B        JLB_directional        1.0
# fu18or24m_041_Right_2C      2C        JLB_directional        2.0

# %%
stn_comparison = stn_comparison.loc[stn_comparison["rank"] == 1.0]

# %%
contact1 = stn_comparison["contact"].values[0]
contact2 = stn_comparison["contact"].values[1]

# %%
if contact1 == contact2:
    print("True")
# Out:
# True

# %% [markdown]
# ### Compare best BSSU directional contact pair to methods

# %%
best_bssu_vs_methods = monopol_comparison.compare_method_to_best_bssu_contact_pair()
# Out:
# file:  fooof_monopol_best_contacts_per_stn_JLB_directional_best_bssu_contact_pair.xlsx
# written in:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/results
# file:  fooof_monopol_best_contacts_per_stn_euclidean_directional_best_bssu_contact_pair.xlsx
# written in:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/results

# %%
best_bssu_vs_methods[0]
# Out:
#                   method    session  sample_size  same_rank_1_and_2_count  \
# 0        JLB_directional     postop           38                       15
# 0        JLB_directional       fu3m           42                       14
# 0        JLB_directional      fu12m           38                        5
# 0        JLB_directional  fu18or24m           18                        3
# 0  euclidean_directional     postop           38                       14
# 0  euclidean_directional       fu3m           42                       15
# 0  euclidean_directional      fu12m           38                        9
# 0  euclidean_directional  fu18or24m           18                        5
#
#    precentage_same  at_least_1_contact_same  precentage_at_least_1_same
# 0         0.394737                       36                    0.947368
# 0         0.333333                       40                    0.952381
# 0         0.131579                       35                    0.921053
# 0         0.166667                       18                    1.000000
# 0         0.368421                       37                    0.973684
# 0         0.357143                       41                    0.976190
# 0         0.236842                       35                    0.921053
# 0         0.277778                       18                    1.000000

# %% [markdown]
# ## Validatation of methods: Spearman correlation to externalized beta

# %% [markdown]
# Watch out!! data only for 5 directional leads, because a directional contact is used as common reference!
# - sub-052: contact 2C Right
# - sub-048: contact 2C Right

# %% [markdown]
# FOOOF

# %% [markdown]
# SSD

# %%
spearman_validation_JLB = monopol_comparison.percept_vs_externalized(method="JLB_directional", externalized_version="externalized_ssd")
# Out:
# file:  fooof_monopol_beta_correlations_per_stn_JLB_directional_externalized_ssd.xlsx
# written in:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/results

# %%
spearman_validation_JLB[0]
# Out:
#                     method      externalized session subject_hemisphere  \
# 024_Left   JLB_directional  externalized_ssd  postop           024_Left
# 024_Right  JLB_directional  externalized_ssd  postop          024_Right
# 025_Left   JLB_directional  externalized_ssd  postop           025_Left
# 025_Right  JLB_directional  externalized_ssd  postop          025_Right
# 028_Left   JLB_directional  externalized_ssd  postop           028_Left
# 028_Right  JLB_directional  externalized_ssd  postop          028_Right
# 029_Left   JLB_directional  externalized_ssd  postop           029_Left
# 029_Right  JLB_directional  externalized_ssd  postop          029_Right
# 030_Left   JLB_directional  externalized_ssd  postop           030_Left
# 030_Right  JLB_directional  externalized_ssd  postop          030_Right
# 032_Left   JLB_directional  externalized_ssd  postop           032_Left
# 032_Right  JLB_directional  externalized_ssd  postop          032_Right
# 047_Left   JLB_directional  externalized_ssd  postop           047_Left
# 047_Right  JLB_directional  externalized_ssd  postop          047_Right
# 048_Left   JLB_directional  externalized_ssd  postop           048_Left
# 048_Right  JLB_directional  externalized_ssd  postop          048_Right
# 049_Left   JLB_directional  externalized_ssd  postop           049_Left
# 049_Right  JLB_directional  externalized_ssd  postop          049_Right
# 052_Left   JLB_directional  externalized_ssd  postop           052_Left
# 052_Right  JLB_directional  externalized_ssd  postop          052_Right
# 059_Left   JLB_directional  externalized_ssd  postop           059_Left
# 059_Right  JLB_directional  externalized_ssd  postop          059_Right
# 061_Left   JLB_directional  externalized_ssd  postop           061_Left
# 061_Right  JLB_directional  externalized_ssd  postop          061_Right
#
#           spearman_r      pval contact_rank_1_method  \
# 024_Left    0.085714  0.871743                    1A
# 024_Right        0.6     0.208                    1A
# 025_Left   -0.314286  0.544093                    2A
# 025_Right   0.142857  0.787172                    2A
# 028_Left   -0.085714  0.871743                    1A
# 028_Right   0.085714  0.871743                    1A
# 029_Left   -0.657143  0.156175                    1B
# 029_Right  -0.714286  0.110787                    1A
# 030_Left   -0.142857  0.787172                    2C
# 030_Right   0.371429  0.468478                    2B
# 032_Left         0.6     0.208                    2C
# 032_Right  -0.371429  0.468478                    2B
# 047_Left   -0.771429  0.072397                    1C
# 047_Right       -0.6     0.208                    2A
# 048_Left    0.085714  0.871743                    1C
# 048_Right   0.828571  0.041563                    1B
# 049_Left   -0.428571  0.396501                    1A
# 049_Right   0.428571  0.396501                    1C
# 052_Left    0.257143  0.622787                    2C
# 052_Right   0.657143  0.156175                    1B
# 059_Left         0.6     0.208                    1A
# 059_Right   0.142857  0.787172                    2B
# 061_Left    0.828571  0.041563                    1C
# 061_Right  -0.085714  0.871743                    2B
#
#           contact_rank_1_externalized contacts_rank_1_2_method  \
# 024_Left                           1A                 [1A, 2A]
# 024_Right                          1A                 [1A, 1C]
# 025_Left                           1A                 [2A, 2C]
# 025_Right                          1B                 [2A, 1A]
# 028_Left                           2C                 [1A, 2A]
# 028_Right                          2C                 [1A, 2A]
# 029_Left                           2A                 [1B, 1A]
# 029_Right                          1C                 [1A, 2A]
# 030_Left                           1B                 [2C, 2B]
# 030_Right                          2B                 [2B, 1B]
# 032_Left                           2C                 [2C, 2A]
# 032_Right                          1B                 [2B, 1B]
# 047_Left                           2B                 [1C, 2C]
# 047_Right                          2B                 [2A, 1A]
# 048_Left                           1B                 [1C, 1B]
# 048_Right                          1B                 [1B, 1C]
# 049_Left                           2C                 [1A, 2A]
# 049_Right                          1B                 [1C, 1B]
# 052_Left                           2C                 [2C, 1C]
# 052_Right                          1C                 [1B, 2B]
# 059_Left                           1B                 [1A, 1B]
# 059_Right                          1C                 [2B, 1B]
# 061_Left                           1C                 [1C, 1A]
# 061_Right                          2C                 [2B, 1B]
#
#           contacts_rank_1_2_externalized compare_rank_1_contact  \
# 024_Left                        [1A, 1C]                   same
# 024_Right                       [1A, 1C]                   same
# 025_Left                        [1A, 1B]              different
# 025_Right                       [1B, 2C]              different
# 028_Left                        [2C, 1B]              different
# 028_Right                       [2C, 1A]              different
# 029_Left                        [2A, 2C]              different
# 029_Right                       [1C, 2C]              different
# 030_Left                        [1B, 1C]              different
# 030_Right                       [2B, 2C]                   same
# 032_Left                        [2C, 2B]                   same
# 032_Right                       [1B, 1A]              different
# 047_Left                        [2B, 2A]              different
# 047_Right                       [2B, 1B]              different
# 048_Left                        [1B, 2C]              different
# 048_Right                       [1B, 1C]                   same
# 049_Left                        [2C, 1A]              different
# 049_Right                       [1B, 1C]              different
# 052_Left                        [2C, 2B]                   same
# 052_Right                       [1C, 1B]              different
# 059_Left                        [1B, 2A]              different
# 059_Right                       [1C, 2B]              different
# 061_Left                        [1C, 1A]                   same
# 061_Right                       [2C, 1B]              different
#
#           compare_rank_1_and_2_contacts both_contacts_match  \
# 024_Left     at_least_one_contact_match                  no
# 024_Right    at_least_one_contact_match                 yes
# 025_Left              no_contacts_match                  no
# 025_Right             no_contacts_match                  no
# 028_Left              no_contacts_match                  no
# 028_Right    at_least_one_contact_match                  no
# 029_Left              no_contacts_match                  no
# 029_Right             no_contacts_match                  no
# 030_Left              no_contacts_match                  no
# 030_Right    at_least_one_contact_match                  no
# 032_Left     at_least_one_contact_match                  no
# 032_Right    at_least_one_contact_match                  no
# 047_Left              no_contacts_match                  no
# 047_Right             no_contacts_match                  no
# 048_Left     at_least_one_contact_match                  no
# 048_Right    at_least_one_contact_match                 yes
# 049_Left     at_least_one_contact_match                  no
# 049_Right    at_least_one_contact_match                 yes
# 052_Left     at_least_one_contact_match                  no
# 052_Right    at_least_one_contact_match                  no
# 059_Left     at_least_one_contact_match                  no
# 059_Right    at_least_one_contact_match                  no
# 061_Left     at_least_one_contact_match                 yes
# 061_Right    at_least_one_contact_match                  no
#
#           significant_correlation
# 024_Left                       no
# 024_Right                      no
# 025_Left                       no
# 025_Right                      no
# 028_Left                       no
# 028_Right                      no
# 029_Left                       no
# 029_Right                      no
# 030_Left                       no
# 030_Right                      no
# 032_Left                       no
# 032_Right                      no
# 047_Left                       no
# 047_Right                      no
# 048_Left                       no
# 048_Right                     yes
# 049_Left                       no
# 049_Right                      no
# 052_Left                       no
# 052_Right                      no
# 059_Left                       no
# 059_Right                      no
# 061_Left                      yes
# 061_Right                      no

# %%
spearman_validation_JLB[1]
# Out:
#    sample_size  spearman_mean  spearman_median  spearman_std  \
# 0           24       0.064286         0.085714       0.48257
#
#    significant_count  percentage_significant  same_rank_1_count  \
# 0                  2                0.083333                  7
#
#    percentage_same_rank_1  at_least_one_contact_match  \
# 0                0.291667                          16
#
#    percentage_at_least_one_contact_match  both_contacts_matching_count  \
# 0                               0.666667                             4
#
#    precentage_both_contacts_match
# 0                        0.166667

# %%
spearman_validation_euclidean = monopol_comparison.percept_vs_externalized(method="euclidean_directional", externalized_version="externalized_ssd")
# Out:
# file:  fooof_monopol_beta_correlations_per_stn_euclidean_directional_externalized_ssd.xlsx
# written in:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/results

# %%
spearman_validation_euclidean[0]
# Out:
#                           method      externalized session subject_hemisphere  \
# 024_Left   euclidean_directional  externalized_ssd  postop           024_Left
# 024_Right  euclidean_directional  externalized_ssd  postop          024_Right
# 025_Left   euclidean_directional  externalized_ssd  postop           025_Left
# 025_Right  euclidean_directional  externalized_ssd  postop          025_Right
# 028_Left   euclidean_directional  externalized_ssd  postop           028_Left
# 028_Right  euclidean_directional  externalized_ssd  postop          028_Right
# 029_Left   euclidean_directional  externalized_ssd  postop           029_Left
# 029_Right  euclidean_directional  externalized_ssd  postop          029_Right
# 030_Left   euclidean_directional  externalized_ssd  postop           030_Left
# 030_Right  euclidean_directional  externalized_ssd  postop          030_Right
# 032_Left   euclidean_directional  externalized_ssd  postop           032_Left
# 032_Right  euclidean_directional  externalized_ssd  postop          032_Right
# 047_Left   euclidean_directional  externalized_ssd  postop           047_Left
# 047_Right  euclidean_directional  externalized_ssd  postop          047_Right
# 048_Left   euclidean_directional  externalized_ssd  postop           048_Left
# 048_Right  euclidean_directional  externalized_ssd  postop          048_Right
# 049_Left   euclidean_directional  externalized_ssd  postop           049_Left
# 049_Right  euclidean_directional  externalized_ssd  postop          049_Right
# 052_Left   euclidean_directional  externalized_ssd  postop           052_Left
# 052_Right  euclidean_directional  externalized_ssd  postop          052_Right
# 059_Left   euclidean_directional  externalized_ssd  postop           059_Left
# 059_Right  euclidean_directional  externalized_ssd  postop          059_Right
# 061_Left   euclidean_directional  externalized_ssd  postop           061_Left
# 061_Right  euclidean_directional  externalized_ssd  postop          061_Right
#
#           spearman_r      pval contact_rank_1_method  \
# 024_Left    0.542857  0.265703                    1A
# 024_Right   0.257143  0.622787                    1A
# 025_Left    0.942857  0.004805                    1A
# 025_Right  -0.314286  0.544093                    1A
# 028_Left   -0.542857  0.265703                    2A
# 028_Right   0.371429  0.468478                    2A
# 029_Left   -0.257143  0.622787                    1A
# 029_Right  -0.428571  0.396501                    1A
# 030_Left    0.371429  0.468478                    1C
# 030_Right   0.542857  0.265703                    2B
# 032_Left    0.542857  0.265703                    2C
# 032_Right   0.257143  0.622787                    1B
# 047_Left        -0.6     0.208                    1C
# 047_Right   0.485714  0.328723                    2B
# 048_Left    0.085714  0.871743                    1C
# 048_Right  -0.885714  0.018845                    2C
# 049_Left   -0.142857  0.787172                    2A
# 049_Right        0.6     0.208                    1C
# 052_Left    0.314286  0.544093                    2C
# 052_Right  -0.714286  0.110787                    2A
# 059_Left    0.142857  0.787172                    1A
# 059_Right       -0.2     0.704                    1B
# 061_Left    0.828571  0.041563                    1C
# 061_Right   0.085714  0.871743                    2A
#
#           contact_rank_1_externalized contacts_rank_1_2_method  \
# 024_Left                           1A                 [1A, 1B]
# 024_Right                          1A                 [1A, 1B]
# 025_Left                           1A                 [1A, 1C]
# 025_Right                          1B                 [1A, 1C]
# 028_Left                           2C                 [2A, 2B]
# 028_Right                          2C                 [2A, 2C]
# 029_Left                           2A                 [1A, 2A]
# 029_Right                          1C                 [1A, 1B]
# 030_Left                           1B                 [1C, 2C]
# 030_Right                          2B                 [2B, 1B]
# 032_Left                           2C                 [2C, 1C]
# 032_Right                          1B                 [1B, 2B]
# 047_Left                           2B                 [1C, 2C]
# 047_Right                          2B                 [2B, 1A]
# 048_Left                           1B                 [1C, 1B]
# 048_Right                          1B                 [2C, 2A]
# 049_Left                           2C                 [2A, 2C]
# 049_Right                          1B                 [1C, 1B]
# 052_Left                           2C                 [2C, 1C]
# 052_Right                          1C                 [2A, 2B]
# 059_Left                           1B                 [1A, 1C]
# 059_Right                          1C                 [1B, 1A]
# 061_Left                           1C                 [1C, 1A]
# 061_Right                          2C                 [2A, 2B]
#
#           contacts_rank_1_2_externalized compare_rank_1_contact  \
# 024_Left                        [1A, 1C]                   same
# 024_Right                       [1A, 1C]                   same
# 025_Left                        [1A, 1B]                   same
# 025_Right                       [1B, 2C]              different
# 028_Left                        [2C, 1B]              different
# 028_Right                       [2C, 1A]              different
# 029_Left                        [2A, 2C]              different
# 029_Right                       [1C, 2C]              different
# 030_Left                        [1B, 1C]              different
# 030_Right                       [2B, 2C]                   same
# 032_Left                        [2C, 2B]                   same
# 032_Right                       [1B, 1A]                   same
# 047_Left                        [2B, 2A]              different
# 047_Right                       [2B, 1B]                   same
# 048_Left                        [1B, 2C]              different
# 048_Right                       [1B, 1C]              different
# 049_Left                        [2C, 1A]              different
# 049_Right                       [1B, 1C]              different
# 052_Left                        [2C, 2B]                   same
# 052_Right                       [1C, 1B]              different
# 059_Left                        [1B, 2A]              different
# 059_Right                       [1C, 2B]              different
# 061_Left                        [1C, 1A]                   same
# 061_Right                       [2C, 1B]              different
#
#           compare_rank_1_and_2_contacts both_contacts_match  \
# 024_Left     at_least_one_contact_match                  no
# 024_Right    at_least_one_contact_match                  no
# 025_Left     at_least_one_contact_match                  no
# 025_Right             no_contacts_match                  no
# 028_Left              no_contacts_match                  no
# 028_Right    at_least_one_contact_match                  no
# 029_Left     at_least_one_contact_match                  no
# 029_Right             no_contacts_match                  no
# 030_Left     at_least_one_contact_match                  no
# 030_Right    at_least_one_contact_match                  no
# 032_Left     at_least_one_contact_match                  no
# 032_Right    at_least_one_contact_match                  no
# 047_Left              no_contacts_match                  no
# 047_Right    at_least_one_contact_match                  no
# 048_Left     at_least_one_contact_match                  no
# 048_Right             no_contacts_match                  no
# 049_Left     at_least_one_contact_match                  no
# 049_Right    at_least_one_contact_match                 yes
# 052_Left     at_least_one_contact_match                  no
# 052_Right             no_contacts_match                  no
# 059_Left              no_contacts_match                  no
# 059_Right             no_contacts_match                  no
# 061_Left     at_least_one_contact_match                 yes
# 061_Right             no_contacts_match                  no
#
#           significant_correlation
# 024_Left                       no
# 024_Right                      no
# 025_Left                      yes
# 025_Right                      no
# 028_Left                       no
# 028_Right                      no
# 029_Left                       no
# 029_Right                      no
# 030_Left                       no
# 030_Right                      no
# 032_Left                       no
# 032_Right                      no
# 047_Left                       no
# 047_Right                      no
# 048_Left                       no
# 048_Right                     yes
# 049_Left                       no
# 049_Right                      no
# 052_Left                       no
# 052_Right                      no
# 059_Left                       no
# 059_Right                      no
# 061_Left                      yes
# 061_Right                      no

# %%
spearman_validation_euclidean[1]
# Out:
#    sample_size  spearman_mean  spearman_median  spearman_std  \
# 0           24       0.095238              0.2      0.488971
#
#    significant_count  percentage_significant  same_rank_1_count  \
# 0                  3                   0.125                  9
#
#    percentage_same_rank_1  at_least_one_contact_match  \
# 0                   0.375                          15
#
#    percentage_at_least_one_contact_match  both_contacts_matching_count  \
# 0                                  0.625                             2
#
#    precentage_both_contacts_match
# 0                        0.083333

# %%
validation_best_bssu_contacts = monopol_comparison.percept_vs_externalized(method="best_bssu_contacts", externalized_version="externalized_ssd")
# Out:
# file:  fooof_monopol_beta_correlations_per_stn_best_bssu_contacts_externalized_ssd.xlsx
# written in:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/results

# %%
validation_best_bssu_contacts[0]
# Out:
#                        method      externalized session subject_hemisphere  \
# 024_Left   best_bssu_contacts  externalized_ssd  postop           024_Left
# 024_Right  best_bssu_contacts  externalized_ssd  postop          024_Right
# 025_Left   best_bssu_contacts  externalized_ssd  postop           025_Left
# 025_Right  best_bssu_contacts  externalized_ssd  postop          025_Right
# 028_Left   best_bssu_contacts  externalized_ssd  postop           028_Left
# 028_Right  best_bssu_contacts  externalized_ssd  postop          028_Right
# 029_Left   best_bssu_contacts  externalized_ssd  postop           029_Left
# 029_Right  best_bssu_contacts  externalized_ssd  postop          029_Right
# 030_Left   best_bssu_contacts  externalized_ssd  postop           030_Left
# 030_Right  best_bssu_contacts  externalized_ssd  postop          030_Right
# 032_Left   best_bssu_contacts  externalized_ssd  postop           032_Left
# 032_Right  best_bssu_contacts  externalized_ssd  postop          032_Right
# 047_Left   best_bssu_contacts  externalized_ssd  postop           047_Left
# 047_Right  best_bssu_contacts  externalized_ssd  postop          047_Right
# 048_Left   best_bssu_contacts  externalized_ssd  postop           048_Left
# 048_Right  best_bssu_contacts  externalized_ssd  postop          048_Right
# 049_Left   best_bssu_contacts  externalized_ssd  postop           049_Left
# 049_Right  best_bssu_contacts  externalized_ssd  postop          049_Right
# 052_Left   best_bssu_contacts  externalized_ssd  postop           052_Left
# 052_Right  best_bssu_contacts  externalized_ssd  postop          052_Right
# 059_Left   best_bssu_contacts  externalized_ssd  postop           059_Left
# 059_Right  best_bssu_contacts  externalized_ssd  postop          059_Right
# 061_Left   best_bssu_contacts  externalized_ssd  postop           061_Left
# 061_Right  best_bssu_contacts  externalized_ssd  postop          061_Right
#
#             spearman_r         pval contact_rank_1_method  \
# 024_Left   no_spearman  no_spearman             no_rank_1
# 024_Right  no_spearman  no_spearman             no_rank_1
# 025_Left   no_spearman  no_spearman             no_rank_1
# 025_Right  no_spearman  no_spearman             no_rank_1
# 028_Left   no_spearman  no_spearman             no_rank_1
# 028_Right  no_spearman  no_spearman             no_rank_1
# 029_Left   no_spearman  no_spearman             no_rank_1
# 029_Right  no_spearman  no_spearman             no_rank_1
# 030_Left   no_spearman  no_spearman             no_rank_1
# 030_Right  no_spearman  no_spearman             no_rank_1
# 032_Left   no_spearman  no_spearman             no_rank_1
# 032_Right  no_spearman  no_spearman             no_rank_1
# 047_Left   no_spearman  no_spearman             no_rank_1
# 047_Right  no_spearman  no_spearman             no_rank_1
# 048_Left   no_spearman  no_spearman             no_rank_1
# 048_Right  no_spearman  no_spearman             no_rank_1
# 049_Left   no_spearman  no_spearman             no_rank_1
# 049_Right  no_spearman  no_spearman             no_rank_1
# 052_Left   no_spearman  no_spearman             no_rank_1
# 052_Right  no_spearman  no_spearman             no_rank_1
# 059_Left   no_spearman  no_spearman             no_rank_1
# 059_Right  no_spearman  no_spearman             no_rank_1
# 061_Left   no_spearman  no_spearman             no_rank_1
# 061_Right  no_spearman  no_spearman             no_rank_1
#
#           contact_rank_1_externalized contacts_rank_1_2_method  \
# 024_Left                           1A                 [1A, 2A]
# 024_Right                          1A                 [1A, 1B]
# 025_Left                           1A                 [1A, 2A]
# 025_Right                          1B                 [1A, 2A]
# 028_Left                           2C                 [1A, 2A]
# 028_Right                          2C                 [1A, 2A]
# 029_Left                           2A                 [1B, 2B]
# 029_Right                          1C                 [1A, 2A]
# 030_Left                           1B                 [1C, 2C]
# 030_Right                          2B                 [1B, 2B]
# 032_Left                           2C                 [1C, 2C]
# 032_Right                          1B                 [1B, 2B]
# 047_Left                           2B                 [1C, 2C]
# 047_Right                          2B                 [1A, 2A]
# 048_Left                           1B                 [1C, 2C]
# 048_Right                          1B                 [2A, 2C]
# 049_Left                           2C                 [1A, 2A]
# 049_Right                          1B                 [1C, 2C]
# 052_Left                           2C                 [1C, 2C]
# 052_Right                          1C                 [2A, 2B]
# 059_Left                           1B                 [1A, 2A]
# 059_Right                          1C                 [1B, 2B]
# 061_Left                           1C                 [1C, 2C]
# 061_Right                          2C                 [1B, 2B]
#
#           contacts_rank_1_2_externalized compare_rank_1_contact  \
# 024_Left                        [1A, 1C]              no_rank_1
# 024_Right                       [1A, 1C]              no_rank_1
# 025_Left                        [1A, 1B]              no_rank_1
# 025_Right                       [1B, 2C]              no_rank_1
# 028_Left                        [2C, 1B]              no_rank_1
# 028_Right                       [2C, 1A]              no_rank_1
# 029_Left                        [2A, 2C]              no_rank_1
# 029_Right                       [1C, 2C]              no_rank_1
# 030_Left                        [1B, 1C]              no_rank_1
# 030_Right                       [2B, 2C]              no_rank_1
# 032_Left                        [2C, 2B]              no_rank_1
# 032_Right                       [1B, 1A]              no_rank_1
# 047_Left                        [2B, 2A]              no_rank_1
# 047_Right                       [2B, 1B]              no_rank_1
# 048_Left                        [1B, 2C]              no_rank_1
# 048_Right                       [1B, 1C]              no_rank_1
# 049_Left                        [2C, 1A]              no_rank_1
# 049_Right                       [1B, 1C]              no_rank_1
# 052_Left                        [2C, 2B]              no_rank_1
# 052_Right                       [1C, 1B]              no_rank_1
# 059_Left                        [1B, 2A]              no_rank_1
# 059_Right                       [1C, 2B]              no_rank_1
# 061_Left                        [1C, 1A]              no_rank_1
# 061_Right                       [2C, 1B]              no_rank_1
#
#           compare_rank_1_and_2_contacts both_contacts_match
# 024_Left     at_least_one_contact_match                  no
# 024_Right    at_least_one_contact_match                  no
# 025_Left     at_least_one_contact_match                  no
# 025_Right             no_contacts_match                  no
# 028_Left              no_contacts_match                  no
# 028_Right    at_least_one_contact_match                  no
# 029_Left              no_contacts_match                  no
# 029_Right             no_contacts_match                  no
# 030_Left     at_least_one_contact_match                  no
# 030_Right    at_least_one_contact_match                  no
# 032_Left     at_least_one_contact_match                  no
# 032_Right    at_least_one_contact_match                  no
# 047_Left              no_contacts_match                  no
# 047_Right             no_contacts_match                  no
# 048_Left     at_least_one_contact_match                  no
# 048_Right             no_contacts_match                  no
# 049_Left     at_least_one_contact_match                  no
# 049_Right    at_least_one_contact_match                  no
# 052_Left     at_least_one_contact_match                  no
# 052_Right             no_contacts_match                  no
# 059_Left     at_least_one_contact_match                  no
# 059_Right    at_least_one_contact_match                  no
# 061_Left     at_least_one_contact_match                  no
# 061_Right    at_least_one_contact_match                  no

# %%
validation_best_bssu_contacts[1]
# Out:
#    sample_size  at_least_one_contact_match  \
# 0           24                          16
#
#    precentage_at_least_one_contact_match  both_contacts_matching_count  \
# 0                               0.666667                             0
#
#    precentage_both_contacts_match
# 0                             0.0

# %% [markdown]
# ## Compare externalized versions with each other: FOOOF vs. SSD

# %%
fooof_vs_ssd_externalized = monopol_comparison.externalized_versions_comparison(externalized_version_1="externalized_fooof", externalized_version_2="externalized_ssd")
# Out:
# Sub-028_Left has no rank 2 contact in the externalized recording.
# Sub-029_Right has no rank 2 contact in the externalized recording.
# Sub-052_Left has no rank 1 contact in the externalized recording.
# file:  fooof_monopol_beta_correlations_per_stn_externalized_fooof_externalized_ssd.xlsx
# written in:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/results

# %%
fooof_vs_ssd_externalized[0]
# Out:
#           externalized_version_1 externalized_version_2 subject_hemisphere  \
# 024_Left      externalized_fooof       externalized_ssd           024_Left
# 024_Right     externalized_fooof       externalized_ssd          024_Right
# 025_Left      externalized_fooof       externalized_ssd           025_Left
# 025_Right     externalized_fooof       externalized_ssd          025_Right
# 028_Right     externalized_fooof       externalized_ssd          028_Right
# 029_Left      externalized_fooof       externalized_ssd           029_Left
# 030_Left      externalized_fooof       externalized_ssd           030_Left
# 030_Right     externalized_fooof       externalized_ssd          030_Right
# 032_Left      externalized_fooof       externalized_ssd           032_Left
# 032_Right     externalized_fooof       externalized_ssd          032_Right
# 047_Left      externalized_fooof       externalized_ssd           047_Left
# 047_Right     externalized_fooof       externalized_ssd          047_Right
# 048_Left      externalized_fooof       externalized_ssd           048_Left
# 049_Left      externalized_fooof       externalized_ssd           049_Left
# 049_Right     externalized_fooof       externalized_ssd          049_Right
# 056_Left      externalized_fooof       externalized_ssd           056_Left
# 056_Right     externalized_fooof       externalized_ssd          056_Right
# 059_Left      externalized_fooof       externalized_ssd           059_Left
# 059_Right     externalized_fooof       externalized_ssd          059_Right
# 061_Left      externalized_fooof       externalized_ssd           061_Left
# 061_Right     externalized_fooof       externalized_ssd          061_Right
# 064_Left      externalized_fooof       externalized_ssd           064_Left
# 064_Right     externalized_fooof       externalized_ssd          064_Right
# 067_Left      externalized_fooof       externalized_ssd           067_Left
# 067_Right     externalized_fooof       externalized_ssd          067_Right
# 069_Left      externalized_fooof       externalized_ssd           069_Left
# 069_Right     externalized_fooof       externalized_ssd          069_Right
# 071_Left      externalized_fooof       externalized_ssd           071_Left
# 071_Right     externalized_fooof       externalized_ssd          071_Right
# 072_Left      externalized_fooof       externalized_ssd           072_Left
# 072_Right     externalized_fooof       externalized_ssd          072_Right
# 075_Left      externalized_fooof       externalized_ssd           075_Left
# 075_Right     externalized_fooof       externalized_ssd          075_Right
# 077_Left      externalized_fooof       externalized_ssd           077_Left
# 077_Right     externalized_fooof       externalized_ssd          077_Right
# 079_Left      externalized_fooof       externalized_ssd           079_Left
# 079_Right     externalized_fooof       externalized_ssd          079_Right
# 080_Left      externalized_fooof       externalized_ssd           080_Left
# 080_Right     externalized_fooof       externalized_ssd          080_Right
#
#            spearman_r      pval contact_rank_1_externalized_1  \
# 024_Left     0.637748  0.173071                            1A
# 024_Right    0.714286  0.110787                            1A
# 025_Left     0.200000  0.704000                            1A
# 025_Right   -0.600000  0.208000                            1C
# 028_Right   -0.200000  0.704000                            1A
# 029_Left     0.371868  0.467910                            1C
# 030_Left     0.485714  0.328723                            2C
# 030_Right   -0.942857  0.004805                            1C
# 032_Left     0.758971  0.080141                            2B
# 032_Right    0.771429  0.072397                            1A
# 047_Left     0.270449  0.604217                            2A
# 047_Right    0.257143  0.622787                            2B
# 048_Left     0.637748  0.173071                            2C
# 049_Left     0.200000  0.704000                            2C
# 049_Right    0.771429  0.072397                            1B
# 056_Left    -0.333947  0.517700                            2B
# 056_Right    0.485714  0.328723                            1A
# 059_Left     0.714286  0.110787                            1B
# 059_Right   -0.085714  0.871743                            1A
# 061_Left     0.724714  0.103243                            1A
# 061_Right    0.085714  0.871743                            2A
# 064_Left     0.028571  0.957155                            1B
# 064_Right    0.542857  0.265703                            1B
# 067_Left     0.600000  0.208000                            1B
# 067_Right   -0.142857  0.787172                            1A
# 069_Left     0.771429  0.072397                            2B
# 069_Right   -0.941124  0.005098                            2B
# 071_Left     0.542857  0.265703                            2C
# 071_Right    0.314286  0.544093                            2C
# 072_Left    -0.314286  0.544093                            2C
# 072_Right    0.314286  0.544093                            2C
# 075_Left     0.942857  0.004805                            2A
# 075_Right    0.771429  0.072397                            1A
# 077_Left     0.405840  0.424663                            2B
# 077_Right    0.942857  0.004805                            1B
# 079_Left    -0.314286  0.544093                            2C
# 079_Right    0.600000  0.208000                            1C
# 080_Left     0.428571  0.396501                            2B
# 080_Right    0.600000  0.208000                            1C
#
#           contact_rank_1_externalized_2 contacts_rank_1_2_externalized_1  \
# 024_Left                             1A                         [1A, 1B]
# 024_Right                            1A                         [1A, 2C]
# 025_Left                             1A                         [1A, 2B]
# 025_Right                            1B                         [1C, 1A]
# 028_Right                            2C                         [1A, 2A]
# 029_Left                             2A                         [1C, 2C]
# 030_Left                             1B                         [2C, 2A]
# 030_Right                            2B                         [1C, 1B]
# 032_Left                             2C                         [2B, 2A]
# 032_Right                            1B                         [1A, 1B]
# 047_Left                             2B                         [2A, 1A]
# 047_Right                            2B                         [2B, 2A]
# 048_Left                             1B                         [2C, 2A]
# 049_Left                             2C                         [2C, 2A]
# 049_Right                            1B                         [1B, 2A]
# 056_Left                             2A                         [2B, 2A]
# 056_Right                            1A                         [1A, 1C]
# 059_Left                             1B                         [1B, 1A]
# 059_Right                            1C                         [1A, 1B]
# 061_Left                             1C                         [1A, 1C]
# 061_Right                            2C                         [2A, 2C]
# 064_Left                             2C                         [1B, 2B]
# 064_Right                            1B                         [1B, 2B]
# 067_Left                             1B                         [1B, 1A]
# 067_Right                            2A                         [1A, 2A]
# 069_Left                             2B                         [2B, 2C]
# 069_Right                            1C                         [2B, 2C]
# 071_Left                             2C                         [2C, 2A]
# 071_Right                            2C                         [2C, 2A]
# 072_Left                             2B                         [2C, 1C]
# 072_Right                            1A                         [2C, 1A]
# 075_Left                             2A                         [2A, 2B]
# 075_Right                            1A                         [1A, 1C]
# 077_Left                             2A                         [2B, 2A]
# 077_Right                            1B                         [1B, 1C]
# 079_Left                             1B                         [2C, 2B]
# 079_Right                            1C                         [1C, 1A]
# 080_Left                             2B                         [2B, 2A]
# 080_Right                            2A                         [1C, 1A]
#
#           contacts_rank_1_2_externalized_2 compare_rank_1_contact  \
# 024_Left                          [1A, 1C]                   same
# 024_Right                         [1A, 1C]                   same
# 025_Left                          [1A, 1B]                   same
# 025_Right                         [1B, 2C]              different
# 028_Right                         [2C, 1A]              different
# 029_Left                          [2A, 2C]              different
# 030_Left                          [1B, 1C]              different
# 030_Right                         [2B, 2C]              different
# 032_Left                          [2C, 2B]              different
# 032_Right                         [1B, 1A]              different
# 047_Left                          [2B, 2A]              different
# 047_Right                         [2B, 1B]                   same
# 048_Left                          [1B, 2C]              different
# 049_Left                          [2C, 1A]                   same
# 049_Right                         [1B, 1C]                   same
# 056_Left                          [2A, 1B]              different
# 056_Right                         [1A, 1C]                   same
# 059_Left                          [1B, 2A]                   same
# 059_Right                         [1C, 2B]              different
# 061_Left                          [1C, 1A]              different
# 061_Right                         [2C, 1B]              different
# 064_Left                          [2C, 2B]              different
# 064_Right                         [1B, 2B]                   same
# 067_Left                          [1B, 1A]                   same
# 067_Right                         [2A, 2C]              different
# 069_Left                          [2B, 2A]                   same
# 069_Right                         [1C, 1B]              different
# 071_Left                          [2C, 1C]                   same
# 071_Right                         [2C, 1B]                   same
# 072_Left                          [2B, 2C]              different
# 072_Right                         [1A, 2B]              different
# 075_Left                          [2A, 2B]                   same
# 075_Right                         [1A, 2C]                   same
# 077_Left                          [2A, 1C]              different
# 077_Right                         [1B, 1C]                   same
# 079_Left                          [1B, 1A]              different
# 079_Right                         [1C, 1A]                   same
# 080_Left                          [2B, 1B]                   same
# 080_Right                         [2A, 1C]              different
#
#           compare_rank_1_and_2_contacts both_contacts_match  \
# 024_Left     at_least_one_contact_match                  no
# 024_Right    at_least_one_contact_match                  no
# 025_Left     at_least_one_contact_match                  no
# 025_Right             no_contacts_match                  no
# 028_Right    at_least_one_contact_match                  no
# 029_Left     at_least_one_contact_match                  no
# 030_Left              no_contacts_match                  no
# 030_Right             no_contacts_match                  no
# 032_Left     at_least_one_contact_match                  no
# 032_Right    at_least_one_contact_match                 yes
# 047_Left     at_least_one_contact_match                  no
# 047_Right    at_least_one_contact_match                  no
# 048_Left     at_least_one_contact_match                  no
# 049_Left     at_least_one_contact_match                  no
# 049_Right    at_least_one_contact_match                  no
# 056_Left     at_least_one_contact_match                  no
# 056_Right    at_least_one_contact_match                 yes
# 059_Left     at_least_one_contact_match                  no
# 059_Right             no_contacts_match                  no
# 061_Left     at_least_one_contact_match                 yes
# 061_Right    at_least_one_contact_match                  no
# 064_Left     at_least_one_contact_match                  no
# 064_Right    at_least_one_contact_match                 yes
# 067_Left     at_least_one_contact_match                 yes
# 067_Right    at_least_one_contact_match                  no
# 069_Left     at_least_one_contact_match                  no
# 069_Right             no_contacts_match                  no
# 071_Left     at_least_one_contact_match                  no
# 071_Right    at_least_one_contact_match                  no
# 072_Left     at_least_one_contact_match                  no
# 072_Right    at_least_one_contact_match                  no
# 075_Left     at_least_one_contact_match                 yes
# 075_Right    at_least_one_contact_match                  no
# 077_Left     at_least_one_contact_match                  no
# 077_Right    at_least_one_contact_match                 yes
# 079_Left              no_contacts_match                  no
# 079_Right    at_least_one_contact_match                 yes
# 080_Left     at_least_one_contact_match                  no
# 080_Right    at_least_one_contact_match                  no
#
#           significant_correlation
# 024_Left                       no
# 024_Right                      no
# 025_Left                       no
# 025_Right                      no
# 028_Right                      no
# 029_Left                       no
# 030_Left                       no
# 030_Right                     yes
# 032_Left                       no
# 032_Right                      no
# 047_Left                       no
# 047_Right                      no
# 048_Left                       no
# 049_Left                       no
# 049_Right                      no
# 056_Left                       no
# 056_Right                      no
# 059_Left                       no
# 059_Right                      no
# 061_Left                       no
# 061_Right                      no
# 064_Left                       no
# 064_Right                      no
# 067_Left                       no
# 067_Right                      no
# 069_Left                       no
# 069_Right                     yes
# 071_Left                       no
# 071_Right                      no
# 072_Left                       no
# 072_Right                      no
# 075_Left                      yes
# 075_Right                      no
# 077_Left                       no
# 077_Right                     yes
# 079_Left                       no
# 079_Right                      no
# 080_Left                       no
# 080_Right                      no

# %%
fooof_vs_ssd_externalized[1]
# Out:
#    sample_size  spearman_mean  spearman_median  spearman_std  \
# 0           39       0.308153         0.428571      0.479168
#
#    significant_count  percentage_significant  same_rank_1_count  \
# 0                  4                0.102564                 18
#
#    percentage_same_rank_1  at_least_one_contact_match  \
# 0                0.461538                          33
#
#    percentage_at_least_one_contact_match  both_contacts_matching_count  \
# 0                               0.846154                             8
#
#    precentage_both_contacts_match
# 0                        0.205128
