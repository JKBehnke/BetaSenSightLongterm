# %% [markdown]
# # SSD

# %% [markdown]
# ## 0. Loading packages

# %%
import plotly
import plotly.graph_objs as go

# Importing Python and external packages


import os
import sys
import importlib
from importlib import reload 
from dataclasses import dataclass, field, fields
from itertools import compress
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cycler import cycler

import scipy
from scipy import stats
from scipy import signal
from scipy.signal import spectrogram, hann, butter, filtfilt, freqz

import seaborn as sns
import pingouin as pg
from itertools import combinations
from statannotations.Annotator import Annotator

import openpyxl
from openpyxl import Workbook, load_workbook
# import xlrd
import pickle
import json
import csv
import h5py
import fooof
from fooof.plts.spectra import plot_spectrum

#mne
from pathlib import Path
import mne_bids
from mne_bids import (
    BIDSPath,
    inspect_dataset,
    mark_channels)
import mne
from mne.time_frequency import tfr_morlet
# Out:
# Excel file loaded:  patient_metadata.xlsx
# loaded from:  /Users/jenniferbehnke/Dropbox/work/ResearchProjects/Monopolar_power_estimation/data

# %%
jennifer_user_path = os.getcwd()
while jennifer_user_path[-14:] != 'jenniferbehnke':
    jennifer_user_path = os.path.dirname(jennifer_user_path)

# directory to this Repository
project_path = os.path.join(jennifer_user_path, 'code', 'BetaSenSightLongterm', 'BetaSenSightLongterm')
sys.path.append(project_path)

os.chdir(project_path)

import src.bssu.utils.find_folders as find_folders
importlib.reload(find_folders)

# import PyPerceive

project_path = find_folders.chdir_repository("Py_Perceive")

from PerceiveImport.classes import (
    main_class, modality_class, metadata_class,
    session_class, condition_class, task_class,
    contact_class, run_class
)

import PerceiveImport.methods.load_rawfile as load_rawfile
import PerceiveImport.methods.find_folders as PyPerceive_find_folders
import PerceiveImport.methods.metadata_helpers as metaHelpers

# import meet

project_path = find_folders.chdir_repository("meet")

import meet as meet

# import all functions from BetaSenSightLongterm
project_path = find_folders.chdir_repository("BetaSenSightLongterm")

# tfr, processing
import src.bssu.tfr.BSSuPsd as BSSuPsd
import src.bssu.tfr.FastFourierPSD as FFpsd
import src.bssu.tfr.feats_ssd as feats_ssd

# bipolar Channel Analysis
import src.bssu.bipolar.power_spectra_plots as power_spectra_plots
import src.bssu.bipolar.PeakFrequencies_PSD as PeakFrequency_psd
import src.bssu.bipolar.BIP_channelGroups as BIP_channelGroups
import src.bssu.bipolar.BIP_perChannelAnalysis as BIP_perChannel


# monopolar Referencing
import src.bssu.monopolar.MonoRef_JLB as MonoRefJLB
import src.bssu.monopolar.GroupMonopolarPSD as groupMonopol
import src.bssu.monopolar.monoRef_weightPsdAverageByCoordinateDistance as MonoRefWeightedCoordinateDistance
import src.bssu.monopolar.externalized_lfp as externalized

# Ranking Order
import src.bssu.ranking.HighestRankedChannelPSD as highestRank
import src.bssu.ranking.monopolPSDaverage_withinSubject as PSDaverageMonopol
import src.bssu.ranking.BIPchannelGroups_ranks as BIP_ranks
import src.bssu.ranking.Permutation_rankings as Permute_ranks


# Clinical stimulation parameters
import src.bssu.stimulation.activeStimulationContacts as activeStimContacts

# utility functions
import src.bssu.utils.loadResults as loadResults
import src.bssu.utils.find_folders as find_folders
import src.bssu.utils.writeGroupDataframes as writeGroupDF
import src.bssu.utils.load_data_files as load_data

# import Classes
from src.bssu.classes import (metadataAnalysis_class, mainAnalysis_class, sessionAnalysis_class, 
                              channelAnalysis_class, featureAnalysis_class, frequencyBand_class)

# import mni coordinates
import src.bssu.mni.load_rotated_coordinates as load_mni

# import Poly5 reader from extern
import src.bssu.extern.tmsi_poly5reader as poly5reader


importlib.reload(BSSuPsd)
importlib.reload(MonoRefJLB)
importlib.reload(loadResults)
importlib.reload(highestRank)
importlib.reload(groupMonopol)
importlib.reload(PSDaverageMonopol)
importlib.reload(FFpsd)
importlib.reload(find_folders)
importlib.reload(metadataAnalysis_class)
importlib.reload(mainAnalysis_class)
importlib.reload(sessionAnalysis_class)
importlib.reload(channelAnalysis_class)
importlib.reload(featureAnalysis_class)
importlib.reload(frequencyBand_class)
importlib.reload(PeakFrequency_psd)
importlib.reload(power_spectra_plots)
importlib.reload(BIP_channelGroups)
importlib.reload(BIP_ranks)
importlib.reload(activeStimContacts)
importlib.reload(Permute_ranks)
importlib.reload(BIP_perChannel)
importlib.reload(load_mni)
importlib.reload(writeGroupDF)
importlib.reload(MonoRefWeightedCoordinateDistance)
importlib.reload(load_data)
importlib.reload(externalized)
importlib.reload(poly5reader)
importlib.reload(feats_ssd)

# load if you want to see complete Dataframes
pd.set_option("display.max_rows", None)

# %% [markdown]
# ## 1. Load Example PyPerceive loaded BSSu (Time Domain)

# %%
example_data = main_class.PerceiveData(
    sub = "017", 
    incl_modalities=["survey"],
    incl_session = [ "postop", "fu3m", "fu12m", "fu18m"],
    incl_condition = ["m0s0"],
    incl_contact=["RingR", "SegmInterR", "SegmIntraR", "RingL", "SegmInterL", "SegmIntraL"],
    incl_task = ["rest"]
)
# Out:
# 	### WARNING: NaNs in Metadata Table sub-017 ###
# NaNs in: sub-017_ses-2021040709594199_run-CHRONIC20210404124649.mat
# NaNs in: sub-017_ses-2021040809491499_run-CHRONIC20210407065701.mat
# NaNs in: sub-017_ses-2021041212054199_run-CHRONIC20210408063010.mat
# NaNs in: sub-017_ses-2021041410364999_run-CHRONIC20210412103008.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414104500.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414104900.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105100.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105600.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105900.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110100.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110400.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110700.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110800.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111200.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111500.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111700.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701073700.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701075300.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701081000.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701082800.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701084400.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702070100.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702071500.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702073000.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702074900.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702080500.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701091600.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701093500.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701095200.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701101000.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701102700.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702083300.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702085000.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702085900.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702091100.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702093000.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702094500.mat
# NaNs in: sub017_ses-1951031311000097_run-CHRONIC20210630042848.mat
# NaNs in: sub017_ses-2021041410364999_run-CHRONIC20210412103008.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414104500.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414104900.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414105100.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414105600.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414105900.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414110100.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414110400.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414110700.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414110800.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414111200.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414111500.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414111700.mat
# NaNs in: sub017_ses-2021070109101797_run-CHRONIC20210701022850.mat
# NaNs in: sub017_ses-2021070206573496_run-CHRONIC20210702012813.mat
# NaNs in: sub017_ses-2021071311000097_run-CHRONIC20210701012849.mat
# NaNs in: sub017_ses-2021070208225996_run-CHRONIC20210702023813.mat
# NaNs in: sub-20210330PSTN_ses-1951031311000087_run-BrainSense20220324080700.mat
# NaNs in: sub-20210330PSTN_ses-1951031311000087_run-BrainSense20220324083800.mat
# NaNs in: sub-20210330PSTN_ses-1951031311000087_run-BrainSense20220324084200.mat
# NaNs in: sub-20210330PSTN_ses-1951031311000087_run-BrainSense20220324084600.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318100100.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318103900.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318104500.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318104900.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318110400.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318111500.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318111900.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318112200.mat
# NaNs in: sub-20210330PSTN_ses-2022032807385487_run-BrainSense20220328075800.mat
# NaNs in: sub-20210330PSTN_ses-2022032807385487_run-BrainSense20220328080800.mat
# NaNs in: sub-20210330PSTN_ses-2022032808474887_run-BrainSense20220328085200.mat
# NaNs in: sub-20210330PSTN_ses-2022032808474887_run-BrainSense20220328085500.mat
# NaNs in: sub-20210330PSTN_ses-2022032808474887_run-BrainSense20220328090200.mat
# NaNs in: sub-20210330PSTN_ses-2022032808474887_run-BrainSense20220328091300.mat
# NaNs in: sub-20210330PSTN_ses-2022032810204287_run-BrainSense20220328102700.mat
# NaNs in: sub-20210330PSTN_ses-2022032810204287_run-BrainSense20220328103500.mat
# NaNs in: sub-20210330PSTN_ses-2022032810204287_run-BrainSense20220328104800.mat
# NaNs in: sub-20210330PSTN_ses-2022032810204287_run-BrainSense20220328105500.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328121200.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328122000.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328123300.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328123700.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328124100.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-CHRONIC20220309063622.mat
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5250
#     Range : 0 ... 5249 =      0.000 ...    20.996 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5313
#     Range : 0 ... 5312 =      0.000 ...    21.248 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5313
#     Range : 0 ... 5312 =      0.000 ...    21.248 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# inserted session (fu18m, survey) can not be found in the metadata table

# %%
timedomain_data = example_data.survey.fu12m.m0s0.rest.SegmIntraR.run1.data

# %%
ch_names = timedomain_data.ch_names
ch_names#[3:6]
# Out:
# ['LFP_R_1A2A_STN', 'LFP_R_1B2B_STN', 'LFP_R_1C2C_STN']

# %%
chan_short = []

for c, chan in enumerate(ch_names):
    bipolarChannel = chan.split("_")
    recording_montage = bipolarChannel[2] 
    chan_short.append(recording_montage)

chan_short
# Out:
# ['1A2A', '1B2B', '1C2C']

# %%
data = timedomain_data.get_data()
data
# Out:
# array([[ 2.59517924,  3.9491858 ,  4.5133552 , ...,  1.80534208,
#          2.36951148,  1.80534208],
#        [-7.14055486, -2.72021138,  2.4935271 , ...,  6.34715988,
#          3.28692208,  0.45336856],
#        [10.4746601 ,  8.88069008,  7.28672007, ...,  2.27710002,
#          1.36626001,  1.70782502],
#        [-1.10845618,  1.10845618,  4.21213347, ...,  4.54467033,
#          1.55183865,  0.77591932],
#        [12.35429333,  8.72734483,  5.78044918, ..., -1.70013211,
#         -0.68005284, -1.70013211],
#        [-5.16718724, -3.9315555 , -3.25757456, ...,  0.56165079,
#          1.79728252,  0.89864126]])

# %%
Ring_2Darray = data[[3,4,5], :]

# %% [markdown]
# ## Load externalized LFP and apply SSD

# %%
externalized_data = externalized.load_patient_data(patient="30")
# Out:
# Extracting parameters from /Users/jenniferbehnke/OneDrive - Charité - Universitätsmedizin Berlin/BIDS_01_Berlin_Neurophys/rawdata/sub-EL007/ses-EcogLfpMedOff01/ieeg/sub-EL007_ses-EcogLfpMedOff01_task-Rest_acq-StimOff_run-1_ieeg.vhdr...
# Setting channel info structure...
# Reading channel info from /Users/jenniferbehnke/OneDrive - Charité - Universitätsmedizin Berlin/BIDS_01_Berlin_Neurophys/rawdata/sub-EL007/ses-EcogLfpMedOff01/ieeg/sub-EL007_ses-EcogLfpMedOff01_task-Rest_acq-StimOff_run-1_channels.tsv.
# Reading electrode coords from /Users/jenniferbehnke/OneDrive - Charité - Universitätsmedizin Berlin/BIDS_01_Berlin_Neurophys/rawdata/sub-EL007/ses-EcogLfpMedOff01/ieeg/sub-EL007_ses-EcogLfpMedOff01_space-MNI152NLin2009bAsym_electrodes.tsv.
# Reading 0 ... 1242569  =      0.000 ...   310.642 secs...
# /Users/jenniferbehnke/Dropbox/work/ResearchProjects/BetaSenSightLongterm/code/BetaSenSightLongterm/src/bssu/utils/load_data_files.py:224: RuntimeWarning: Did not find any events.tsv associated with sub-EL007_ses-EcogLfpMedOff01_task-Rest_acq-StimOff_run-1.
#
# The search_str was "/Users/jenniferbehnke/OneDrive - Charité - Universitätsmedizin Berlin/BIDS_01_Berlin_Neurophys/rawdata/sub-EL007/**/ieeg/sub-EL007_ses-EcogLfpMedOff01*events.tsv"
#   data = mne_bids.read_raw_bids(bids_path=bids_path) # datatype: mne.io.brainvision.brainvision.RawBrainVision
# /Users/jenniferbehnke/Dropbox/work/ResearchProjects/BetaSenSightLongterm/code/BetaSenSightLongterm/src/bssu/utils/load_data_files.py:224: RuntimeWarning: The unit for channel(s) ACC_L_X_D2_TM, ACC_L_Y_D2_TM, ACC_L_Z_D2_TM, ACC_R_X_D2_TM, ACC_R_Y_D2_TM, ACC_R_Z_D2_TM has changed from V to NA.
#   data = mne_bids.read_raw_bids(bids_path=bids_path) # datatype: mne.io.brainvision.brainvision.RawBrainVision
# /Users/jenniferbehnke/Dropbox/work/ResearchProjects/BetaSenSightLongterm/code/BetaSenSightLongterm/src/bssu/utils/load_data_files.py:224: RuntimeWarning: MNI152NLin2009bAsym is not an MNE-Python coordinate frame for IEEG data and so will be set to 'unknown'
#   data = mne_bids.read_raw_bids(bids_path=bids_path) # datatype: mne.io.brainvision.brainvision.RawBrainVision
# /Users/jenniferbehnke/Dropbox/work/ResearchProjects/BetaSenSightLongterm/code/BetaSenSightLongterm/src/bssu/utils/load_data_files.py:224: RuntimeWarning: DigMontage is only a subset of info. There are 2 channel positions not present in the DigMontage. The channels missing from the montage are:
#
# ['EEG_CZ_TM', 'EEG_FZ_TM'].
#
# Consider using inst.rename_channels to match the montage nomenclature, or inst.set_channel_types if these are not EEG channels, or use the on_missing parameter if the channel positions are allowed to be unknown in your analyses.
#   data = mne_bids.read_raw_bids(bids_path=bids_path) # datatype: mne.io.brainvision.brainvision.RawBrainVision
# subject 30 with bids ID sub-EL007 was loaded.

# %%
ch_names = externalized_data["mne_data"].info["ch_names"]

directional = ["LFP_R_02", "LFP_R_03", "LFP_R_04", "LFP_R_05", "LFP_R_06", "LFP_R_07"]
ch_names_LFP = []

for cont in directional:
    ch_name = [chan for chan in ch_names if cont in chan]
    ch_names_LFP.append(ch_name)

# get one list of nested list
ch_names_LFP = [item for sublist in ch_names_LFP for item in sublist]
ch_names_LFP
# Out:
# ['LFP_R_02_STN_MT',
#  'LFP_R_03_STN_MT',
#  'LFP_R_04_STN_MT',
#  'LFP_R_05_STN_MT',
#  'LFP_R_06_STN_MT',
#  'LFP_R_07_STN_MT']

# %%
externalized_data["mne_data"].pick(ch_names_LFP)
# Out:
# <RawBrainVision | sub-EL007_ses-EcogLfpMedOff01_task-Rest_acq-StimOff_run-1_ieeg.eeg, 6 x 1242570 (310.6 s), ~56.9 MB, data loaded>

# %%
data.shape
# Out:
# (6, 1242570)

# %%
data
# Out:
# array([[0.03087226, 0.03087053, 0.03087773, ..., 0.        , 0.        ,
#         0.        ],
#        [0.02585511, 0.02585096, 0.02585037, ..., 0.        , 0.        ,
#         0.        ],
#        [0.03610477, 0.03610395, 0.03610971, ..., 0.        , 0.        ,
#         0.        ],
#        [0.05366432, 0.05366837, 0.05367003, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00899277, 0.00899819, 0.00899883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.0140424 , 0.01405178, 0.01405923, ..., 0.        , 0.        ,
#         0.        ]])

# %%
data = externalized_data["mne_data"].get_data()
Ring_2Darray = data[[3,4,5], :]

# %%
data
# Out:
# array([[0.03087226, 0.03087053, 0.03087773, ..., 0.        , 0.        ,
#         0.        ],
#        [0.02585511, 0.02585096, 0.02585037, ..., 0.        , 0.        ,
#         0.        ],
#        [0.03610477, 0.03610395, 0.03610971, ..., 0.        , 0.        ,
#         0.        ],
#        [0.05366432, 0.05366837, 0.05367003, ..., 0.        , 0.        ,
#         0.        ],
#        [0.00899277, 0.00899819, 0.00899883, ..., 0.        , 0.        ,
#         0.        ],
#        [0.0140424 , 0.01405178, 0.01405923, ..., 0.        , 0.        ,
#         0.        ]])

# %%
artefact_free_lfp = load_data.load_externalized_pickle(filename="externalized_preprocessed_data_artefact_free")

# %%
artefact_free_lfp.head()
# Out:
#     BIDS_id subject hemisphere subject_hemisphere original_ch_name contact  \
# 0  noBIDS24     024      Right          024_Right  LFP_R_01_STN_MT       0
# 1  noBIDS24     024      Right          024_Right  LFP_R_02_STN_MT      1A
# 2  noBIDS24     024      Right          024_Right  LFP_R_03_STN_MT      1B
# 3  noBIDS24     024      Right          024_Right  LFP_R_04_STN_MT      1C
# 4  noBIDS24     024      Right          024_Right  LFP_R_05_STN_MT      2A
#
#                                            lfp_2_min  \
# 0  [-0.0146489130859375, -0.014644931640625, -0.0...
# 1  [0.039686453125, 0.039691835937499996, 0.03968...
# 2  [0.03292761328125, 0.032930234375, 0.032923703...
# 3  [0.045496296874999995, 0.045501386718749995, 0...
# 4  [0.0427853984375, 0.042789980468749995, 0.0427...
#
#                                          time_stamps   sfreq  sfreq_250Hz  \
# 0  [0.0, 0.00025, 0.0005, 0.00075, 0.001, 0.00125...  4000.0        250.0
# 1  [0.0, 0.00025, 0.0005, 0.00075, 0.001, 0.00125...  4000.0        250.0
# 2  [0.0, 0.00025, 0.0005, 0.00075, 0.001, 0.00125...  4000.0        250.0
# 3  [0.0, 0.00025, 0.0005, 0.00075, 0.001, 0.00125...  4000.0        250.0
# 4  [0.0, 0.00025, 0.0005, 0.00075, 0.001, 0.00125...  4000.0        250.0
#
#                                  lfp_resampled_250Hz  \
# 0  [-0.014650027539175887, -0.014658252839254222,...
# 1  [0.03968639766579897, 0.03968883078857783, 0.0...
# 2  [0.032927483537599944, 0.03292990107505366, 0....
# 3  [0.04549634883916892, 0.045498958747322946, 0....
# 4  [0.04278504138418886, 0.04278242301035655, 0.0...
#
#                                    time_stamps_250Hz  \
# 0  [0.0, 0.004, 0.008, 0.012, 0.016, 0.02, 0.024,...
# 1  [0.0, 0.004, 0.008, 0.012, 0.016, 0.02, 0.024,...
# 2  [0.0, 0.004, 0.008, 0.012, 0.016, 0.02, 0.024,...
# 3  [0.0, 0.004, 0.008, 0.012, 0.016, 0.02, 0.024,...
# 4  [0.0, 0.004, 0.008, 0.012, 0.016, 0.02, 0.024,...
#
#                                  filtered_lfp_4000Hz  \
# 0  [3.949032564210164e-06, 3.231238646820861e-06,...
# 1  [2.69323285735393e-06, 2.6718105241033025e-06,...
# 2  [5.628119694315582e-06, 5.634421217695854e-06,...
# 3  [2.665509928098474e-06, 2.743510995010399e-06,...
# 4  [1.3620866122894671e-06, 1.0821347147950646e-0...
#
#                                   filtered_lfp_250Hz  \
# 0  [6.123400776917009e-07, -5.407946823371875e-06...
# 1  [8.025196923263087e-07, 2.69209607371728e-06, ...
# 2  [4.2740305276734576e-07, 2.710763405123185e-06...
# 3  [4.4935559260612634e-07, 2.595175289608499e-06...
# 4  [4.438050843228251e-07, -2.0337643064453155e-0...
#
#                            only_high_pass_lfp_4000Hz  \
# 0  [-2.4981869404081425e-05, -2.098775904803258e-...
# 1  [5.3605057278560556e-05, 5.898965124908392e-05...
# 2  [4.5840314161579463e-05, 4.8444143264025994e-0...
# 3  [6.176658591199339e-05, 6.683700517625139e-05,...
# 4  [5.5626169510300896e-05, 6.016454306745876e-05...
#
#                             only_high_pass_lfp_250Hz  n_samples_250Hz
# 0  [-3.083407269474924e-05, -3.904940482474359e-0...            30000
# 1  [4.4700173607974624e-05, 4.70875647783374e-05,...            30000
# 2  [3.393127763495085e-05, 3.6322806623074414e-05...            30000
# 3  [4.960405505227174e-05, 5.217963047545978e-05,...            30000
# 4  [5.81265284287486e-05, 5.550971705296326e-05, ...            30000

# %%
L001 = artefact_free_lfp.loc[artefact_free_lfp.BIDS_id == "L001"]
Right = L001.loc[L001.hemisphere == "Right"]
channels = Right.loc[Right.original_ch_name.isin(ch_names_LFP)]
data = channels.lfp_resampled_250Hz.values
data = np.array(data.tolist())
data
# Out:
# array([[0.04113918, 0.04115063, 0.04114793, ..., 0.04122739, 0.0412333 ,
#         0.04123277],
#        [0.03457557, 0.03458712, 0.0345822 , ..., 0.03458505, 0.03459017,
#         0.03459477],
#        [0.03603297, 0.03604644, 0.03603988, ..., 0.03617177, 0.03617792,
#         0.0361811 ],
#        [0.10439865, 0.1044135 , 0.1044082 , ..., 0.10515224, 0.10515603,
#         0.10515895],
#        [0.05455787, 0.05457045, 0.05456486, ..., 0.05473022, 0.05473583,
#         0.05473838],
#        [0.04605297, 0.04606389, 0.04605902, ..., 0.04580346, 0.04580694,
#         0.04581161]])

# %% [markdown]
# ## 2. Tutorial to use Jeroen's function get_SSD_component with meet Toolbox (Gunnar)

# %%
# loop over windows 
for i_w, win_dat in enumerate(windows.data[:5]): 
    win_dat = win_dat.astype(np.float64) 

    # select only rows without missing 
    nan_rows = np.array([pd.isna(win_dat[:, i]).any() for i in range(win_dat.shape[-1])]) 
    win_dat = win_dat[:, ~nan_rows] # HAS TO 2D ARRAY WITHOUT MISSING VALUES! 
    win_chnames = list(compress(windows.keys, ~nan_rows)) 
    win_time = windows.win_starttimes[i_w] 
    
    # loop over defined frequency bands 
    for bw in SETTINGS['SPECTRAL_BANDS']: 
        f_range = SETTINGS['SPECTRAL_BANDS'][bw] 
        
        # check whether to perform SSD 
        if SETTINGS['FEATS_INCL']['SSD']: 
            (ssd_filt_data, ssd_pattern, ssd_eigvals 
             ) = ssd.get_SSD_component( 
                data_2d=win_dat.T, 
                fband_interest=f_range, 
                s_rate=windows.fs, 
                use_freqBand_filtered=True, 
                return_comp_n=0, ) 
            
            f, psd = signal.welch(ssd_filt_data, axis=-1, nperseg=windows.fs, fs=windows.fs) 
            
            plt.plot(f, psd, label=bw) 

            
plt.xlim(0, 100) 
plt.title(f'WINDOW # {i_w} - {dType.upper()}') 
plt.legend() 
plt.close()

# %%
f_range = 13, 35
sfreq = 250


(ssd_filt_data, ssd_pattern, ssd_eigvals 
             ) = feats_ssd.get_SSD_component( 
                data_2d=data, 
                fband_interest=f_range, 
                s_rate=sfreq, 
                use_freqBand_filtered=True, 
                return_comp_n=0, ) 
            
f, psd = signal.welch(ssd_filt_data, axis=-1, nperseg=sfreq, fs=sfreq) 
            
plt.plot(f, psd) 

            
plt.xlim(0, 100) 
#plt.title(f'WINDOW # {i_w} - {dType.upper()}') 
#plt.legend() 
#plt.close()
# Out:
# (0.0, 100.0)

# %%
ssd_eigvals
# Out:
# array([0.81232341, 0.77361431, 0.76471818, 0.7111812 , 0.67321323,
#        0.532767  ])

# %%
ssd_pattern[0]
# Out:
# array([ 0.05620908,  0.74919202, -1.        ,  0.28354337, -0.58646868,
#         0.46546271])

# %%
ch_names = externalized_data["mne_data"].ch_names
data = externalized_data["mne_data"].get_data()

# plot the PSD channels in a recording group

for c, chan in enumerate(ch_names):

    # filter signal to visualize
    filtered_lfp = externalized.band_pass_filter_externalized(
        fs=externalized_data["mne_data"].info["sfreq"],
        signal=data[c])


    f, psd = signal.welch(filtered_lfp, axis=-1, nperseg=sfreq, fs=sfreq) 

    plt.plot(f, psd, label=chan)            
    plt.xlim(0, 100) 
    plt.xlabel("Frequency")
    plt.ylabel("PSD [uV^2/Hz]")
    plt.axvline(x=13, color='black', linestyle='--')
    plt.axvline(x=35, color='black', linestyle='--')
    plt.legend()

# %%
fig, axes = plt.subplots(2, 1, figsize=(10,15))

ch_names = timedomain_data.ch_names
data = timedomain_data.get_data()

# plot the PSD channels in a recording group

for c, chan in enumerate(ch_names):

    f, psd = signal.welch(data[c], axis=-1, nperseg=sfreq, fs=sfreq) 

    axes[0].plot(f, psd, label=chan)            
    axes[0].set_xlim(0, 100) 
    axes[0].set_xlabel("Frequency")
    axes[0].set_ylabel("PSD [uV^2/Hz]")
    axes[0].axvline(x=13, color='black', linestyle='--')
    axes[0].axvline(x=35, color='black', linestyle='--')
    axes[0].legend()

# %% [markdown]
# ## 3. Automatize a function calculating and writing Dataframes after applying SSD
# - weights of all bipolar channels
# - weights of different recording montage groups (Ring, SegmInter, SegmIntra)

# %% [markdown]
# write Dataframe with SSD filtered weights for each montage groups seperately

# %%
writtenDataframe = writeGroupDF.write_SSD_filtered_groupChannels(
    incl_sub=["017", "019", "021", "024", "025", "026", "028", "029", "030", "031", "032", "033", "038"],
    f_band="lowBeta"
)
# Out:
# 	### WARNING: NaNs in Metadata Table sub-017 ###
# NaNs in: sub-017_ses-2021040709594199_run-CHRONIC20210404124649.mat
# NaNs in: sub-017_ses-2021040809491499_run-CHRONIC20210407065701.mat
# NaNs in: sub-017_ses-2021041212054199_run-CHRONIC20210408063010.mat
# NaNs in: sub-017_ses-2021041410364999_run-CHRONIC20210412103008.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414104500.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414104900.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105100.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105600.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105900.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110100.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110400.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110700.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110800.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111200.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111500.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111700.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701073700.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701075300.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701081000.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701082800.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210701084400.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702070100.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702071500.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702073000.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702074900.mat
# NaNs in: sub017_ses-2021070206573496_run-BrainSense20210702080500.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701091600.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701093500.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701095200.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701101000.mat
# NaNs in: sub017_ses-2021070109101797_run-BrainSense20210701102700.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702083300.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702085000.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702085900.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702091100.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702093000.mat
# NaNs in: sub017_ses-2021070208225996_run-BrainSense20210702094500.mat
# NaNs in: sub017_ses-1951031311000097_run-CHRONIC20210630042848.mat
# NaNs in: sub017_ses-2021041410364999_run-CHRONIC20210412103008.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414104500.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414104900.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414105100.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414105600.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414105900.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414110100.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414110400.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414110700.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414110800.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414111200.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414111500.mat
# NaNs in: sub017_ses-2021041410364999_run-IS20210414111700.mat
# NaNs in: sub017_ses-2021070109101797_run-CHRONIC20210701022850.mat
# NaNs in: sub017_ses-2021070206573496_run-CHRONIC20210702012813.mat
# NaNs in: sub017_ses-2021071311000097_run-CHRONIC20210701012849.mat
# NaNs in: sub017_ses-2021070208225996_run-CHRONIC20210702023813.mat
# NaNs in: sub-20210330PSTN_ses-1951031311000087_run-BrainSense20220324080700.mat
# NaNs in: sub-20210330PSTN_ses-1951031311000087_run-BrainSense20220324083800.mat
# NaNs in: sub-20210330PSTN_ses-1951031311000087_run-BrainSense20220324084200.mat
# NaNs in: sub-20210330PSTN_ses-1951031311000087_run-BrainSense20220324084600.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318100100.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318103900.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318104500.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318104900.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318110400.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318111500.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318111900.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-BrainSense20220318112200.mat
# NaNs in: sub-20210330PSTN_ses-2022032807385487_run-BrainSense20220328075800.mat
# NaNs in: sub-20210330PSTN_ses-2022032807385487_run-BrainSense20220328080800.mat
# NaNs in: sub-20210330PSTN_ses-2022032808474887_run-BrainSense20220328085200.mat
# NaNs in: sub-20210330PSTN_ses-2022032808474887_run-BrainSense20220328085500.mat
# NaNs in: sub-20210330PSTN_ses-2022032808474887_run-BrainSense20220328090200.mat
# NaNs in: sub-20210330PSTN_ses-2022032808474887_run-BrainSense20220328091300.mat
# NaNs in: sub-20210330PSTN_ses-2022032810204287_run-BrainSense20220328102700.mat
# NaNs in: sub-20210330PSTN_ses-2022032810204287_run-BrainSense20220328103500.mat
# NaNs in: sub-20210330PSTN_ses-2022032810204287_run-BrainSense20220328104800.mat
# NaNs in: sub-20210330PSTN_ses-2022032810204287_run-BrainSense20220328105500.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328121200.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328122000.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328123300.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328123700.mat
# NaNs in: sub-20210330PSTN_ses-2022032812074487_run-BrainSense20220328124100.mat
# NaNs in: sub-20210330PSTN_ses-2022031311000088_run-CHRONIC20220309063622.mat
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5313
#     Range : 0 ... 5312 =      0.000 ...    21.248 secs
# Ready.
mat
# NaNs in: sub033_ses-2021121009000995_run-BrainSense20211210090300.mat
# NaNs in: sub033_ses-2021121009000995_run-BrainSense20211210090600.mat
# NaNs in: sub033_ses-2021121009000995_run-BrainSense20211210092400.mat
# NaNs in: sub033_ses-2021121009000995_run-BrainSense20211210094200.mat
# NaNs in: sub033_ses-2021121009000995_run-CHRONIC20211209034154.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210104400.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210110300.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210112000.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210113800.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210115800.mat
# NaNs in: sub033_ses-2021121010311295_run-CHRONIC20211209041154.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902070300.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902072500.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902072800.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902073800.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902074000.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902074700.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-CHRONIC20220628064614.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906072700.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906074500.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906074900.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906075500.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906075900.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906080400.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906081000.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906083100.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906084100.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906084400.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906084900.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906085200.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906085500.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906085700.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-CHRONIC20220701054724.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092200.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092700.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092800.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201101700.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201102000.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-CHRONIC20220701054724.mat
# inserted session (postop, survey) can not be found in the metadata table
# Creating RawArray with float64 data, n_channels=6, n_times=5275
#     Range : 0 ... 5274 =      0.000 ...    21.096 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5187
#     Range : 0 ... 5186 =      0.000 ...    20.744 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5313
#     Range : 0 ... 5312 =      0.000 ...    21.248 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
#
# 	### WARNING: NaNs in Metadata Table sub-033 ###
# NaNs in: sub033_ses-2021121001471395_run-BrainSense20211210015900.mat
# NaNs in: sub033_ses-2021121001471395_run-BrainSense20211210020200.mat
# NaNs in: sub033_ses-2021121001471395_run-BrainSense20211210021900.mat
# NaNs in: sub033_ses-2021121001471395_run-BrainSense20211210023700.mat
# NaNs in: sub033_ses-2021121001471395_run-BrainSense20211210025400.mat
# NaNs in: sub033_ses-2021121001471395_run-BrainSense20211210031300.mat
# NaNs in: sub033_ses-2021121001471395_run-CHRONIC20211209053154.mat
# NaNs in: sub033_ses-2021121003372895_run-BrainSense20211210033800.mat
# NaNs in: sub033_ses-2021121003372895_run-BrainSense20211210033900.mat
# NaNs in: sub033_ses-2021121003372895_run-CHRONIC20211209064154.mat
# NaNs in: sub033_ses-2021121004021895_run-BrainSense20211210040300.mat
# NaNs in: sub033_ses-2021121004021895_run-BrainSense20211210040400.mat
# NaNs in: sub033_ses-2021121004021895_run-BrainSense20211210042200.mat
# NaNs in: sub033_ses-2021121004021895_run-BrainSense20211210043900.mat
# NaNs in: sub033_ses-2021121004021895_run-BrainSense20211210045800.mat
# NaNs in: sub033_ses-2021121004021895_run-CHRONIC20211209065154.mat
# NaNs in: sub033_ses-2021121007482195_run-BrainSense20211210081300.mat
# NaNs in: sub033_ses-2021121007482195_run-BrainSense20211210081500.mat
# NaNs in: sub033_ses-2021121007482195_run-BrainSense20211210083000.mat
# NaNs in: sub033_ses-2021121007482195_run-CHRONIC20211209031154.mat
# NaNs in: sub033_ses-2021121009000995_run-BrainSense20211210090300.mat
# NaNs in: sub033_ses-2021121009000995_run-BrainSense20211210090600.mat
# NaNs in: sub033_ses-2021121009000995_run-BrainSense20211210092400.mat
# NaNs in: sub033_ses-2021121009000995_run-BrainSense20211210094200.mat
# NaNs in: sub033_ses-2021121009000995_run-CHRONIC20211209034154.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210104400.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210110300.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210112000.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210113800.mat
# NaNs in: sub033_ses-2021121010311295_run-BrainSense20211210115800.mat
# NaNs in: sub033_ses-2021121010311295_run-CHRONIC20211209041154.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902070300.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902072500.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902072800.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902073800.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902074000.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-BrainSense20220902074700.mat
# NaNs in: sub-20210902PStn_ses-2022090206484580_run-CHRONIC20220628064614.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906072700.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906074500.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906074900.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906075500.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906075900.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906080400.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906081000.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906083100.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906084100.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906084400.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906084900.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906085200.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906085500.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-BrainSense20220906085700.mat
# NaNs in: sub-20210902PStn_ses-2022090607102980_run-CHRONIC20220701054724.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092200.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092700.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092800.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201101700.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201102000.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-CHRONIC20220701054724.mat
# inserted session (postop, survey) can not be found in the metadata table
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
#
# 	### WARNING: NaNs in Metadata Table sub-038 ###
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222081400.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222081700.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222082500.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222082700.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222083100.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530072200.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530075400.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530080900.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530082400.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530083800.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-CHRONIC20220530013031.mat
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5188
#     Range : 0 ... 5187 =      0.000 ...    20.748 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5187
#     Range : 0 ... 5186 =      0.000 ...    20.744 secs
# Ready.
# inserted session (fu12m, survey) can not be found in the metadata table
# inserted session (fu18m, survey) can not be found in the metadata table
#
# 	### WARNING: NaNs in Metadata Table sub-038 ###
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222081400.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222081700.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222082500.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222082700.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222083100.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530072200.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530075400.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530080900.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530082400.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530083800.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-CHRONIC20220530013031.mat
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5187
#     Range : 0 ... 5186 =      0.000 ...    20.744 secs
# Ready.
# inserted session (fu12m, survey) can not be found in the metadata table
# inserted session (fu18m, survey) can not be found in the metadata table
# file:  SSD_results_Dataframe_lowBeta.pickle
# written in:  c:\Users\jebe12\Research\Longterm_beta_project\results

# %%
loaded_ssd_result = loadResults.load_SSD_results_pickle(f_band="Beta")
loaded_ssd_result
# Out:
# pickle file loaded:  SSD_results_Dataframe_Beta.pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results
#                                  subject hemisphere session recording_group  \
# 017_Right_fu3m_LFP_R_12_STN_MT       017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_01_STN_MT       017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_23_STN_MT       017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_1A1B_STN_MT     017      Right    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_1B1C_STN_MT     017      Right    fu3m      SegmIntraR
# ...                                  ...        ...     ...             ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT      038       Left    fu3m      SegmIntraL
# 038_Left_fu3m_LFP_L_2A2C_STN_MT      038       Left    fu3m      SegmIntraL
# 038_Left_fu3m_LFP_L_1A2A_STN_MT      038       Left    fu3m      SegmInterL
# 038_Left_fu3m_LFP_L_1B2B_STN_MT      038       Left    fu3m      SegmInterL
# 038_Left_fu3m_LFP_L_1C2C_STN_MT      038       Left    fu3m      SegmInterL
#
#                                  bipolarChannel  \
# 017_Right_fu3m_LFP_R_12_STN_MT               12
# 017_Right_fu3m_LFP_R_01_STN_MT               01
# 017_Right_fu3m_LFP_R_23_STN_MT               23
# 017_Right_fu3m_LFP_R_1A1B_STN_MT           1A1B
# 017_Right_fu3m_LFP_R_1B1C_STN_MT           1B1C
# ...                                         ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT            2B2C
# 038_Left_fu3m_LFP_L_2A2C_STN_MT            2A2C
# 038_Left_fu3m_LFP_L_1A2A_STN_MT            1A2A
# 038_Left_fu3m_LFP_L_1B2B_STN_MT            1B2B
# 038_Left_fu3m_LFP_L_1C2C_STN_MT            1C2C
#
#                                                             ssd_filtered_timedomain  \
# 017_Right_fu3m_LFP_R_12_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_01_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_23_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_1A1B_STN_MT  [-0.09952216387371969, -1.2380238972337754, -2...
# 017_Right_fu3m_LFP_R_1B1C_STN_MT  [-0.09952216387371969, -1.2380238972337754, -2...
# ...                                                                             ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT   [0.03864237345034142, -0.25534729218288954, -0...
# 038_Left_fu3m_LFP_L_2A2C_STN_MT   [0.03864237345034142, -0.25534729218288954, -0...
# 038_Left_fu3m_LFP_L_1A2A_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1B2B_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1C2C_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
#
#                                  ssd_pattern ssd_eigvals
# 017_Right_fu3m_LFP_R_12_STN_MT     -0.872632    0.901847
# 017_Right_fu3m_LFP_R_01_STN_MT     -0.213996    0.792729
# 017_Right_fu3m_LFP_R_23_STN_MT           1.0    0.649734
# 017_Right_fu3m_LFP_R_1A1B_STN_MT    0.029354     0.89082
# 017_Right_fu3m_LFP_R_1B1C_STN_MT   -0.241398    0.840307
# ...                                      ...         ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT    -0.000054    0.789974
# 038_Left_fu3m_LFP_L_2A2C_STN_MT      0.20553    0.753945
# 038_Left_fu3m_LFP_L_1A2A_STN_MT      0.33295    0.926278
# 038_Left_fu3m_LFP_L_1B2B_STN_MT          1.0    0.828405
# 038_Left_fu3m_LFP_L_1C2C_STN_MT     0.459841    0.771573
#
# [864 rows x 8 columns]

# %% [markdown]
# Write Dataframe of SSD filtered signals of different channel groups + PLOT Power Spectra and first component Spectrum

# %%
SSD_results = BSSu_ssd.SSD_filter_groupChannels(
    incl_sub=["017", "019", "021", "024", "025", "026", "028", "029", "030", "031", "032", "033", "038"],
    f_band="highBeta"
)
# Out:
# 	### WARNING: NaNs in Metadata Table sub-017 ###
# NaNs in: sub-017_ses-2021040709594199_run-CHRONIC20210404124649.mat
# NaNs in: sub-017_ses-2021040809491499_run-CHRONIC20210407065701.mat
# NaNs in: sub-017_ses-2021041212054199_run-CHRONIC20210408063010.mat
# NaNs in: sub-017_ses-2021041410364999_run-CHRONIC20210412103008.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414104500.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414104900.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105100.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105600.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414105900.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110100.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110400.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110700.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414110800.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111200.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111500.mat
# NaNs in: sub-017_ses-2021041410364999_run-IS20210414111700.mat
# NaNs in: sub017_ses-2021071311000097_run-BrainSense20210
mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092200.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092700.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201092800.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201101700.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-BrainSense20230201102000.mat
# NaNs in: sub-20210902PStn_ses-2023020108101472_run-CHRONIC20220701054724.mat
# inserted session (postop, survey) can not be found in the metadata table
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
#
# 	### WARNING: NaNs in Metadata Table sub-038 ###
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222081400.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222081700.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222082500.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222082700.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222083100.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530072200.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530075400.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530080900.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530082400.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530083800.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-CHRONIC20220530013031.mat
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5188
#     Range : 0 ... 5187 =      0.000 ...    20.748 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5187
#     Range : 0 ... 5186 =      0.000 ...    20.744 secs
# Ready.
# inserted session (fu12m, survey) can not be found in the metadata table
# inserted session (fu18m, survey) can not be found in the metadata table
#
# 	### WARNING: NaNs in Metadata Table sub-038 ###
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222081400.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222081700.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222082500.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222082700.mat
# NaNs in: sub-20220209PStn_ses-2022020611000099_run-BrainSense20220222083100.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530072200.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530075400.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530080900.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530082400.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-BrainSense20220530083800.mat
# NaNs in: sub-20220209PStn_ses-1956020611000096_run-CHRONIC20220530013031.mat
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5312
#     Range : 0 ... 5311 =      0.000 ...    21.244 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=6, n_times=5288
#     Range : 0 ... 5287 =      0.000 ...    21.148 secs
# Ready.
# Creating RawArray with float64 data, n_channels=3, n_times=5187
#     Range : 0 ... 5186 =      0.000 ...    20.744 secs
# Ready.
# inserted session (fu12m, survey) can not be found in the metadata table
# inserted session (fu18m, survey) can not be found in the metadata table
# file:  SSD_results_Dataframe_highBeta.pickle
# written in:  c:\Users\jebe12\Research\Longterm_beta_project\results

# %%
SSD_results
# Out:
#                                    subject hemisphere session recording_group  \
# 017_Right_fu3m_LFP_R_12_STN_MT         017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_01_STN_MT         017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_23_STN_MT         017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_1A1B_STN_MT       017      Right    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_1B1C_STN_MT       017      Right    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_1A1C_STN_MT       017      Right    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_2A2B_STN_MT       017      Right    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_2B2C_STN_MT       017      Right    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_2A2C_STN_MT       017      Right    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_1A2A_STN_MT       017      Right    fu3m      SegmInterR
# 017_Right_fu3m_LFP_R_1B2B_STN_MT       017      Right    fu3m      SegmInterR
# 017_Right_fu3m_LFP_R_1C2C_STN_MT       017      Right    fu3m      SegmInterR
# 017_Right_fu12m_LFP_R_12_STN           017      Right   fu12m           RingR
# 017_Right_fu12m_LFP_R_01_STN           017      Right   fu12m           RingR
# 017_Right_fu12m_LFP_R_23_STN           017      Right   fu12m           RingR
# 017_Right_fu12m_LFP_R_1A1B_STN         017      Right   fu12m      SegmIntraR
# 017_Right_fu12m_LFP_R_1B1C_STN         017      Right   fu12m      SegmIntraR
# 017_Right_fu12m_LFP_R_1A1C_STN         017      Right   fu12m      SegmIntraR
# 017_Right_fu12m_LFP_R_2A2B_STN         017      Right   fu12m      SegmIntraR
# 017_Right_fu12m_LFP_R_2B2C_STN         017      Right   fu12m      SegmIntraR
# 017_Right_fu12m_LFP_R_2A2C_STN         017      Right   fu12m      SegmIntraR
# 017_Right_fu12m_LFP_R_1A2A_STN         017      Right   fu12m      SegmInterR
# 017_Right_fu12m_LFP_R_1B2B_STN         017      Right   fu12m      SegmInterR
# 017_Right_fu12m_LFP_R_1C2C_STN         017      Right   fu12m      SegmInterR
# 017_Left_fu3m_LFP_L_12_STN_MT          017       Left    fu3m           RingL
# 017_Left_fu3m_LFP_L_01_STN_MT          017       Left    fu3m           RingL
# 017_Left_fu3m_LFP_L_23_STN_MT          017       Left    fu3m           RingL
# 017_Left_fu3m_LFP_L_1A1B_STN_MT        017       Left    fu3m      SegmIntraL
# 017_Left_fu3m_LFP_L_1B1C_STN_MT        017       Left    fu3m      SegmIntraL
# 017_Left_fu3m_LFP_L_1A1C_STN_MT        017       Left    fu3m      SegmIntraL
# 017_Left_fu3m_LFP_L_2A2B_STN_MT        017       Left    fu3m      SegmIntraL
# 017_Left_fu3m_LFP_L_2B2C_STN_MT        017       Left    fu3m      SegmIntraL
# 017_Left_fu3m_LFP_L_2A2C_STN_MT        017       Left    fu3m      SegmIntraL
# 017_Left_fu3m_LFP_L_1A2A_STN_MT        017       Left    fu3m      SegmInterL
# 017_Left_fu3m_LFP_L_1B2B_STN_MT        017       Left    fu3m      SegmInterL
# 017_Left_fu3m_LFP_L_1C2C_STN_MT        017       Left    fu3m      SegmInterL
# 017_Left_fu12m_LFP_L_12_STN            017       Left   fu12m           RingL
# 017_Left_fu12m_LFP_L_01_STN            017       Left   fu12m           RingL
# 017_Left_fu12m_LFP_L_23_STN            017       Left   fu12m           RingL
# 017_Left_fu12m_LFP_L_1A1B_STN          017       Left   fu12m      SegmIntraL
# 017_Left_fu12m_LFP_L_1B1C_STN          017       Left   fu12m      SegmIntraL
# 017_Left_fu12m_LFP_L_1A1C_STN          017       Left   fu12m      SegmIntraL
# 017_Left_fu12m_LFP_L_2A2B_STN          017       Left   fu12m      SegmIntraL
# 017_Left_fu12m_LFP_L_2B2C_STN          017       Left   fu12m      SegmIntraL
# 017_Left_fu12m_LFP_L_2A2C_STN          017       Left   fu12m      SegmIntraL
# 017_Left_fu12m_LFP_L_1A2A_STN          017       Left   fu12m      SegmInterL
# 017_Left_fu12m_LFP_L_1B2B_STN          017       Left   fu12m      SegmInterL
# 017_Left_fu12m_LFP_L_1C2C_STN          017       Left   fu12m      SegmInterL
# 019_Right_fu3m_LFP_R_12_STN_MT         019      Right    fu3m           RingR
# 019_Right_fu3m_LFP_R_01_STN_MT         019      Right    fu3m           RingR
# 019_Right_fu3m_LFP_R_23_STN_MT         019      Right    fu3m           RingR
# 019_Right_fu3m_LFP_R_1A1B_STN_MT       019      Right    fu3m      SegmIntraR
# 019_Right_fu3m_LFP_R_1B1C_STN_MT       019      Right    fu3m      SegmIntraR
# 019_Right_fu3m_LFP_R_1A1C_STN_MT       019      Right    fu3m      SegmIntraR
# 019_Right_fu3m_LFP_R_2A2B_STN_MT       019      Right    fu3m      SegmIntraR
# 019_Right_fu3m_LFP_R_2B2C_STN_MT       019      Right    fu3m      SegmIntraR
# 019_Right_fu3m_LFP_R_2A2C_STN_MT       019      Right    fu3m      SegmIntraR
# 019_Right_fu3m_LFP_R_1A2A_STN_MT       019      Right    fu3m      SegmInterR
# 019_Right_fu3m_LFP_R_1B2B_STN_MT       019      Right    fu3m      SegmInterR
# 019_Right_fu3m_LFP_R_1C2C_STN_MT       019      Right    fu3m      SegmInterR
# 019_Right_fu12m_LFP_R_12_STN_MT        019      Right   fu12m           RingR
# 019_Right_fu12m_LFP_R_01_STN_MT        019      Right   fu12m           RingR
# 019_Right_fu12m_LFP_R_23_STN_MT        019      Right   fu12m           RingR
# 019_Right_fu12m_LFP_R_1A1B_STN_MT      019      Right   fu12m      SegmIntraR
# 019_Right_fu12m_LFP_R_1B1C_STN_MT      019      Right   fu12m      SegmIntraR
# 019_Right_fu12m_LFP_R_1A1C_STN_MT      019      Right   fu12m      SegmIntraR
# 019_Right_fu12m_LFP_R_2A2B_STN_MT      019      Right   fu12m      SegmIntraR
# 019_Right_fu12m_LFP_R_2B2C_STN_MT      019      Right   fu12m      SegmIntraR
# 019_Right_fu12m_LFP_R_2A2C_STN_MT      019      Right   fu12m      SegmIntraR
# 019_Right_fu12m_LFP_R_1A2A_STN_MT      019      Right   fu12m      SegmInterR
# 019_Right_fu12m_LFP_R_1B2B_STN_MT      019      Right   fu12m      SegmInterR
# 019_Right_fu12m_LFP_R_1C2C_STN_MT      019      Right   fu12m      SegmInterR
# 019_Right_fu18m_LFP_R_12_STN_MT        019      Right   fu18m           RingR
# 019_Right_fu18m_LFP_R_01_STN_MT        019      Right   fu18m           RingR
# 019_Right_fu18m_LFP_R_23_STN_MT        019      Right   fu18m           RingR
# 019_Right_fu18m_LFP_R_1A1B_STN_MT      019      Right   fu18m      SegmIntraR
# 019_Right_fu18m_LFP_R_1B1C_STN_MT      019      Right   fu18m      SegmIntraR
# 019_Right_fu18m_LFP_R_1A1C_STN_MT      019      Right   fu18m      SegmIntraR
# 019_Right_fu18m_LFP_R_2A2B_STN_MT      019      Right   fu18m      SegmIntraR
# 019_Right_fu18m_LFP_R_2B2C_STN_MT      019      Right   fu18m      SegmIntraR
# 019_Right_fu18m_LFP_R_2A2C_STN_MT      019      Right   fu18m      SegmIntraR
# 019_Right_fu18m_LFP_R_1A2A_STN_MT      019      Right   fu18m      SegmInterR
# 019_Right_fu18m_LFP_R_1B2B_STN_MT      019      Right   fu18m      SegmInterR
# 019_Right_fu18m_LFP_R_1C2C_STN_MT      019      Right   fu18m      SegmInterR
# 019_Left_fu3m_LFP_L_12_STN_MT          019       Left    fu3m           RingL
# 019_Left_fu3m_LFP_L_01_STN_MT          019       Left    fu3m           RingL
# 019_Left_fu3m_LFP_L_23_STN_MT          019       Left    fu3m           RingL
# 019_Left_fu3m_LFP_L_1A1B_STN_MT        019       Left    fu3m      SegmIntraL
# 019_Left_fu3m_LFP_L_1B1C_STN_MT        019       Left    fu3m      SegmIntraL
# 019_Left_fu3m_LFP_L_1A1C_STN_MT        019       Left    fu3m      SegmIntraL
# 019_Left_fu3m_LFP_L_2A2B_STN_MT        019       Left    fu3m      SegmIntraL
# 019_Left_fu3m_LFP_L_2B2C_STN_MT        019       Left    fu3m      SegmIntraL
# 019_Left_fu3m_LFP_L_2A2C_STN_MT        019       Left    fu3m      SegmIntraL
# 021_Right_fu3m_LFP_R_2B2C_STN_MT       021      Right    fu3m      SegmIntraR
# 021_Right_fu3m_LFP_R_2A2C_STN_MT       021      Right    fu3m      SegmIntraR
# 021_Right_fu3m_LFP_R_1A2A_STN_MT       021      Right    fu3m      SegmInterR
# 021_Right_fu3m_LFP_R_1B2B_STN_MT       021      Right    fu3m      SegmInterR
# 021_Right_fu3m_LFP_R_1C2C_STN_MT       021      Right    fu3m      SegmInterR
# 021_Right_fu12m_LFP_R_12_STN_MT        021      Right   fu12m           RingR
# 021_Right_fu12m_LFP_R_01_STN_MT        021      Right   fu12m           RingR
# 021_Right_fu12m_LFP_R_23_STN_MT        021      Right   fu12m           RingR
# 021_Right_fu12m_LFP_R_1A1B_STN_MT      021      Right   fu12m      SegmIntraR
# 021_Right_fu12m_LFP_R_1B1C_STN_MT      021      Right   fu12m      SegmIntraR
# 021_Right_fu12m_LFP_R_1A1C_STN_MT      021      Right   fu12m      SegmIntraR
# 021_Right_fu12m_LFP_R_2A2B_STN_MT      021      Right   fu12m      SegmIntraR
# 021_Right_fu12m_LFP_R_2B2C_STN_MT      021      Right   fu12m      SegmIntraR
# 021_Right_fu12m_LFP_R_2A2C_STN_MT      021      Right   fu12m      SegmIntraR
# 021_Right_fu12m_LFP_R_1A2A_STN_MT      021      Right   fu12m      SegmInterR
# 021_Right_fu12m_LFP_R_1B2B_STN_MT      021      Right   fu12m      SegmInterR
# 021_Right_fu12m_LFP_R_1C2C_STN_MT      021      Right   fu12m      SegmInterR
# 021_Right_fu18m_LFP_R_12_STN_MT        021      Right   fu18m           RingR
# 021_Right_fu18m_LFP_R_01_STN_MT        021      Right   fu18m           RingR
# 021_Right_fu18m_LFP_R_23_STN_MT        021      Right   fu18m           RingR
# 021_Right_fu18m_LFP_R_1A1B_STN_MT      021      Right   fu18m      SegmIntraR
# 021_Right_fu18m_LFP_R_1B1C_STN_MT      021      Right   fu18m      SegmIntraR
# 021_Right_fu18m_LFP_R_1A1C_STN_MT      021      Right   fu18m      SegmIntraR
# 021_Right_fu18m_LFP_R_2A2B_STN_MT      021      Right   fu18m      SegmIntraR
# 021_Right_fu18m_LFP_R_2B2C_STN_MT      021      Right   fu18m      SegmIntraR
# 021_Right_fu18m_LFP_R_2A2C_STN_MT      021      Right   fu18m      SegmIntraR
# 021_Right_fu18m_LFP_R_1A2A_STN_MT      021      Right   fu18m      SegmInterR
# 021_Right_fu18m_LFP_R_1B2B_STN_MT      021      Right   fu18m      SegmInterR
# 021_Right_fu18m_LFP_R_1C2C_STN_MT      021      Right   fu18m      SegmInterR
# 021_Left_fu3m_LFP_L_12_STN_MT          021       Left    fu3m           RingL
# 021_Left_fu3m_LFP_L_01_STN_MT          021       Left    fu3m           RingL
# 021_Left_fu3m_LFP_L_23_STN_MT          021       Left    fu3m           RingL
# 021_Left_fu3m_LFP_L_1A1B_STN_MT        021       Left    fu3m      SegmIntraL
# 021_Left_fu3m_LFP_L_1B1C_STN_MT        021       Left    fu3m      SegmIntraL
# 024_Right_postop_LFP_R_1B1C_STN_MT     024      Right  postop      SegmIntraR
# 024_Right_postop_LFP_R_1A1C_STN_MT     024      Right  postop      SegmIntraR
# 024_Right_postop_LFP_R_2A2B_STN_MT     024      Right  postop      SegmIntraR
# 024_Right_postop_LFP_R_2B2C_STN_MT     024      Right  postop      SegmIntraR
# 024_Right_postop_LFP_R_2A2C_STN_MT     024      Right  postop      SegmIntraR
# 024_Right_postop_LFP_R_1A2A_STN_MT     024      Right  postop      SegmInterR
# 024_Right_postop_LFP_R_1B2B_STN_MT     024      Right  postop      SegmInterR
# 024_Right_postop_LFP_R_1C2C_STN_MT     024      Right  postop      SegmInterR
# 024_Right_fu3m_LFP_R_12_STN_MT         024      Right    fu3m           RingR
# 024_Right_fu3m_LFP_R_01_STN_MT         024      Right    fu3m           RingR
# 024_Right_fu3m_LFP_R_23_STN_MT         024      Right    fu3m           RingR
# 024_Right_fu3m_LFP_R_1A1B_STN_MT       024      Right    fu3m      SegmIntraR
# 024_Right_fu3m_LFP_R_1B1C_STN_MT       024      Right    fu3m      SegmIntraR
# 024_Right_fu3m_LFP_R_1A1C_STN_MT       024      Right    fu3m      SegmIntraR
# 024_Right_fu3m_LFP_R_2A2B_STN_MT       024      Right    fu3m      SegmIntraR
# 024_Right_fu3m_LFP_R_2B2C_STN_MT       024      Right    fu3m      SegmIntraR
# 024_Right_fu3m_LFP_R_2A2C_STN_MT       024      Right    fu3m      SegmIntraR
# 024_Right_fu3m_LFP_R_1A2A_STN_MT       024      Right    fu3m      SegmInterR
# 024_Right_fu3m_LFP_R_1B2B_STN_MT       024      Right    fu3m      SegmInterR
# 024_Right_fu3m_LFP_R_1C2C_STN_MT       024      Right    fu3m      SegmInterR
# 024_Right_fu12m_LFP_R_12_STN_MT        024      Right   fu12m           RingR
# 024_Right_fu12m_LFP_R_01_STN_MT        024      Right   fu12m           RingR
# 024_Right_fu12m_LFP_R_23_STN_MT        024      Right   fu12m           RingR
# 024_Right_fu12m_LFP_R_1A1B_STN_MT      024      Right   fu12m      SegmIntraR
# 024_Right_fu12m_LFP_R_1B1C_STN_MT      024      Right   fu12m      SegmIntraR
# 024_Right_fu12m_LFP_R_1A1C_STN_MT      024      Right   fu12m      SegmIntraR
# 024_Right_fu12m_LFP_R_2A2B_STN_MT      024      Right   fu12m      SegmIntraR
# 024_Right_fu12m_LFP_R_2B2C_STN_MT      024      Right   fu12m      SegmIntraR
# 024_Right_fu12m_LFP_R_2A2C_STN_MT      024      Right   fu12m      SegmIntraR
# 024_Right_fu12m_LFP_R_1A2A_STN_MT      024      Right   fu12m      SegmInterR
# 024_Right_fu12m_LFP_R_1B2B_STN_MT      024      Right   fu12m      SegmInterR
# 024_Right_fu12m_LFP_R_1C2C_STN_MT      024      Right   fu12m      SegmInterR
# 024_Right_fu18m_LFP_R_12_STN_MT        024      Right   fu18m           RingR
# 024_Right_fu18m_LFP_R_01_STN_MT        024      Right   fu18m           RingR
# 024_Right_fu18m_LFP_R_23_STN_MT        024      Right   fu18m           RingR
# 024_Right_fu18m_LFP_R_1A1B_STN_MT      024      Right   fu18m      SegmIntraR
# 024_Right_fu18m_LFP_R_1B1C_STN_MT      024      Right   fu18m      SegmIntraR
# 024_Right_fu18m_LFP_R_1A1C_STN_MT      024      Right   fu18m      SegmIntraR
# 024_Right_fu18m_LFP_R_2A2B_STN_MT      024      Right   fu18m      SegmIntraR
# 024_Right_fu18m_LFP_R_2B2C_STN_MT      024      Right   fu18m      SegmIntraR
# 024_Right_fu18m_LFP_R_2A2C_STN_MT      024      Right   fu18m      SegmIntraR
# 024_Right_fu18m_LFP_R_1A2A_STN_MT      024      Right   fu18m      SegmInterR
# 024_Right_fu18m_LFP_R_1B2B_STN_MT      024      Right   fu18m      SegmInterR
# 024_Right_fu18m_LFP_R_1C2C_STN_MT      024      Right   fu18m      SegmInterR
# 024_Left_postop_LFP_L_12_STN_MT        024       Left  postop           RingL
# 024_Left_postop_LFP_L_01_STN_MT        024       Left  postop           RingL
# 024_Left_postop_LFP_L_23_STN_MT        024       Left  postop           RingL
# 024_Left_postop_LFP_L_1A1B_STN_MT      024       Left  postop      SegmIntraL
# 024_Left_postop_LFP_L_1B1C_STN_MT      024       Left  postop      SegmIntraL
# 024_Left_postop_LFP_L_1A1C_STN_MT      024       Left  postop      SegmIntraL
# 024_Left_postop_LFP_L_2A2B_STN_MT      024       Left  postop      SegmIntraL
# 024_Left_postop_LFP_L_2B2C_STN_MT      024       Left  postop      SegmIntraL
# 024_Left_postop_LFP_L_2A2C_STN_MT      024       Left  postop      SegmIntraL
# 024_Left_postop_LFP_L_1A2A_STN_MT      024       Left  postop      SegmInterL
# 024_Left_postop_LFP_L_1B2B_STN_MT      024       Left  postop      SegmInterL
# 024_Left_postop_LFP_L_1C2C_STN_MT      024       Left  postop      SegmInterL
# 024_Left_fu3m_LFP_L_12_STN_MT          024       Left    fu3m           RingL
# 024_Left_fu3m_LFP_L_01_STN_MT          024       Left    fu3m           RingL
# 024_Left_fu3m_LFP_L_23_STN_MT          024       Left    fu3m           RingL
# 024_Left_fu3m_LFP_L_1A1B_STN_MT        024       Left    fu3m      SegmIntraL
# 024_Left_fu3m_LFP_L_1B1C_STN_MT        024       Left    fu3m      SegmIntraL
# 024_Left_fu3m_LFP_L_1A1C_STN_MT        024       Left    fu3m      SegmIntraL
# 024_Left_fu3m_LFP_L_2A2B_STN_MT        024       Left    fu3m      SegmIntraL
# 024_Left_fu3m_LFP_L_2B2C_STN_MT        024       Left    fu3m      SegmIntraL
# 024_Left_fu3m_LFP_L_2A2C_STN_MT        024       Left    fu3m      SegmIntraL
# 024_Left_fu3m_LFP_L_1A2A_STN_MT        024       Left    fu3m      SegmInterL
# 024_Left_fu3m_LFP_L_1B2B_STN_MT        024       Left    fu3m      SegmInterL
# 024_Left_fu3m_LFP_L_1C2C_STN_MT        024       Left    fu3m      SegmInterL
# 024_Left_fu12m_LFP_L_12_STN_MT         024       Left   fu12m           RingL
# 024_Left_fu12m_LFP_L_01_STN_MT         024       Left   fu12m           RingL
# 024_Left_fu12m_LFP_L_23_STN_MT         024       Left   fu12m           RingL
# 024_Left_fu12m_LFP_L_1A1B_STN_MT       024       Left   fu12m      SegmIntraL
# 024_Left_fu12m_LFP_L_1B1C_STN_MT       024       Left   fu12m      SegmIntraL
# 024_Left_fu12m_LFP_L_1A1C_STN_MT       024       Left   fu12m      SegmIntraL
# 024_Left_fu12m_LFP_L_2A2B_STN_MT       024       Left   fu12m      SegmIntraL
# 024_Left_fu12m_LFP_L_2B2C_STN_MT       024       Left   fu12m      SegmIntraL
# 024_Left_fu12m_LFP_L_2A2C_STN_MT       024       Left   fu12m      SegmIntraL
# 024_Left_fu12m_LFP_L_1A2A_STN_MT       024       Left   fu12m      SegmInterL
# 024_Left_fu12m_LFP_L_1B2B_STN_MT       024       Left   fu12m      SegmInterL
# 024_Left_fu12m_LFP_L_1C2C_STN_MT       024       Left   fu12m      SegmInterL
# 024_Left_fu18m_LFP_L_12_STN_MT         024       Left   fu18m           RingL
# 024_Left_fu18m_LFP_L_01_STN_MT         024       Left   fu18m           RingL
# 024_Left_fu18m_LFP_L_23_STN_MT         024       Left   fu18m           RingL
# 024_Left_fu18m_LFP_L_1A1B_STN_MT       024       Left   fu18m      SegmIntraL
# 024_Left_fu18m_LFP_L_1B1C_STN_MT       024       Left   fu18m      SegmIntraL
# 024_Left_fu18m_LFP_L_1A1C_STN_MT       024       Left   fu18m      SegmIntraL
# 024_Left_fu18m_LFP_L_2A2B_STN_MT       024       Left   fu18m      SegmIntraL
# 024_Left_fu18m_LFP_L_2B2C_STN_MT       024       Left   fu18m      SegmIntraL
# 024_Left_fu18m_LFP_L_2A2C_STN_MT       024       Left   fu18m      SegmIntraL
# 024_Left_fu18m_LFP_L_1A2A_STN_MT       024       Left   fu18m      SegmInterL
# 024_Left_fu18m_LFP_L_1B2B_STN_MT       024       Left   fu18m      SegmInterL
# 024_Left_fu18m_LFP_L_1C2C_STN_MT       024       Left   fu18m      SegmInterL
# 025_Right_postop_LFP_R_12_STN_MT       025      Right  postop           RingR
# 025_Right_postop_LFP_R_01_STN_MT       025      Right  postop           RingR
# 025_Right_postop_LFP_R_23_STN_MT       025      Right  postop           RingR
# 025_Right_postop_LFP_R_1A1B_STN_MT     025      Right  postop      SegmIntraR
# 025_Right_postop_LFP_R_1B1C_STN_MT     025      Right  postop      SegmIntraR
# 025_Right_postop_LFP_R_1A1C_STN_MT     025      Right  postop      SegmIntraR
# 025_Right_postop_LFP_R_2A2B_STN_MT     025      Right  postop      SegmIntraR
# 025_Right_postop_LFP_R_2B2C_STN_MT     025      Right  postop      SegmIntraR
# 025_Right_postop_LFP_R_2A2C_STN_MT     025      Right  postop      SegmIntraR
# 025_Right_postop_LFP_R_1A2A_STN_MT     025      Right  postop      SegmInterR
# 025_Right_postop_LFP_R_1B2B_STN_MT     025      Right  postop      SegmInterR
# 025_Right_postop_LFP_R_1C2C_STN_MT     025      Right  postop      SegmInterR
# 025_Right_fu3m_LFP_R_12_STN_MT         025      Right    fu3m           RingR
# 025_Right_fu3m_LFP_R_01_STN_MT         025      Right    fu3m           RingR
# 025_Right_fu3m_LFP_R_23_STN_MT         025      Right    fu3m           RingR
# 025_Right_fu3m_LFP_R_1A1B_STN_MT       025      Right    fu3m      SegmIntraR
# 025_Right_fu3m_LFP_R_1B1C_STN_MT       025      Right    fu3m      SegmIntraR
# 025_Right_fu3m_LFP_R_1A1C_STN_MT       025      Right    fu3m      SegmIntraR
# 025_Right_fu3m_LFP_R_2A2B_STN_MT       025      Right    fu3m      SegmIntraR
# 025_Right_fu3m_LFP_R_2B2C_STN_MT       025      Right    fu3m      SegmIntraR
# 025_Right_fu3m_LFP_R_2A2C_STN_MT       025      Right    fu3m      SegmIntraR
# 025_Right_fu3m_LFP_R_1A2A_STN_MT       025      Right    fu3m      SegmInterR
# 025_Right_fu3m_LFP_R_1B2B_STN_MT       025      Right    fu3m      SegmInterR
# 025_Right_fu3m_LFP_R_1C2C_STN_MT       025      Right    fu3m      SegmInterR
# 025_Right_fu12m_LFP_R_12_STN_MT        025      Right   fu12m           RingR
# 025_Right_fu12m_LFP_R_01_STN_MT        025      Right   fu12m           RingR
# 025_Right_fu12m_LFP_R_23_STN_MT        025      Right   fu12m           RingR
# 025_Right_fu12m_LFP_R_1A1B_STN_MT      025      Right   fu12m      SegmIntraR
# 025_Right_fu12m_LFP_R_1B1C_STN_MT      025      Right   fu12m      SegmIntraR
# 025_Right_fu12m_LFP_R_1A1C_STN_MT      025      Right   fu12m      SegmIntraR
# 025_Right_fu12m_LFP_R_2A2B_STN_MT      025      Right   fu12m      SegmIntraR
# 025_Right_fu12m_LFP_R_2B2C_STN_MT      025      Right   fu12m      SegmIntraR
# 025_Right_fu12m_LFP_R_2A2C_STN_MT      025      Right   fu12m      SegmIntraR
# 025_Right_fu12m_LFP_R_1A2A_STN_MT      025      Right   fu12m      SegmInterR
# 025_Right_fu12m_LFP_R_1B2B_STN_MT      025      Right   fu12m      SegmInterR
# 025_Right_fu12m_LFP_R_1C2C_STN_MT      025      Right   fu12m      SegmInterR
# 025_Left_postop_LFP_L_12_STN_MT        025       Left  postop           RingL
# 025_Left_postop_LFP_L_01_STN_MT        025       Left  postop           RingL
# 025_Left_postop_LFP_L_23_STN_MT        025       Left  postop           RingL
# 025_Left_postop_LFP_L_1A1B_STN_MT      025       Left  postop      SegmIntraL
# 025_Left_postop_LFP_L_1B1C_STN_MT      025       Left  postop      SegmIntraL
# 025_Left_postop_LFP_L_1A1C_STN_MT      025       Left  postop      SegmIntraL
# 025_Left_postop_LFP_L_2A2B_STN_MT      025       Left  postop      SegmIntraL
# 025_Left_postop_LFP_L_2B2C_STN_MT      025       Left  postop      SegmIntraL
# 025_Left_postop_LFP_L_2A2C_STN_MT      025       Left  postop      SegmIntraL
# 025_Left_postop_LFP_L_1A2A_STN_MT      025       Left  postop      SegmInterL
# 025_Left_postop_LFP_L_1B2B_STN_MT      025       Left  postop      SegmInterL
# 025_Left_postop_LFP_L_1C2C_STN_MT      025       Left  postop      SegmInterL
# 025_Left_fu3m_LFP_L_12_STN_MT          025       Left    fu3m           RingL
# 025_Left_fu3m_LFP_L_01_STN_MT          025       Left    fu3m           RingL
# 025_Left_fu3m_LFP_L_23_STN_MT          025       Left    fu3m           RingL
# 025_Left_fu3m_LFP_L_1A1B_STN_MT        025       Left    fu3m      SegmIntraL
# 025_Left_fu3m_LFP_L_1B1C_STN_MT        025       Left    fu3m      SegmIntraL
# 025_Left_fu3m_LFP_L_1A1C_STN_MT        025       Left    fu3m      SegmIntraL
# 025_Left_fu3m_LFP_L_2A2B_STN_MT        025       Left    fu3m      SegmIntraL
# 025_Left_fu3m_LFP_L_2B2C_STN_MT        025       Left    fu3m      SegmIntraL
# 025_Left_fu3m_LFP_L_2A2C_STN_MT        025       Left    fu3m      SegmIntraL
# 025_Left_fu3m_LFP_L_1A2A_STN_MT        025       Left    fu3m      SegmInterL
# 025_Left_fu3m_LFP_L_1B2B_STN_MT        025       Left    fu3m      SegmInterL
# 025_Left_fu3m_LFP_L_1C2C_STN_MT        025       Left    fu3m      SegmInterL
# 025_Left_fu12m_LFP_L_12_STN_MT         025       Left   fu12m           RingL
# 025_Left_fu12m_LFP_L_01_STN_MT         025       Left   fu12m           RingL
# 025_Left_fu12m_LFP_L_23_STN_MT         025       Left   fu12m           RingL
# 025_Left_fu12m_LFP_L_1A1B_STN_MT       025       Left   fu12m      SegmIntraL
# 025_Left_fu12m_LFP_L_1B1C_STN_MT       025       Left   fu12m      SegmIntraL
# 025_Left_fu12m_LFP_L_1A1C_STN_MT       025       Left   fu12m      SegmIntraL
# 025_Left_fu12m_LFP_L_2A2B_STN_MT       025       Left   fu12m      SegmIntraL
# 025_Left_fu12m_LFP_L_2B2C_STN_MT       025       Left   fu12m      SegmIntraL
# 025_Left_fu12m_LFP_L_2A2C_STN_MT       025       Left   fu12m      SegmIntraL
# 025_Left_fu12m_LFP_L_1A2A_STN_MT       025       Left   fu12m      SegmInterL
# 025_Left_fu12m_LFP_L_1B2B_STN_MT       025       Left   fu12m      SegmInterL
# 025_Left_fu12m_LFP_L_1C2C_STN_MT       025       Left   fu12m      SegmInterL
# 026_Right_postop_LFP_R_12_STN_MT       026      Right  postop           RingR
# 026_Right_postop_LFP_R_01_STN_MT       026      Right  postop           RingR
# 026_Right_postop_LFP_R_23_STN_MT       026      Right  postop           RingR
# 026_Right_postop_LFP_R_1A1B_STN_MT     026      Right  postop      SegmIntraR
# 026_Right_postop_LFP_R_1B1C_STN_MT     026      Right  postop      SegmIntraR
# 026_Right_postop_LFP_R_1A1C_STN_MT     026      Right  postop      SegmIntraR
# 026_Right_postop_LFP_R_2A2B_STN_MT     026      Right  postop      SegmIntraR
# 026_Right_postop_LFP_R_2B2C_STN_MT     026      Right  postop      SegmIntraR
# 026_Right_postop_LFP_R_2A2C_STN_MT     026      Right  postop      SegmIntraR
# 026_Right_postop_LFP_R_1A2A_STN_MT     026      Right  postop      SegmInterR
# 026_Right_postop_LFP_R_1B2B_STN_MT     026      Right  postop      SegmInterR
# 026_Right_postop_LFP_R_1C2C_STN_MT     026      Right  postop      SegmInterR
# 026_Right_fu3m_LFP_R_12_STN_MT         026      Right    fu3m           RingR
# 026_Right_fu3m_LFP_R_01_STN_MT         026      Right    fu3m           RingR
# 026_Right_fu3m_LFP_R_23_STN_MT         026      Right    fu3m           RingR
# 026_Right_fu3m_LFP_R_1A1B_STN_MT       026      Right    fu3m      SegmIntraR
# 026_Right_fu3m_LFP_R_1B1C_STN_MT       026      Right    fu3m      SegmIntraR
# 026_Right_fu3m_LFP_R_1A1C_STN_MT       026      Right    fu3m      SegmIntraR
# 026_Right_fu3m_LFP_R_2A2B_STN_MT       026      Right    fu3m      SegmIntraR
# 026_Right_fu3m_LFP_R_2B2C_STN_MT       026      Right    fu3m      SegmIntraR
# 026_Right_fu3m_LFP_R_2A2C_STN_MT       026      Right    fu3m      SegmIntraR
# 026_Right_fu3m_LFP_R_1A2A_STN_MT       026      Right    fu3m      SegmInterR
# 026_Right_fu3m_LFP_R_1B2B_STN_MT       026      Right    fu3m      SegmInterR
# 026_Right_fu3m_LFP_R_1C2C_STN_MT       026      Right    fu3m      SegmInterR
# 026_Right_fu12m_LFP_R_12_STN_MT        026      Right   fu12m           RingR
# 026_Right_fu12m_LFP_R_01_STN_MT        026      Right   fu12m           RingR
# 026_Right_fu12m_LFP_R_23_STN_MT        026      Right   fu12m           RingR
# 026_Right_fu12m_LFP_R_1A1B_STN_MT      026      Right   fu12m      SegmIntraR
# 026_Right_fu12m_LFP_R_1B1C_STN_MT      026      Right   fu12m      SegmIntraR
# 026_Right_fu12m_LFP_R_1A1C_STN_MT      026      Right   fu12m      SegmIntraR
# 026_Right_fu12m_LFP_R_2A2B_STN_MT      026      Right   fu12m      SegmIntraR
# 026_Right_fu12m_LFP_R_2B2C_STN_MT      026      Right   fu12m      SegmIntraR
# 026_Right_fu12m_LFP_R_2A2C_STN_MT      026      Right   fu12m      SegmIntraR
# 026_Right_fu12m_LFP_R_1A2A_STN_MT      026      Right   fu12m      SegmInterR
# 026_Right_fu12m_LFP_R_1B2B_STN_MT      026      Right   fu12m      SegmInterR
# 026_Right_fu12m_LFP_R_1C2C_STN_MT      026      Right   fu12m      SegmInterR
# 026_Left_postop_LFP_L_12_STN_MT        026       Left  postop           RingL
# 026_Left_postop_LFP_L_01_STN_MT        026       Left  postop           RingL
# 026_Left_postop_LFP_L_23_STN_MT        026       Left  postop           RingL
# 026_Left_postop_LFP_L_1A1B_STN_MT      026       Left  postop      SegmIntraL
# 026_Left_postop_LFP_L_1B1C_STN_MT      026       Left  postop      SegmIntraL
# 026_Left_postop_LFP_L_1A1C_STN_MT      026       Left  postop      SegmIntraL
# 026_Left_postop_LFP_L_2A2B_STN_MT      026       Left  postop      SegmIntraL
# 026_Left_postop_LFP_L_2B2C_STN_MT      026       Left  postop      SegmIntraL
# 026_Left_postop_LFP_L_2A2C_STN_MT      026       Left  postop      SegmIntraL
# 026_Left_postop_LFP_L_1A2A_STN_MT      026       Left  postop      SegmInterL
# 026_Left_postop_LFP_L_1B2B_STN_MT      026       Left  postop      SegmInterL
# 026_Left_postop_LFP_L_1C2C_STN_MT      026       Left  postop      SegmInterL
# 026_Left_fu3m_LFP_L_12_STN_MT          026       Left    fu3m           RingL
# 026_Left_fu3m_LFP_L_01_STN_MT          026       Left    fu3m           RingL
# 026_Left_fu3m_LFP_L_23_STN_MT          026       Left    fu3m           RingL
# 026_Left_fu3m_LFP_L_1A1B_STN_MT        026       Left    fu3m      SegmIntraL
# 026_Left_fu3m_LFP_L_1B1C_STN_MT        026       Left    fu3m      SegmIntraL
# 026_Left_fu3m_LFP_L_1A1C_STN_MT        026       Left    fu3m      SegmIntraL
# 026_Left_fu3m_LFP_L_2A2B_STN_MT        026       Left    fu3m      SegmIntraL
# 026_Left_fu3m_LFP_L_2B2C_STN_MT        026       Left    fu3m      SegmIntraL
# 026_Left_fu3m_LFP_L_2A2C_STN_MT        026       Left    fu3m      SegmIntraL
# 026_Left_fu3m_LFP_L_1A2A_STN_MT        026       Left    fu3m      SegmInterL
# 026_Left_fu3m_LFP_L_1B2B_STN_MT        026       Left    fu3m      SegmInterL
# 026_Left_fu3m_LFP_L_1C2C_STN_MT        026       Left    fu3m      SegmInterL
# 026_Left_fu12m_LFP_L_12_STN_MT         026       Left   fu12m           RingL
# 026_Left_fu12m_LFP_L_01_STN_MT         026       Left   fu12m           RingL
# 026_Left_fu12m_LFP_L_23_STN_MT         026       Left   fu12m           RingL
# 026_Left_fu12m_LFP_L_1A1B_STN_MT       026       Left   fu12m      SegmIntraL
# 026_Left_fu12m_LFP_L_1B1C_STN_MT       026       Left   fu12m      SegmIntraL
# 026_Left_fu12m_LFP_L_1A1C_STN_MT       026       Left   fu12m      SegmIntraL
# 026_Left_fu12m_LFP_L_2A2B_STN_MT       026       Left   fu12m      SegmIntraL
# 026_Left_fu12m_LFP_L_2B2C_STN_MT       026       Left   fu12m      SegmIntraL
# 026_Left_fu12m_LFP_L_2A2C_STN_MT       026       Left   fu12m      SegmIntraL
# 026_Left_fu12m_LFP_L_1A2A_STN_MT       026       Left   fu12m      SegmInterL
# 026_Left_fu12m_LFP_L_1B2B_STN_MT       026       Left   fu12m      SegmInterL
# 026_Left_fu12m_LFP_L_1C2C_STN_MT       026       Left   fu12m      SegmInterL
# 028_Right_postop_LFP_R_12_STN_MT       028      Right  postop           RingR
# 028_Right_postop_LFP_R_01_STN_MT       028      Right  postop           RingR
# 028_Right_postop_LFP_R_23_STN_MT       028      Right  postop           RingR
# 028_Right_postop_LFP_R_1A1B_STN_MT     028      Right  postop      SegmIntraR
# 028_Right_postop_LFP_R_1B1C_STN_MT     028      Right  postop      SegmIntraR
# 028_Right_postop_LFP_R_1A1C_STN_MT     028      Right  postop      SegmIntraR
# 028_Right_postop_LFP_R_2A2B_STN_MT     028      Right  postop      SegmIntraR
# 028_Right_postop_LFP_R_2B2C_STN_MT     028      Right  postop      SegmIntraR
# 028_Right_postop_LFP_R_2A2C_STN_MT     028      Right  postop      SegmIntraR
# 028_Right_postop_LFP_R_1A2A_STN_MT     028      Right  postop      SegmInterR
# 028_Right_postop_LFP_R_1B2B_STN_MT     028      Right  postop      SegmInterR
# 028_Right_postop_LFP_R_1C2C_STN_MT     028      Right  postop      SegmInterR
# 028_Right_fu12m_LFP_R_12_STN_MT        028      Right   fu12m           RingR
# 028_Right_fu12m_LFP_R_01_STN_MT        028      Right   fu12m           RingR
# 028_Right_fu12m_LFP_R_23_STN_MT        028      Right   fu12m           RingR
# 028_Right_fu12m_LFP_R_1A1B_STN_MT      028      Right   fu12m      SegmIntraR
# 028_Right_fu12m_LFP_R_1B1C_STN_MT      028      Right   fu12m      SegmIntraR
# 028_Right_fu12m_LFP_R_1A1C_STN_MT      028      Right   fu12m      SegmIntraR
# 028_Right_fu12m_LFP_R_2A2B_STN_MT      028      Right   fu12m      SegmIntraR
# 028_Right_fu12m_LFP_R_2B2C_STN_MT      028      Right   fu12m      SegmIntraR
# 028_Right_fu12m_LFP_R_2A2C_STN_MT      028      Right   fu12m      SegmIntraR
# 028_Right_fu12m_LFP_R_1A2A_STN_MT      028      Right   fu12m      SegmInterR
# 028_Right_fu12m_LFP_R_1B2B_STN_MT      028      Right   fu12m      SegmInterR
# 028_Right_fu12m_LFP_R_1C2C_STN_MT      028      Right   fu12m      SegmInterR
# 028_Left_postop_LFP_L_12_STN_MT        028       Left  postop           RingL
# 028_Left_postop_LFP_L_01_STN_MT        028       Left  postop           RingL
# 028_Left_postop_LFP_L_23_STN_MT        028       Left  postop           RingL
# 028_Left_postop_LFP_L_1A1B_STN_MT      028       Left  postop      SegmIntraL
# 028_Left_postop_LFP_L_1B1C_STN_MT      028       Left  postop      SegmIntraL
# 028_Left_postop_LFP_L_1A1C_STN_MT      028       Left  postop      SegmIntraL
# 028_Left_postop_LFP_L_2A2B_STN_MT      028       Left  postop      SegmIntraL
# 028_Left_postop_LFP_L_2B2C_STN_MT      028       Left  postop      SegmIntraL
# 028_Left_postop_LFP_L_2A2C_STN_MT      028       Left  postop      SegmIntraL
# 028_Left_postop_LFP_L_1A2A_STN_MT      028       Left  postop      SegmInterL
# 028_Left_postop_LFP_L_1B2B_STN_MT      028       Left  postop      SegmInterL
# 028_Left_postop_LFP_L_1C2C_STN_MT      028       Left  postop      SegmInterL
# 028_Left_fu12m_LFP_L_12_STN_MT         028       Left   fu12m           RingL
# 028_Left_fu12m_LFP_L_01_STN_MT         028       Left   fu12m           RingL
# 028_Left_fu12m_LFP_L_23_STN_MT         028       Left   fu12m           RingL
# 028_Left_fu12m_LFP_L_1A1B_STN_MT       028       Left   fu12m      SegmIntraL
# 028_Left_fu12m_LFP_L_1B1C_STN_MT       028       Left   fu12m      SegmIntraL
# 028_Left_fu12m_LFP_L_1A1C_STN_MT       028       Left   fu12m      SegmIntraL
# 028_Left_fu12m_LFP_L_2A2B_STN_MT       028       Left   fu12m      SegmIntraL
# 028_Left_fu12m_LFP_L_2B2C_STN_MT       028       Left   fu12m      SegmIntraL
# 028_Left_fu12m_LFP_L_2A2C_STN_MT       028       Left   fu12m      SegmIntraL
# 028_Left_fu12m_LFP_L_1A2A_STN_MT       028       Left   fu12m      SegmInterL
# 028_Left_fu12m_LFP_L_1B2B_STN_MT       028       Left   fu12m      SegmInterL
# 028_Left_fu12m_LFP_L_1C2C_STN_MT       028       Left   fu12m      SegmInterL
# 029_Right_postop_LFP_R_12_STN_MT       029      Right  postop           RingR
# 029_Right_postop_LFP_R_01_STN_MT       029      Right  postop           RingR
# 029_Right_postop_LFP_R_23_STN_MT       029      Right  postop           RingR
# 029_Right_postop_LFP_R_1A1B_STN_MT     029      Right  postop      SegmIntraR
# 029_Right_postop_LFP_R_1B1C_STN_MT     029      Right  postop      SegmIntraR
# 029_Right_postop_LFP_R_1A1C_STN_MT     029      Right  postop      SegmIntraR
# 029_Right_postop_LFP_R_2A2B_STN_MT     029      Right  postop      SegmIntraR
# 029_Right_postop_LFP_R_2B2C_STN_MT     029      Right  postop      SegmIntraR
# 029_Right_postop_LFP_R_2A2C_STN_MT     029      Right  postop      SegmIntraR
# 029_Right_postop_LFP_R_1A2A_STN_MT     029      Right  postop      SegmInterR
# 029_Right_postop_LFP_R_1B2B_STN_MT     029      Right  postop      SegmInterR
# 029_Right_postop_LFP_R_1C2C_STN_MT     029      Right  postop      SegmInterR
# 029_Right_fu3m_LFP_R_12_STN_MT         029      Right    fu3m           RingR
# 029_Right_fu3m_LFP_R_01_STN_MT         029      Right    fu3m           RingR
# 029_Right_fu3m_LFP_R_23_STN_MT         029      Right    fu3m           RingR
# 029_Right_fu3m_LFP_R_1A1B_STN_MT       029      Right    fu3m      SegmIntraR
# 029_Right_fu3m_LFP_R_1B1C_STN_MT       029      Right    fu3m      SegmIntraR
# 029_Right_fu3m_LFP_R_1A1C_STN_MT       029      Right    fu3m      SegmIntraR
# 029_Right_fu3m_LFP_R_2A2B_STN_MT       029      Right    fu3m      SegmIntraR
# 029_Right_fu3m_LFP_R_2B2C_STN_MT       029      Right    fu3m      SegmIntraR
# 029_Right_fu3m_LFP_R_2A2C_STN_MT       029      Right    fu3m      SegmIntraR
# 029_Right_fu3m_LFP_R_1A2A_STN_MT       029      Right    fu3m      SegmInterR
# 029_Right_fu3m_LFP_R_1B2B_STN_MT       029      Right    fu3m      SegmInterR
# 029_Right_fu3m_LFP_R_1C2C_STN_MT       029      Right    fu3m      SegmInterR
# 029_Right_fu12m_LFP_R_12_STN_MT        029      Right   fu12m           RingR
# 029_Right_fu12m_LFP_R_01_STN_MT        029      Right   fu12m           RingR
# 029_Right_fu12m_LFP_R_23_STN_MT        029      Right   fu12m           RingR
# 029_Right_fu12m_LFP_R_1A1B_STN_MT      029      Right   fu12m      SegmIntraR
# 029_Right_fu12m_LFP_R_1B1C_STN_MT      029      Right   fu12m      SegmIntraR
# 029_Right_fu12m_LFP_R_1A1C_STN_MT      029      Right   fu12m      SegmIntraR
# 029_Right_fu12m_LFP_R_2A2B_STN_MT      029      Right   fu12m      SegmIntraR
# 029_Right_fu12m_LFP_R_2B2C_STN_MT      029      Right   fu12m      SegmIntraR
# 029_Right_fu12m_LFP_R_2A2C_STN_MT      029      Right   fu12m      SegmIntraR
# 029_Right_fu12m_LFP_R_1A2A_STN_MT      029      Right   fu12m      SegmInterR
# 029_Right_fu12m_LFP_R_1B2B_STN_MT      029      Right   fu12m      SegmInterR
# 029_Right_fu12m_LFP_R_1C2C_STN_MT      029      Right   fu12m      SegmInterR
# 029_Right_fu18m_LFP_R_12_STN_MT        029      Right   fu18m           RingR
# 029_Right_fu18m_LFP_R_01_STN_MT        029      Right   fu18m           RingR
# 029_Right_fu18m_LFP_R_23_STN_MT        029      Right   fu18m           RingR
# 029_Right_fu18m_LFP_R_1A1B_STN_MT      029      Right   fu18m      SegmIntraR
# 029_Right_fu18m_LFP_R_1B1C_STN_MT      029      Right   fu18m      SegmIntraR
# 029_Right_fu18m_LFP_R_1A1C_STN_MT      029      Right   fu18m      SegmIntraR
# 029_Right_fu18m_LFP_R_2A2B_STN_MT      029      Right   fu18m      SegmIntraR
# 029_Right_fu18m_LFP_R_2B2C_STN_MT      029      Right   fu18m      SegmIntraR
# 029_Right_fu18m_LFP_R_2A2C_STN_MT      029      Right   fu18m      SegmIntraR
# 029_Right_fu18m_LFP_R_1A2A_STN_MT      029      Right   fu18m      SegmInterR
# 029_Right_fu18m_LFP_R_1B2B_STN_MT      029      Right   fu18m      SegmInterR
# 029_Right_fu18m_LFP_R_1C2C_STN_MT      029      Right   fu18m      SegmInterR
# 029_Left_postop_LFP_L_12_STN_MT        029       Left  postop           RingL
# 029_Left_postop_LFP_L_01_STN_MT        029       Left  postop           RingL
# 029_Left_postop_LFP_L_23_STN_MT        029       Left  postop           RingL
# 029_Left_postop_LFP_L_1A1B_STN_MT      029       Left  postop      SegmIntraL
# 029_Left_postop_LFP_L_1B1C_STN_MT      029       Left  postop      SegmIntraL
# 029_Left_postop_LFP_L_1A1C_STN_MT      029       Left  postop      SegmIntraL
# 029_Left_postop_LFP_L_2A2B_STN_MT      029       Left  postop      SegmIntraL
# 029_Left_postop_LFP_L_2B2C_STN_MT      029       Left  postop      SegmIntraL
# 029_Left_postop_LFP_L_2A2C_STN_MT      029       Left  postop      SegmIntraL
# 029_Left_postop_LFP_L_1A2A_STN_MT      029       Left  postop      SegmInterL
# 029_Left_postop_LFP_L_1B2B_STN_MT      029       Left  postop      SegmInterL
# 029_Left_postop_LFP_L_1C2C_STN_MT      029       Left  postop      SegmInterL
# 029_Left_fu3m_LFP_L_12_STN_MT          029       Left    fu3m           RingL
# 029_Left_fu3m_LFP_L_01_STN_MT          029       Left    fu3m           RingL
# 029_Left_fu3m_LFP_L_23_STN_MT          029       Left    fu3m           RingL
# 029_Left_fu3m_LFP_L_1A1B_STN_MT        029       Left    fu3m      SegmIntraL
# 029_Left_fu3m_LFP_L_1B1C_STN_MT        029       Left    fu3m      SegmIntraL
# 029_Left_fu3m_LFP_L_1A1C_STN_MT        029       Left    fu3m      SegmIntraL
# 029_Left_fu3m_LFP_L_2A2B_STN_MT        029       Left    fu3m      SegmIntraL
# 029_Left_fu3m_LFP_L_2B2C_STN_MT        029       Left    fu3m      SegmIntraL
# 029_Left_fu3m_LFP_L_2A2C_STN_MT        029       Left    fu3m      SegmIntraL
# 030_Right_postop_LFP_R_2A2C_STN_MT     030      Right  postop      SegmIntraR
# 030_Right_postop_LFP_R_1A2A_STN_MT     030      Right  postop      SegmInterR
# 030_Right_postop_LFP_R_1B2B_STN_MT     030      Right  postop      SegmInterR
# 030_Right_postop_LFP_R_1C2C_STN_MT     030      Right  postop      SegmInterR
# 030_Right_fu3m_LFP_R_12_STN_MT         030      Right    fu3m           RingR
# 030_Right_fu3m_LFP_R_01_STN_MT         030      Right    fu3m           RingR
# 030_Right_fu3m_LFP_R_23_STN_MT         030      Right    fu3m           RingR
# ...
# 030_Right_fu12m_LFP_R_23_STN_MT           -1.0    0.396483
# 030_Right_fu12m_LFP_R_1A1B_STN_MT     0.363385    0.598108
# 030_Right_fu12m_LFP_R_1B1C_STN_MT    -0.293023    0.563399
# 030_Right_fu12m_LFP_R_1A1C_STN_MT     -0.00396    0.502307
# 030_Right_fu12m_LFP_R_2A2B_STN_MT     0.694438    0.497806
# 030_Right_fu12m_LFP_R_2B2C_STN_MT         -1.0    0.467445
# 030_Right_fu12m_LFP_R_2A2C_STN_MT     0.555306    0.442535
# 030_Right_fu12m_LFP_R_1A2A_STN_MT    -0.200867     0.51553
# 030_Right_fu12m_LFP_R_1B2B_STN_MT    -0.404195    0.496465
# 030_Right_fu12m_LFP_R_1C2C_STN_MT          1.0    0.435586
# 030_Left_postop_LFP_L_12_STN_MT            1.0    0.663921
# 030_Left_postop_LFP_L_01_STN_MT       -0.22024    0.437146
# 030_Left_postop_LFP_L_23_STN_MT       0.082399    0.307669
# 030_Left_postop_LFP_L_1A1B_STN_MT     0.322582     0.69318
# 030_Left_postop_LFP_L_1B1C_STN_MT    -0.488348    0.573236
# 030_Left_postop_LFP_L_1A1C_STN_MT    -0.294043     0.54741
# 030_Left_postop_LFP_L_2A2B_STN_MT      0.68442    0.522026
# 030_Left_postop_LFP_L_2B2C_STN_MT         -1.0    0.484912
# 030_Left_postop_LFP_L_2A2C_STN_MT    -0.292198    0.298206
# 030_Left_postop_LFP_L_1A2A_STN_MT     0.128988    0.759907
# 030_Left_postop_LFP_L_1B2B_STN_MT     0.970873    0.621393
# 030_Left_postop_LFP_L_1C2C_STN_MT          1.0    0.225359
# 030_Left_fu3m_LFP_L_12_STN_MT              1.0    0.658149
# 030_Left_fu3m_LFP_L_01_STN_MT        -0.137244    0.438163
# 030_Left_fu3m_LFP_L_23_STN_MT        -0.214039    0.392576
# 030_Left_fu3m_LFP_L_1A1B_STN_MT       0.484429    0.694068
# 030_Left_fu3m_LFP_L_1B1C_STN_MT       0.443904    0.632391
# 030_Left_fu3m_LFP_L_1A1C_STN_MT       0.870664    0.584975
# 030_Left_fu3m_LFP_L_2A2B_STN_MT           -1.0    0.565063
# 030_Left_fu3m_LFP_L_2B2C_STN_MT       0.196908    0.520458
# 030_Left_fu3m_LFP_L_2A2C_STN_MT      -0.681646    0.447659
# 030_Left_fu3m_LFP_L_1A2A_STN_MT       0.140152    0.710214
# 030_Left_fu3m_LFP_L_1B2B_STN_MT            1.0     0.54599
# 030_Left_fu3m_LFP_L_1C2C_STN_MT       0.983545    0.486143
# 030_Left_fu12m_LFP_L_12_STN_MT             1.0    0.545238
# 030_Left_fu12m_LFP_L_01_STN_MT       -0.130345    0.528609
# 030_Left_fu12m_LFP_L_23_STN_MT        0.307705     0.37718
# 030_Left_fu12m_LFP_L_1A1B_STN_MT     -0.223738    0.613209
# 030_Left_fu12m_LFP_L_1B1C_STN_MT     -0.082488    0.599262
# 030_Left_fu12m_LFP_L_1A1C_STN_MT      0.493981    0.535787
# 030_Left_fu12m_LFP_L_2A2B_STN_MT      0.039332    0.527171
# 030_Left_fu12m_LFP_L_2B2C_STN_MT          -1.0    0.450675
# 030_Left_fu12m_LFP_L_2A2C_STN_MT      0.131135    0.398734
# 030_Left_fu12m_LFP_L_1A2A_STN_MT      0.137334    0.563095
# 030_Left_fu12m_LFP_L_1B2B_STN_MT      0.763235    0.494416
# 030_Left_fu12m_LFP_L_1C2C_STN_MT           1.0    0.451857
# 031_Right_postop_LFP_R_12_STN_MT      0.228397     0.62465
# 031_Right_postop_LFP_R_01_STN_MT     -0.425876    0.477051
# 031_Right_postop_LFP_R_23_STN_MT           1.0     0.42199
# 031_Right_postop_LFP_R_1A1B_STN_MT    0.435885    0.675915
# 031_Right_postop_LFP_R_1B1C_STN_MT   -0.131205    0.571018
# 031_Right_postop_LFP_R_1A1C_STN_MT    0.422765    0.553508
# 031_Right_postop_LFP_R_2A2B_STN_MT    0.596989    0.492952
# 031_Right_postop_LFP_R_2B2C_STN_MT        -1.0    0.433512
# 031_Right_postop_LFP_R_2A2C_STN_MT   -0.426641    0.313019
# 031_Right_postop_LFP_R_1A2A_STN_MT    0.405841    0.584053
# 031_Right_postop_LFP_R_1B2B_STN_MT         1.0    0.491124
# 031_Right_postop_LFP_R_1C2C_STN_MT     0.46451    0.451739
# 031_Right_fu3m_LFP_R_12_STN_MT             1.0    0.618054
# 031_Right_fu3m_LFP_R_01_STN_MT       -0.521249    0.560703
# 031_Right_fu3m_LFP_R_23_STN_MT       -0.186511    0.481643
# 031_Right_fu3m_LFP_R_1A1B_STN_MT       -0.1907    0.702142
# 031_Right_fu3m_LFP_R_1B1C_STN_MT     -0.685219    0.612546
# 031_Right_fu3m_LFP_R_1A1C_STN_MT          -1.0     0.54493
# 031_Right_fu3m_LFP_R_2A2B_STN_MT     -0.333032     0.53787
# 031_Right_fu3m_LFP_R_2B2C_STN_MT      0.990434    0.443886
# 031_Right_fu3m_LFP_R_2A2C_STN_MT      0.599748    0.378116
# 031_Right_fu3m_LFP_R_1A2A_STN_MT      0.325665    0.731958
# 031_Right_fu3m_LFP_R_1B2B_STN_MT      0.400426    0.489278
# 031_Right_fu3m_LFP_R_1C2C_STN_MT           1.0    0.363826
# 031_Left_postop_LFP_L_12_STN_MT            1.0    0.568301
# 031_Left_postop_LFP_L_01_STN_MT       0.353741    0.503596
# 031_Left_postop_LFP_L_23_STN_MT      -0.328103    0.425284
# 031_Left_postop_LFP_L_1A1B_STN_MT     0.460731    0.606094
# 031_Left_postop_LFP_L_1B1C_STN_MT    -0.446606     0.59175
# 031_Left_postop_LFP_L_1A1C_STN_MT     0.845728    0.528084
# 031_Left_postop_LFP_L_2A2B_STN_MT         -1.0    0.479371
# 031_Left_postop_LFP_L_2B2C_STN_MT    -0.648332    0.463194
# 031_Left_postop_LFP_L_2A2C_STN_MT     0.575429    0.419812
# 031_Left_postop_LFP_L_1A2A_STN_MT     0.456549    0.690519
# 031_Left_postop_LFP_L_1B2B_STN_MT          1.0    0.540742
# 031_Left_postop_LFP_L_1C2C_STN_MT     0.963493    0.437384
# 031_Left_fu3m_LFP_L_12_STN_MT              1.0     0.72794
# 031_Left_fu3m_LFP_L_01_STN_MT        -0.022203    0.567532
# 031_Left_fu3m_LFP_L_23_STN_MT        -0.506351    0.438205
# 031_Left_fu3m_LFP_L_1A1B_STN_MT       0.838114    0.755071
# 031_Left_fu3m_LFP_L_1B1C_STN_MT      -0.375861    0.617425
# 031_Left_fu3m_LFP_L_1A1C_STN_MT       0.471045    0.587919
# 031_Left_fu3m_LFP_L_2A2B_STN_MT           -1.0    0.566407
# 031_Left_fu3m_LFP_L_2B2C_STN_MT       0.295383    0.467382
# 031_Left_fu3m_LFP_L_2A2C_STN_MT      -0.721913    0.426066
# 031_Left_fu3m_LFP_L_1A2A_STN_MT       0.280448    0.823217
# 031_Left_fu3m_LFP_L_1B2B_STN_MT            1.0    0.563338
# 031_Left_fu3m_LFP_L_1C2C_STN_MT       0.664472    0.491079
# 032_Right_postop_LFP_R_12_STN_MT      0.395571    0.528255
# 032_Right_postop_LFP_R_01_STN_MT      0.968747    0.494657
# 032_Right_postop_LFP_R_23_STN_MT          -1.0    0.395241
# 032_Right_postop_LFP_R_1A1B_STN_MT    0.844215    0.592607
# 032_Right_postop_LFP_R_1B1C_STN_MT     0.47763    0.562079
# 032_Right_postop_LFP_R_1A1C_STN_MT   -0.393267    0.507987
# 032_Right_postop_LFP_R_2A2B_STN_MT         1.0     0.46257
# 032_Right_postop_LFP_R_2B2C_STN_MT   -0.008434    0.458847
# 032_Right_postop_LFP_R_2A2C_STN_MT   -0.642799    0.394116
# 032_Right_postop_LFP_R_1A2A_STN_MT   -0.012129    0.578358
# 032_Right_postop_LFP_R_1B2B_STN_MT         1.0    0.522367
# 032_Right_postop_LFP_R_1C2C_STN_MT    0.348469     0.48911
# 032_Right_fu3m_LFP_R_12_STN_MT        0.376561    0.809769
# 032_Right_fu3m_LFP_R_01_STN_MT       -0.699951     0.69045
# 032_Right_fu3m_LFP_R_23_STN_MT             1.0    0.513145
# 032_Right_fu3m_LFP_R_1A1B_STN_MT     -0.083119    0.875168
# 032_Right_fu3m_LFP_R_1B1C_STN_MT      0.730513    0.785179
# 032_Right_fu3m_LFP_R_1A1C_STN_MT      0.655303    0.737664
# 032_Right_fu3m_LFP_R_2A2B_STN_MT      0.514642    0.583242
# 032_Right_fu3m_LFP_R_2B2C_STN_MT      0.492536     0.57461
# 032_Right_fu3m_LFP_R_2A2C_STN_MT           1.0    0.565674
# 032_Right_fu3m_LFP_R_1A2A_STN_MT      0.389792    0.793081
# 032_Right_fu3m_LFP_R_1B2B_STN_MT           1.0    0.589601
# 032_Right_fu3m_LFP_R_1C2C_STN_MT      0.856846    0.506514
# 032_Left_postop_LFP_L_12_STN_MT            1.0    0.612042
# 032_Left_postop_LFP_L_01_STN_MT      -0.595709    0.471841
# 032_Left_postop_LFP_L_23_STN_MT       0.629616    0.387649
# 032_Left_postop_LFP_L_1A1B_STN_MT     0.278608    0.718251
# 032_Left_postop_LFP_L_1B1C_STN_MT    -0.028526    0.594242
# 032_Left_postop_LFP_L_1A1C_STN_MT     0.260213    0.539092
# 032_Left_postop_LFP_L_2A2B_STN_MT     0.455227    0.495625
# 032_Left_postop_LFP_L_2B2C_STN_MT         -1.0    0.456617
# 032_Left_postop_LFP_L_2A2C_STN_MT    -0.642478    0.424951
# 032_Left_postop_LFP_L_1A2A_STN_MT     0.465068    0.600745
# 032_Left_postop_LFP_L_1B2B_STN_MT     0.314411    0.486001
# 032_Left_postop_LFP_L_1C2C_STN_MT          1.0    0.455753
# 032_Left_fu3m_LFP_L_12_STN_MT          0.39138    0.811726
# 032_Left_fu3m_LFP_L_01_STN_MT        -0.317882    0.728896
# 032_Left_fu3m_LFP_L_23_STN_MT              1.0    0.426271
# 032_Left_fu3m_LFP_L_1A1B_STN_MT       0.583697    0.747417
# 032_Left_fu3m_LFP_L_1B1C_STN_MT      -0.425147    0.633393
# 032_Left_fu3m_LFP_L_1A1C_STN_MT       0.171559    0.617028
# 032_Left_fu3m_LFP_L_2A2B_STN_MT       0.781657    0.577255
# 032_Left_fu3m_LFP_L_2B2C_STN_MT       0.308981    0.574939
# 032_Left_fu3m_LFP_L_2A2C_STN_MT            1.0    0.500898
# 032_Left_fu3m_LFP_L_1A2A_STN_MT       0.378727    0.751271
# 032_Left_fu3m_LFP_L_1B2B_STN_MT       0.653057    0.667738
# 032_Left_fu3m_LFP_L_1C2C_STN_MT            1.0    0.574002
# 033_Right_fu3m_LFP_R_12_STN_MT             1.0    0.665946
# 033_Right_fu3m_LFP_R_01_STN_MT       -0.560325    0.559466
# 033_Right_fu3m_LFP_R_23_STN_MT        0.744681    0.444343
# 033_Right_fu3m_LFP_R_1A1B_STN_MT      0.701974    0.738888
# 033_Right_fu3m_LFP_R_1B1C_STN_MT          -1.0    0.617335
# 033_Right_fu3m_LFP_R_1A1C_STN_MT     -0.227796    0.565357
# 033_Right_fu3m_LFP_R_2A2B_STN_MT      0.189888    0.556141
# 033_Right_fu3m_LFP_R_2B2C_STN_MT      -0.40133    0.525051
# 033_Right_fu3m_LFP_R_2A2C_STN_MT     -0.256791    0.490616
# 033_Right_fu3m_LFP_R_1A2A_STN_MT        0.3669    0.710518
# 033_Right_fu3m_LFP_R_1B2B_STN_MT           1.0    0.567033
# 033_Right_fu3m_LFP_R_1C2C_STN_MT      0.452375    0.503956
# 033_Right_fu12m_LFP_R_12_STN_MT       0.608087    0.714831
# 033_Right_fu12m_LFP_R_01_STN_MT      -0.496805    0.576278
# 033_Right_fu12m_LFP_R_23_STN_MT            1.0    0.444175
# 033_Right_fu12m_LFP_R_1A1B_STN_MT     0.552993    0.696877
# 033_Right_fu12m_LFP_R_1B1C_STN_MT      -0.7585    0.603417
# 033_Right_fu12m_LFP_R_1A1C_STN_MT    -0.184506    0.598727
# 033_Right_fu12m_LFP_R_2A2B_STN_MT     0.837236    0.552985
# 033_Right_fu12m_LFP_R_2B2C_STN_MT         -1.0    0.504681
# 033_Right_fu12m_LFP_R_2A2C_STN_MT    -0.168001    0.472005
# 033_Right_fu12m_LFP_R_1A2A_STN_MT     0.634843     0.63259
# 033_Right_fu12m_LFP_R_1B2B_STN_MT          1.0    0.585138
# 033_Right_fu12m_LFP_R_1C2C_STN_MT     0.776017    0.458796
# 033_Right_fu18m_LFP_R_12_STN_MT       0.316941    0.663017
# 033_Right_fu18m_LFP_R_01_STN_MT      -0.171092    0.558343
# 033_Right_fu18m_LFP_R_23_STN_MT            1.0    0.436928
# 033_Right_fu18m_LFP_R_1A1B_STN_MT    -0.524304    0.626109
# 033_Right_fu18m_LFP_R_1B1C_STN_MT     0.457609    0.617006
# 033_Right_fu18m_LFP_R_1A1C_STN_MT    -0.303731    0.590434
# 033_Right_fu18m_LFP_R_2A2B_STN_MT    -0.806436    0.519829
# 033_Right_fu18m_LFP_R_2B2C_STN_MT          1.0    0.487013
# 033_Right_fu18m_LFP_R_2A2C_STN_MT    -0.021884    0.436921
# 033_Right_fu18m_LFP_R_1A2A_STN_MT     0.676109    0.563844
# 033_Right_fu18m_LFP_R_1B2B_STN_MT          1.0     0.52303
# 033_Right_fu18m_LFP_R_1C2C_STN_MT     0.852417    0.458248
# 033_Left_fu3m_LFP_L_12_STN_MT             -1.0      0.6851
# 033_Left_fu3m_LFP_L_01_STN_MT         0.781221    0.541185
# 033_Left_fu3m_LFP_L_23_STN_MT         -0.47016     0.48291
# 033_Left_fu3m_LFP_L_1A1B_STN_MT       0.968821    0.710743
# 033_Left_fu3m_LFP_L_1B1C_STN_MT           -1.0    0.608689
# 033_Left_fu3m_LFP_L_1A1C_STN_MT       -0.05299    0.580617
# 033_Left_fu3m_LFP_L_2A2B_STN_MT      -0.846281    0.560847
# 033_Left_fu3m_LFP_L_2B2C_STN_MT       0.669659    0.505177
# 033_Left_fu3m_LFP_L_2A2C_STN_MT      -0.151655    0.412425
# 033_Left_fu3m_LFP_L_1A2A_STN_MT            1.0    0.712095
# 033_Left_fu3m_LFP_L_1B2B_STN_MT       0.648247    0.614358
# 033_Left_fu3m_LFP_L_1C2C_STN_MT       0.953193     0.46894
# 033_Left_fu12m_LFP_L_12_STN_MT             1.0    0.696604
# 033_Left_fu12m_LFP_L_01_STN_MT       -0.573282    0.549558
# 033_Left_fu12m_LFP_L_23_STN_MT        0.299322    0.459638
# 033_Left_fu12m_LFP_L_1A1B_STN_MT      0.776243    0.619426
# 033_Left_fu12m_LFP_L_1B1C_STN_MT          -1.0    0.568284
# 033_Left_fu12m_LFP_L_1A1C_STN_MT     -0.314005    0.534764
# 038_Right_fu3m_LFP_R_1C2C_STN_MT           1.0     0.44913
# 038_Left_postop_LFP_L_12_STN_MT            1.0    0.694312
# 038_Left_postop_LFP_L_01_STN_MT        -0.8212    0.665031
# 038_Left_postop_LFP_L_23_STN_MT       0.198642    0.451565
# 038_Left_postop_LFP_L_1A1B_STN_MT     0.581703      0.7461
# 038_Left_postop_LFP_L_1B1C_STN_MT     0.423256    0.676518
# 038_Left_postop_LFP_L_1A1C_STN_MT          1.0    0.652871
# 038_Left_postop_LFP_L_2A2B_STN_MT     0.183976    0.594013
# 038_Left_postop_LFP_L_2B2C_STN_MT     -0.12187    0.536974
# 038_Left_postop_LFP_L_2A2C_STN_MT     0.061628    0.463278
# 038_Left_postop_LFP_L_1A2A_STN_MT     0.672883    0.721205
# 038_Left_postop_LFP_L_1B2B_STN_MT          1.0    0.639011
# 038_Left_postop_LFP_L_1C2C_STN_MT     0.645654    0.550131
# 038_Left_fu3m_LFP_L_12_STN_MT             -1.0    0.727177
# 038_Left_fu3m_LFP_L_01_STN_MT          0.60866    0.629399
# 038_Left_fu3m_LFP_L_23_STN_MT        -0.010338    0.516469
# 038_Left_fu3m_LFP_L_1A1B_STN_MT            1.0    0.737064
# 038_Left_fu3m_LFP_L_1B1C_STN_MT      -0.420709    0.674303
# 038_Left_fu3m_LFP_L_1A1C_STN_MT       0.564036      0.6123
# 038_Left_fu3m_LFP_L_2A2B_STN_MT       0.084141    0.608801
# 038_Left_fu3m_LFP_L_2B2C_STN_MT       0.118213    0.588517
# 038_Left_fu3m_LFP_L_2A2C_STN_MT       0.185329    0.548523
# 038_Left_fu3m_LFP_L_1A2A_STN_MT       0.405986    0.750579
# 038_Left_fu3m_LFP_L_1B2B_STN_MT            1.0    0.707112
# 038_Left_fu3m_LFP_L_1C2C_STN_MT       0.642355    0.593812

# %%
# load the PSD data with classes
incl_sub = ["017", "019", "021", "024", "025", "026", "028", "029", "030", "031", "032", "033", "038"]
hemisphere =["Right", "Left"]
signalFilter="unfiltered"
incl_session=["postop", "fu3m", "fu12m", "fu18m"]
incl_cond=["m0s0"]
Ring = ['BIP_03', 'BIP_02', 'BIP_13', 'BIP_12', 'BIP_01', 'BIP_23']
SegmIntra = ['BIP_1A1B', 'BIP_1B1C', 'BIP_1A1C', 'BIP_2A2B', 'BIP_2B2C', 'BIP_2A2C']
SegmInter = ['BIP_1A2A', 'BIP_1B2B', 'BIP_1C2C']

f_range = 13, 35

incl_contact={}
rec_group_input_array={}
SSD_results_storage = {}

for sub in incl_sub:

    sub_results_path = find_folders.get_local_path(folder="figures", sub=sub) 

    for hem in hemisphere:
        if hem == "Right":
            incl_contact["Right"] = ["RingR", "SegmIntraR", "SegmInterR"]

        elif hem == "Left":
            incl_contact["Left"] = ["RingL", "SegmIntraL", "SegmInterL"]

        mainclass_sub = main_class.PerceiveData(
            sub = sub, 
            incl_modalities= ["survey"],
            incl_session = incl_session,
            incl_condition = incl_cond,
            incl_task = ["rest"],
            incl_contact=incl_contact[f"{hem}"]
            )

        for ses in incl_session:
            for cond in incl_cond:
                for recording_group in incl_contact[f"{hem}"]:

                    # check if session exists 
                    try: 
                        getattr(mainclass_sub.survey, ses)
                    except AttributeError:
                        continue

                    timedomain_data = getattr(mainclass_sub.survey, ses)
                    

                    # check if condition exists
                    try:
                        getattr(timedomain_data, cond)
                    except AttributeError:
                        continue

                    timedomain_data = getattr(timedomain_data, cond)
                    timedomain_data = getattr(timedomain_data.rest, recording_group) # for each rec group in incl_contact
                    timedomain_data = timedomain_data.run1.data

                    ch_names = timedomain_data.ch_names
                    sfreq = timedomain_data.info["sfreq"]

                    rec_group_data = timedomain_data.get_data() # 2D array of all rec channels in a rec group
                    rec_group_input_array[f"{sub}_{hem}_{ses}_{cond}_{recording_group}"] = rec_group_data


                    # fig, axes = plt.subplots(2, 1, figsize=(10,15))
                    
                    # # plot the PSD channels in a recording group
                    # for c, chan in enumerate(ch_names):

                    #     f_raw, psd_raw = signal.welch(rec_group_data[c], axis=-1, nperseg=sfreq, fs=sfreq) 

                    #     axes[0].plot(f_raw, psd_raw, label=chan)        
                    #     axes[0].set_title(f'Power Spectra {recording_group}: sub{sub} {hem} hemisphere, {ses}')
                    #     axes[0].set_xlim(0, 100) 
                    #     axes[0].set_xlabel("Frequency")
                    #     axes[0].set_ylabel("PSD [uV^2/Hz]")
                    #     axes[0].axvline(x=13, color='black', linestyle='--')
                    #     axes[0].axvline(x=35, color='black', linestyle='--')
                    #     axes[0].legend()


                    # apply SSD filter on time domain of each recording group
                    (ssd_filt_data, ssd_pattern, ssd_eigvals 
                                ) = feats_ssd.get_SSD_component( 
                                    data_2d=rec_group_data, 
                                    fband_interest=f_range, 
                                    s_rate=sfreq, 
                                    use_freqBand_filtered=True, 
                                    return_comp_n=0, ) 
                    
                    # store SSD outcome in Dataframe
                    for c, chan in enumerate(ch_names):
                        SSD_results_storage[f"{sub}_{hem}_{ses}_{chan}"] = [sub, hem, ses, recording_group, chan, ssd_filt_data, ssd_pattern[0][c], ssd_eigvals[c]]

                    # use Welch to transform the time domain data to frequency domain data            
                    f, psd = signal.welch(ssd_filt_data, axis=-1, nperseg=sfreq, fs=sfreq) # ssd_filt_data is only one array with the PSD of the FIRST component
                    

                    # plot the first component Power spectrum of each recording group
                    # axes[1].plot(f, psd) 
                                
                    # axes[1].set_xlim(0, 100)   
                    # axes[1].set_xlabel("Frequency")
                    # axes[1].set_title(f'Power Spectrum of first component: sub{sub} {hem} hemisphere, {ses}, {recording_group}') 
                    # axes[1].axvline(x=13, color='black', linestyle='--')
                    # axes[1].axvline(x=35, color='black', linestyle='--')

                    # fig.savefig(sub_results_path + f"\\sub-{sub}_{hem}_SSD_firstComponent_PowerSpectrum_{ses}_{recording_group}")

                   

SSD_results_Dataframe = pd.DataFrame(SSD_results_storage)
SSD_results_Dataframe.rename(index={0:"subject", 1:"hemisphere", 2:"session", 3:"recording_group", 4:"bipolarChannel", 5:"ssd_filtered_timedomain", 6:"ssd_pattern", 7:"ssd_eigvals"}, inplace=True)
SSD_results_Dataframe = SSD_results_Dataframe.transpose()

# %%
example_data.survey.fu3m.m0s0.rest.RingR.run1.data
# Out:
# <RawArray | 6 x 5288 (21.1 s), ~259 kB, data loaded>

# %%
SSD_results_Dataframe
# Out:
#                                 subject hemisphere session recording_group  \
# 017_Right_fu3m_LFP_R_03_STN_MT      017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_13_STN_MT      017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_02_STN_MT      017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_12_STN_MT      017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_01_STN_MT      017      Right    fu3m           RingR
# ...                                 ...        ...     ...             ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT     038       Left    fu3m      SegmIntraL
# 038_Left_fu3m_LFP_L_2A2C_STN_MT     038       Left    fu3m      SegmIntraL
# 038_Left_fu3m_LFP_L_1A2A_STN_MT     038       Left    fu3m      SegmInterL
# 038_Left_fu3m_LFP_L_1B2B_STN_MT     038       Left    fu3m      SegmInterL
# 038_Left_fu3m_LFP_L_1C2C_STN_MT     038       Left    fu3m      SegmInterL
#
#                                     bipolarChannel  \
# 017_Right_fu3m_LFP_R_03_STN_MT     LFP_R_03_STN_MT
# 017_Right_fu3m_LFP_R_13_STN_MT     LFP_R_13_STN_MT
# 017_Right_fu3m_LFP_R_02_STN_MT     LFP_R_02_STN_MT
# 017_Right_fu3m_LFP_R_12_STN_MT     LFP_R_12_STN_MT
# 017_Right_fu3m_LFP_R_01_STN_MT     LFP_R_01_STN_MT
# ...                                            ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT  LFP_L_2B2C_STN_MT
# 038_Left_fu3m_LFP_L_2A2C_STN_MT  LFP_L_2A2C_STN_MT
# 038_Left_fu3m_LFP_L_1A2A_STN_MT  LFP_L_1A2A_STN_MT
# 038_Left_fu3m_LFP_L_1B2B_STN_MT  LFP_L_1B2B_STN_MT
# 038_Left_fu3m_LFP_L_1C2C_STN_MT  LFP_L_1C2C_STN_MT
#
#                                                            ssd_filtered_timedomain  \
# 017_Right_fu3m_LFP_R_03_STN_MT   [0.032600785035807434, 0.7626753251134801, 1.1...
# 017_Right_fu3m_LFP_R_13_STN_MT   [0.032600785035807434, 0.7626753251134801, 1.1...
# 017_Right_fu3m_LFP_R_02_STN_MT   [0.032600785035807434, 0.7626753251134801, 1.1...
# 017_Right_fu3m_LFP_R_12_STN_MT   [0.032600785035807434, 0.7626753251134801, 1.1...
# 017_Right_fu3m_LFP_R_01_STN_MT   [0.032600785035807434, 0.7626753251134801, 1.1...
# ...                                                                            ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT  [0.03864237345034142, -0.25534729218288954, -0...
# 038_Left_fu3m_LFP_L_2A2C_STN_MT  [0.03864237345034142, -0.25534729218288954, -0...
# 038_Left_fu3m_LFP_L_1A2A_STN_MT  [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1B2B_STN_MT  [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1C2C_STN_MT  [0.015277493370720955, 0.052832819667909856, -...
#
#                                                                        ssd_pattern  \
# 017_Right_fu3m_LFP_R_03_STN_MT   [0.049633312649387556, -0.11807269603846558, 1...
# 017_Right_fu3m_LFP_R_13_STN_MT   [-0.6976578114138412, -1.0, -0.053549634023087...
# 017_Right_fu3m_LFP_R_02_STN_MT   [0.11941976453875561, 1.0, 0.4835446327298178,...
# 017_Right_fu3m_LFP_R_12_STN_MT   [-0.1577970189024648, 0.3892758161742464, -0.5...
# 017_Right_fu3m_LFP_R_01_STN_MT   [0.7412484930803367, 1.0, 0.41054062958764065,...
# ...                                                                            ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT  [-0.9909773157082497, -1.0, -0.671864658432917...
# 038_Left_fu3m_LFP_L_2A2C_STN_MT  [-0.413394721776951, -0.5497875590907301, -1.0...
# 038_Left_fu3m_LFP_L_1A2A_STN_MT      [0.3329504197102434, 1.0, 0.4598411306516709]
# 038_Left_fu3m_LFP_L_1B2B_STN_MT  [-1.0, 0.06634172126279622, -0.24626902957366567]
# 038_Left_fu3m_LFP_L_1C2C_STN_MT     [0.27344921243664644, 0.4610704121511254, 1.0]
#
#                                 ssd_eigvals
# 017_Right_fu3m_LFP_R_03_STN_MT     0.904594
# 017_Right_fu3m_LFP_R_13_STN_MT     0.832452
# 017_Right_fu3m_LFP_R_02_STN_MT     0.814931
# 017_Right_fu3m_LFP_R_12_STN_MT     0.791301
# 017_Right_fu3m_LFP_R_01_STN_MT     0.785849
# ...                                     ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT    0.789974
# 038_Left_fu3m_LFP_L_2A2C_STN_MT    0.753945
# 038_Left_fu3m_LFP_L_1A2A_STN_MT    0.926278
# 038_Left_fu3m_LFP_L_1B2B_STN_MT    0.828405
# 038_Left_fu3m_LFP_L_1C2C_STN_MT    0.771573
#
# [1080 rows x 8 columns]

# %%
Ring_2Darray = data[[3,4,5], :]

# %%
data_keys = list(rec_group_input_array.keys())
data_keys
# Out:
# ['017_Right_fu3m_m0s0_RingR',
#  '017_Right_fu3m_m0s0_SegmIntraR',
#  '017_Right_fu3m_m0s0_SegmInterR',
#  '017_Right_fu12m_m0s0_RingR',
#  '017_Right_fu12m_m0s0_SegmIntraR',
#  '017_Right_fu12m_m0s0_SegmInterR',
#  '017_Left_fu3m_m0s0_RingL',
#  '017_Left_fu3m_m0s0_SegmIntraL',
#  '017_Left_fu3m_m0s0_SegmInterL',
#  '017_Left_fu12m_m0s0_RingL',
#  '017_Left_fu12m_m0s0_SegmIntraL',
#  '017_Left_fu12m_m0s0_SegmInterL',
#  '019_Right_fu3m_m0s0_RingR',
#  '019_Right_fu3m_m0s0_SegmIntraR',
#  '019_Right_fu3m_m0s0_SegmInterR',
#  '019_Right_fu12m_m0s0_RingR',
#  '019_Right_fu12m_m0s0_SegmIntraR',
#  '019_Right_fu12m_m0s0_SegmInterR',
#  '019_Right_fu18m_m0s0_RingR',
#  '019_Right_fu18m_m0s0_SegmIntraR',
#  '019_Right_fu18m_m0s0_SegmInterR',
#  '019_Left_fu3m_m0s0_RingL',
#  '019_Left_fu3m_m0s0_SegmIntraL',
#  '019_Left_fu3m_m0s0_SegmInterL',
#  '019_Left_fu12m_m0s0_RingL',
#  '019_Left_fu12m_m0s0_SegmIntraL',
#  '019_Left_fu12m_m0s0_SegmInterL',
#  '019_Left_fu18m_m0s0_RingL',
#  '019_Left_fu18m_m0s0_SegmIntraL',
#  '019_Left_fu18m_m0s0_SegmInterL',
#  '021_Right_fu3m_m0s0_RingR',
#  '021_Right_fu3m_m0s0_SegmIntraR',
#  '021_Right_fu3m_m0s0_SegmInterR',
pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results
#                                  subject hemisphere session recording_group  \
# 017_Right_fu3m_LFP_R_12_STN_MT       017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_01_STN_MT       017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_23_STN_MT       017      Right    fu3m           RingR
# 017_Right_fu3m_LFP_R_1A1B_STN_MT     017      Right    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_1B1C_STN_MT     017      Right    fu3m      SegmIntraR
# ...                                  ...        ...     ...             ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT      038       Left    fu3m      SegmIntraL
# 038_Left_fu3m_LFP_L_2A2C_STN_MT      038       Left    fu3m      SegmIntraL
# 038_Left_fu3m_LFP_L_1A2A_STN_MT      038       Left    fu3m      SegmInterL
# 038_Left_fu3m_LFP_L_1B2B_STN_MT      038       Left    fu3m      SegmInterL
# 038_Left_fu3m_LFP_L_1C2C_STN_MT      038       Left    fu3m      SegmInterL
#
#                                  bipolarChannel  \
# 017_Right_fu3m_LFP_R_12_STN_MT               12
# 017_Right_fu3m_LFP_R_01_STN_MT               01
# 017_Right_fu3m_LFP_R_23_STN_MT               23
# 017_Right_fu3m_LFP_R_1A1B_STN_MT           1A1B
# 017_Right_fu3m_LFP_R_1B1C_STN_MT           1B1C
# ...                                         ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT            2B2C
# 038_Left_fu3m_LFP_L_2A2C_STN_MT            2A2C
# 038_Left_fu3m_LFP_L_1A2A_STN_MT            1A2A
# 038_Left_fu3m_LFP_L_1B2B_STN_MT            1B2B
# 038_Left_fu3m_LFP_L_1C2C_STN_MT            1C2C
#
#                                                             ssd_filtered_timedomain  \
# 017_Right_fu3m_LFP_R_12_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_01_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_23_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_1A1B_STN_MT  [-0.09952216387371969, -1.2380238972337754, -2...
# 017_Right_fu3m_LFP_R_1B1C_STN_MT  [-0.09952216387371969, -1.2380238972337754, -2...
# ...                                                                             ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT   [0.03864237345034142, -0.25534729218288954, -0...
# 038_Left_fu3m_LFP_L_2A2C_STN_MT   [0.03864237345034142, -0.25534729218288954, -0...
# 038_Left_fu3m_LFP_L_1A2A_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1B2B_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1C2C_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
#
#                                  ssd_pattern ssd_eigvals
# 017_Right_fu3m_LFP_R_12_STN_MT     -0.872632    0.901847
# 017_Right_fu3m_LFP_R_01_STN_MT     -0.213996    0.792729
# 017_Right_fu3m_LFP_R_23_STN_MT           1.0    0.649734
# 017_Right_fu3m_LFP_R_1A1B_STN_MT    0.029354     0.89082
# 017_Right_fu3m_LFP_R_1B1C_STN_MT   -0.241398    0.840307
# ...                                      ...         ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT    -0.000054    0.789974
# 038_Left_fu3m_LFP_L_2A2C_STN_MT      0.20553    0.753945
# 038_Left_fu3m_LFP_L_1A2A_STN_MT      0.33295    0.926278
# 038_Left_fu3m_LFP_L_1B2B_STN_MT          1.0    0.828405
# 038_Left_fu3m_LFP_L_1C2C_STN_MT     0.459841    0.771573
#
# [864 rows x 8 columns]

# %% [markdown]
# Perform Permutation Test from scipy.stats import permutation_test

# %%
# subject hemisphere aggragate to one column

loaded_ssd_result["subject_hemisphere"] = loaded_ssd_result[["subject", "hemisphere", "bipolarChannel"]].agg("_".join, axis=1)
loaded_ssd_result.drop(columns=["subject", "hemisphere", "bipolarChannel"], inplace=True)
loaded_ssd_result
# Out:
#                                  session recording_group  \
# 017_Right_fu3m_LFP_R_12_STN_MT      fu3m           RingR
# 017_Right_fu3m_LFP_R_01_STN_MT      fu3m           RingR
# 017_Right_fu3m_LFP_R_23_STN_MT      fu3m           RingR
# 017_Right_fu3m_LFP_R_1A1B_STN_MT    fu3m      SegmIntraR
# 017_Right_fu3m_LFP_R_1B1C_STN_MT    fu3m      SegmIntraR
# ...                                  ...             ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT     fu3m      SegmIntraL
# 038_Left_fu3m_LFP_L_2A2C_STN_MT     fu3m      SegmIntraL
# 038_Left_fu3m_LFP_L_1A2A_STN_MT     fu3m      SegmInterL
# 038_Left_fu3m_LFP_L_1B2B_STN_MT     fu3m      SegmInterL
# 038_Left_fu3m_LFP_L_1C2C_STN_MT     fu3m      SegmInterL
#
#                                                             ssd_filtered_timedomain  \
# 017_Right_fu3m_LFP_R_12_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_01_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_23_STN_MT    [-0.0418909072384, -0.8479430804553855, -1.238...
# 017_Right_fu3m_LFP_R_1A1B_STN_MT  [-0.09952216387371969, -1.2380238972337754, -2...
# 017_Right_fu3m_LFP_R_1B1C_STN_MT  [-0.09952216387371969, -1.2380238972337754, -2...
# ...                                                                             ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT   [0.03864237345034142, -0.25534729218288954, -0...
# 038_Left_fu3m_LFP_L_2A2C_STN_MT   [0.03864237345034142, -0.25534729218288954, -0...
# 038_Left_fu3m_LFP_L_1A2A_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1B2B_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1C2C_STN_MT   [0.015277493370720955, 0.052832819667909856, -...
#
#                                  ssd_pattern ssd_eigvals subject_hemisphere
# 017_Right_fu3m_LFP_R_12_STN_MT     -0.872632    0.901847       017_Right_12
# 017_Right_fu3m_LFP_R_01_STN_MT     -0.213996    0.792729       017_Right_01
# 017_Right_fu3m_LFP_R_23_STN_MT           1.0    0.649734       017_Right_23
# 017_Right_fu3m_LFP_R_1A1B_STN_MT    0.029354     0.89082     017_Right_1A1B
# 017_Right_fu3m_LFP_R_1B1C_STN_MT   -0.241398    0.840307     017_Right_1B1C
# ...                                      ...         ...                ...
# 038_Left_fu3m_LFP_L_2B2C_STN_MT    -0.000054    0.789974      038_Left_2B2C
# 038_Left_fu3m_LFP_L_2A2C_STN_MT      0.20553    0.753945      038_Left_2A2C
# 038_Left_fu3m_LFP_L_1A2A_STN_MT      0.33295    0.926278      038_Left_1A2A
# 038_Left_fu3m_LFP_L_1B2B_STN_MT          1.0    0.828405      038_Left_1B2B
# 038_Left_fu3m_LFP_L_1C2C_STN_MT     0.459841    0.771573      038_Left_1C2C
#
# [864 rows x 6 columns]

# %%
# get Data of each channel group and create different groups per session

# select rows if Ring isin recording_group

Ring_group = ["RingR", "RingL"]
SegmInter_group = ["SegmInterR", "SegmInterL"]
SegmIntra_group = ["SegmIntraR", "SegmIntraL"]

Ring_data = loaded_ssd_result.loc[(loaded_ssd_result["recording_group"].isin(Ring_group))]
SegmInter_data = loaded_ssd_result.loc[(loaded_ssd_result["recording_group"].isin(SegmInter_group))]
SegmIntra_data = loaded_ssd_result.loc[(loaded_ssd_result["recording_group"].isin(SegmIntra_group))]
# Out:
#                                   session recording_group bipolarChannel  \
# 017_Right_fu3m_LFP_R_1A2A_STN_MT     fu3m      SegmInterR           1A2A
# 017_Right_fu3m_LFP_R_1B2B_STN_MT     fu3m      SegmInterR           1B2B
# 017_Right_fu3m_LFP_R_1C2C_STN_MT     fu3m      SegmInterR           1C2C
# 017_Right_fu12m_LFP_R_1A2A_STN      fu12m      SegmInterR           1A2A
# 017_Right_fu12m_LFP_R_1B2B_STN      fu12m      SegmInterR           1B2B
# ...                                   ...             ...            ...
# 038_Left_postop_LFP_L_1B2B_STN_MT  postop      SegmInterL           1B2B
# 038_Left_postop_LFP_L_1C2C_STN_MT  postop      SegmInterL           1C2C
# 038_Left_fu3m_LFP_L_1A2A_STN_MT      fu3m      SegmInterL           1A2A
# 038_Left_fu3m_LFP_L_1B2B_STN_MT      fu3m      SegmInterL           1B2B
# 038_Left_fu3m_LFP_L_1C2C_STN_MT      fu3m      SegmInterL           1C2C
#
#                                                              ssd_filtered_timedomain  \
# 017_Right_fu3m_LFP_R_1A2A_STN_MT   [-0.0814305720309305, 0.20661286529413897, 0.5...
# 017_Right_fu3m_LFP_R_1B2B_STN_MT   [-0.0814305720309305, 0.20661286529413897, 0.5...
# 017_Right_fu3m_LFP_R_1C2C_STN_MT   [-0.0814305720309305, 0.20661286529413897, 0.5...
# 017_Right_fu12m_LFP_R_1A2A_STN     [0.021052015000057708, 0.10553247674722971, 0....
# 017_Right_fu12m_LFP_R_1B2B_STN     [0.021052015000057708, 0.10553247674722971, 0....
# ...                                                                              ...
# 038_Left_postop_LFP_L_1B2B_STN_MT  [-0.01886512704168981, -0.019108599272464864, ...
# 038_Left_postop_LFP_L_1C2C_STN_MT  [-0.01886512704168981, -0.019108599272464864, ...
# 038_Left_fu3m_LFP_L_1A2A_STN_MT    [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1B2B_STN_MT    [0.015277493370720955, 0.052832819667909856, -...
# 038_Left_fu3m_LFP_L_1C2C_STN_MT    [0.015277493370720955, 0.052832819667909856, -...
#
#                                   ssd_pattern ssd_eigvals subject_hemisphere
# 017_Right_fu3m_LFP_R_1A2A_STN_MT         -1.0    0.834739          017_Right
# 017_Right_fu3m_LFP_R_1B2B_STN_MT     -0.73892    0.817409          017_Right
# 017_Right_fu3m_LFP_R_1C2C_STN_MT       -0.325    0.755167          017_Right
# 017_Right_fu12m_LFP_R_1A2A_STN            1.0    0.795757          017_Right
# 017_Right_fu12m_LFP_R_1B2B_STN       0.534543    0.744245          017_Right
# ...                                       ...         ...                ...
# 038_Left_postop_LFP_L_1B2B_STN_MT         1.0    0.798822           038_Left
# 038_Left_postop_LFP_L_1C2C_STN_MT    0.545084     0.69212           038_Left
# 038_Left_fu3m_LFP_L_1A2A_STN_MT       0.33295    0.926278           038_Left
# 038_Left_fu3m_LFP_L_1B2B_STN_MT           1.0    0.828405           038_Left
# 038_Left_fu3m_LFP_L_1C2C_STN_MT      0.459841    0.771573           038_Left
#
# [216 rows x 7 columns]

# %%
# example Ring_data -> four groups: postop, fu3m, fu12m, fu18m

postop_data = Ring_data.loc[(Ring_data["session"] == "postop")]
fu3m_data = Ring_data.loc[(Ring_data["session"] == "fu3m")]
fu12m_data = Ring_data.loc[(Ring_data["session"] == "fu12m")]
fu18m_data = Ring_data.loc[(Ring_data["session"] == "fu18m")]
# Out:
#                                 session recording_group bipolarChannel  \
# 019_Right_fu18m_LFP_R_12_STN_MT   fu18m           RingR             12
# 019_Right_fu18m_LFP_R_01_STN_MT   fu18m           RingR             01
# 019_Right_fu18m_LFP_R_23_STN_MT   fu18m           RingR             23
# 019_Left_fu18m_LFP_L_12_STN_MT    fu18m           RingL             12
# 019_Left_fu18m_LFP_L_01_STN_MT    fu18m           RingL             01
# 019_Left_fu18m_LFP_L_23_STN_MT    fu18m           RingL             23
# 021_Right_fu18m_LFP_R_12_STN_MT   fu18m           RingR             12
# 021_Right_fu18m_LFP_R_01_STN_MT   fu18m           RingR             01
# 021_Right_fu18m_LFP_R_23_STN_MT   fu18m           RingR             23
# 021_Left_fu18m_LFP_L_12_STN_MT    fu18m           RingL             12
# 021_Left_fu18m_LFP_L_01_STN_MT    fu18m           RingL             01
# 021_Left_fu18m_LFP_L_23_STN_MT    fu18m           RingL             23
# 024_Right_fu18m_LFP_R_12_STN_MT   fu18m           RingR             12
# 024_Right_fu18m_LFP_R_01_STN_MT   fu18m           RingR             01
# 024_Right_fu18m_LFP_R_23_STN_MT   fu18m           RingR             23
# 024_Left_fu18m_LFP_L_12_STN_MT    fu18m           RingL             12
# 024_Left_fu18m_LFP_L_01_STN_MT    fu18m           RingL             01
# 024_Left_fu18m_LFP_L_23_STN_MT    fu18m           RingL             23
# 029_Right_fu18m_LFP_R_12_STN_MT   fu18m           RingR             12
# 029_Right_fu18m_LFP_R_01_STN_MT   fu18m           RingR             01
# 029_Right_fu18m_LFP_R_23_STN_MT   fu18m           RingR             23
# 029_Left_fu18m_LFP_L_12_STN_MT    fu18m           RingL             12
# 029_Left_fu18m_LFP_L_01_STN_MT    fu18m           RingL             01
# 029_Left_fu18m_LFP_L_23_STN_MT    fu18m           RingL             23
# 033_Right_fu18m_LFP_R_12_STN_MT   fu18m           RingR             12
# 033_Right_fu18m_LFP_R_01_STN_MT   fu18m           RingR             01
# 033_Right_fu18m_LFP_R_23_STN_MT   fu18m           RingR             23
# 033_Left_fu18m_LFP_L_12_STN_MT    fu18m           RingL             12
# 033_Left_fu18m_LFP_L_01_STN_MT    fu18m           RingL             01
# 033_Left_fu18m_LFP_L_23_STN_MT    fu18m           RingL             23
#
#                                                            ssd_filtered_timedomain  \
# 019_Right_fu18m_LFP_R_12_STN_MT  [0.05681183320383477, 0.5791239867140039, 0.87...
# 019_Right_fu18m_LFP_R_01_STN_MT  [0.05681183320383477, 0.5791239867140039, 0.87...
# 019_Right_fu18m_LFP_R_23_STN_MT  [0.05681183320383477, 0.5791239867140039, 0.87...
# 019_Left_fu18m_LFP_L_12_STN_MT   [0.025406467556420276, -0.1788192989060508, -0...
# 019_Left_fu18m_LFP_L_01_STN_MT   [0.025406467556420276, -0.1788192989060508, -0...
# 021_Right_fu18m_LFP_R_12_STN_MT         1.0    0.849045          021_Right
# 021_Right_fu18m_LFP_R_01_STN_MT   -0.124106    0.701677          021_Right
# 021_Right_fu18m_LFP_R_23_STN_MT     0.09313    0.627946          021_Right
# 021_Left_fu18m_LFP_L_12_STN_MT         -1.0    0.826104           021_Left
# 021_Left_fu18m_LFP_L_01_STN_MT     0.497238    0.806074           021_Left
# 021_Left_fu18m_LFP_L_23_STN_MT    -0.444107    0.658873           021_Left
# 024_Right_fu18m_LFP_R_12_STN_MT   -0.411545    0.761684          024_Right
# 024_Right_fu18m_LFP_R_01_STN_MT         1.0    0.608956          024_Right
# 024_Right_fu18m_LFP_R_23_STN_MT   -0.029671    0.431126          024_Right
# 024_Left_fu18m_LFP_L_12_STN_MT          1.0     0.92044           024_Left
# 024_Left_fu18m_LFP_L_01_STN_MT    -0.342462    0.782147           024_Left
# 024_Left_fu18m_LFP_L_23_STN_MT    -0.041496    0.676379           024_Left
# 029_Right_fu18m_LFP_R_12_STN_MT         1.0    0.779711          029_Right
# 029_Right_fu18m_LFP_R_01_STN_MT   -0.883649    0.766913          029_Right
# 029_Right_fu18m_LFP_R_23_STN_MT    0.071366     0.60216          029_Right
# 029_Left_fu18m_LFP_L_12_STN_MT          1.0    0.807454           029_Left
# 029_Left_fu18m_LFP_L_01_STN_MT     -0.03704    0.742769           029_Left
# 029_Left_fu18m_LFP_L_23_STN_MT    -0.568277    0.611282           029_Left
# 033_Right_fu18m_LFP_R_12_STN_MT    0.153762    0.932806          033_Right
# 033_Right_fu18m_LFP_R_01_STN_MT   -0.131876    0.757525          033_Right
# 033_Right_fu18m_LFP_R_23_STN_MT         1.0    0.740551          033_Right
# 033_Left_fu18m_LFP_L_12_STN_MT          1.0    0.939514           033_Left
# 033_Left_fu18m_LFP_L_01_STN_MT    -0.452476    0.865429           033_Left
# 033_Left_fu18m_LFP_L_23_STN_MT     0.121631    0.757932           033_Left

# %%
# create all possible pairwise comparisons
pairs = list(combinations([postop_data["ssd_pattern"], fu3m_data["ssd_pattern"], fu12m_data["ssd_pattern"], fu18m_data["ssd_pattern"]], 2))

# perform a permutation test for each pairwise comparison
for pair in pairs:
    stat, p_value, _ = permutation_test(pair[0], pair[1], 
                                        n_resamples=1000)
    
    print("Comparison between", pair[0], "and", pair[1])
    print("Test statistic:", stat)
    print("P-value:", p_value)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# c:\Users\jebe12\Research\Longterm_beta_project\Code\BetaSenSightLongterm\code\notebooks\SSD_playground.ipynb Cell 49 in <cell line: 5>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jebe12/Research/Longterm_beta_project/Code/BetaSenSightLongterm/code/notebooks/SSD_playground.ipynb#Y100sZmlsZQ%3D%3D?line=3'>4</a> # perform a permutation test for each pairwise comparison
#       <a href='vscode-notebook-cell:/c%3A/Users/jebe12/Research/Longterm_beta_project/Code/BetaSenSightLongterm/code/notebooks/SSD_playground.ipynb#Y100sZmlsZQ%3D%3D?line=4'>5</a> for pair in pairs:
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jebe12/Research/Longterm_beta_project/Code/BetaSenSightLongterm/code/notebooks/SSD_playground.ipynb#Y100sZmlsZQ%3D%3D?line=5'>6</a>     stat, p_value, _ = permutation_test(pair[0], pair[1],
#       <a href='vscode-notebook-cell:/c%3A/Users/jebe12/Research/Longterm_beta_project/Code/BetaSenSightLongterm/code/notebooks/SSD_playground.ipynb#Y100sZmlsZQ%3D%3D?line=6'>7</a>                                         n_resamples=1000)
#       <a href='vscode-notebook-cell:/c%3A/Users/jebe12/Research/Longterm_beta_project/Code/BetaSenSightLongterm/code/notebooks/SSD_playground.ipynb#Y100sZmlsZQ%3D%3D?line=8'>9</a>     print("Comparison between", pair[0], "and", pair[1])
#      <a href='vscode-notebook-cell:/c%3A/Users/jebe12/Research/Longterm_beta_project/Code/BetaSenSightLongterm/code/notebooks/SSD_playground.ipynb#Y100sZmlsZQ%3D%3D?line=9'>10</a>     print("Test statistic:", stat)
#
# File c:\Users\jebe12\anaconda3\envs\pyPerceive_dev\lib\site-packages\scipy\stats\_resampling.py:1396, in permutation_test(data, statistic, permutation_type, vectorized, n_resamples, batch, alternative, axis, random_state)
#     977 def permutation_test(data, statistic, *, permutation_type='independent',
#     978                      vectorized=False, n_resamples=9999, batch=None,
#     979                      alternative="two-sided", axis=0, random_state=None):
#     980     r"""
#     981     Performs a permutation test of a given statistic on provided data.
#     982
#    (...)
#    1394
#    1395     """
# -> 1396     args = _permutation_test_iv(data, statistic, permutation_type, vectorized,
#    1397                                 n_resamples, batch, alternative, axis,
#    1398                                 random_state)
#    1399     (data, statistic, permutation_type, vectorized, n_resamples, batch,
#    1400      alternative, axis, random_state) = args
#    1402     observed = statistic(*data, axis=-1)
#
# File c:\Users\jebe12\anaconda3\envs\pyPerceive_dev\lib\site-packages\scipy\stats\_resampling.py:944, in _permutation_test_iv(data, statistic, permutation_type, vectorized, n_resamples, batch, alternative, axis, random_state)
#     941 except TypeError:
#     942     raise TypeError(message)
# --> 944 data = _broadcast_arrays(data, axis)
#     945 data_iv = []
#     946 for sample in data:
#
# File c:\Users\jebe12\anaconda3\envs\pyPerceive_dev\lib\site-packages\scipy\stats\_axis_nan_policy.py:19, in _broadcast_arrays(arrays, axis)
#      15 def _broadcast_arrays(arrays, axis=None):
#      16     """
#      17     Broadcast shapes of arrays, ignoring incompatibility of specified axes
#      18     """
# ---> 19     new_shapes = _broadcast_array_shapes(arrays, axis=axis)
#      20     if axis is None:
#      21         new_shapes = [new_shapes]*len(arrays)
#
# File c:\Users\jebe12\anaconda3\envs\pyPerceive_dev\lib\site-packages\scipy\stats\_axis_nan_policy.py:31, in _broadcast_array_shapes(arrays, axis)
#      27 """
#      28 Broadcast shapes of arrays, ignoring incompatibility of specified axes
#      29 """
#      30 shapes = [np.asarray(arr).shape for arr in arrays]
# ---> 31 return _broadcast_shapes(shapes, axis)
#
# File c:\Users\jebe12\anaconda3\envs\pyPerceive_dev\lib\site-packages\scipy\stats\_axis_nan_policy.py:63, in _broadcast_shapes(shapes, axis)
#      60 if axis[-1] >= n_dims or axis[0] < 0:
#      61     message = (f"`axis` is out of bounds "
#      62                f"for array of dimension {n_dims}")
# ---> 63     raise np.AxisError(message)
#      65 if len(np.unique(axis)) != len(axis):
#      66     raise np.AxisError("`axis` must contain only distinct elements")
#
# AxisError: `axis` is out of bounds for array of dimension 0

# %%
Permutation_data = BIP_ranks.Permutation_BIPranksRingSegmGroups(
    result = "psdAverage",
    difference = "rank",
    filterSignal = "band-pass",
    normalization = "rawPsd",
    freqBand = "beta"
)
# Out:
# pickle file loaded:  BIPranksChannelGroup_session_dict_psdAverage_beta_rawPsd_band-pass.pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results
# files:  BIP_relativePsdToRank1_psdAverage_beta_rawPsd_band-pass.pickle
# BIPpermutationDF_Postop_Fu3m_psdAverage_beta_rawPsd_band-pass.pickle
# BIPpermutationDF_Postop_Fu12m_psdAverage_beta_rawPsd_band-pass.pickle
# BIPpermutationDF_Postop_Fu18m_psdAverage_beta_rawPsd_band-pass.pickle
# BIPpermutationDF_Fu3m_Fu12m_psdAverage_beta_rawPsd_band-pass.pickle
# BIPpermutationDF_Fu3m_Fu18m_psdAverage_beta_rawPsd_band-pass.pickle
# BIPpermutationDF_Fu12m_Fu18m_psdAverage_beta_rawPsd_band-pass.pickle
# written in:  c:\Users\jebe12\Research\Longterm_beta_project\results

# %%
Permutation_data["DF_all_in_one"]
# Out:
#     recording_type session  averagedPSD  rank sub_hem_BIPchannel  \
# 0             Ring  postop     0.027022   2.0   024_Right_BIP_12
# 1             Ring  postop     0.275318   1.0   024_Right_BIP_01
# 2             Ring  postop     0.020856   3.0   024_Right_BIP_23
# 3             Ring  postop     0.104155   1.0    024_Left_BIP_12
# 4             Ring  postop     0.050440   2.0    024_Left_BIP_01
# ..             ...     ...          ...   ...                ...
# 667      SegmIntra   fu18m     0.349558   5.0  033_Left_BIP_1B1C
# 668      SegmIntra   fu18m     0.232625   6.0  033_Left_BIP_1A1C
# 669      SegmIntra   fu18m     0.501286   2.0  033_Left_BIP_2A2B
# 670      SegmIntra   fu18m     0.378244   4.0  033_Left_BIP_2B2C
# 671      SegmIntra   fu18m     0.633057   1.0  033_Left_BIP_2A2C
#
#      relative_to_rank1
# 0             0.098147
# 1             1.000000
# 2             0.075751
# 3             1.000000
# 4             0.484281
# ..                 ...
# 667           0.552175
# 668           0.367462
# 669           0.791851
# 670           0.597489
# 671           1.000000
#
# [672 rows x 6 columns]

# %%
BIPcomparison_data = loadResults.load_BIPpermutationComparisonsPickle(
        result="psdAverage",
        freqBand="beta",
        normalization="rawPsd",
        filterSignal="band-pass"
    )
# Out:
# pickle file loaded:  BIPpermutationDF_Postop_Fu3m_psdAverage_beta_rawPsd_band-pass.pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results
# pickle file loaded:  BIPpermutationDF_Postop_Fu12m_psdAverage_beta_rawPsd_band-pass.pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results
# pickle file loaded:  BIPpermutationDF_Postop_Fu18m_psdAverage_beta_rawPsd_band-pass.pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results
# pickle file loaded:  BIPpermutationDF_Fu3m_Fu12m_psdAverage_beta_rawPsd_band-pass.pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results
# pickle file loaded:  BIPpermutationDF_Fu3m_Fu18m_psdAverage_beta_rawPsd_band-pass.pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results
# pickle file loaded:  BIPpermutationDF_Fu12m_Fu18m_psdAverage_beta_rawPsd_band-pass.pickle
# loaded from:  c:\Users\jebe12\Research\Longterm_beta_project\results

# %%
dataframe = BIPcomparison_data["Postop_Fu3m"]["Ring"]
dataframe
# Out:
#    recording_type_x session_x  averagedPSD_x  rank_x sub_hem_BIPchannel  \
# 0              Ring    postop       0.027022     2.0   024_Right_BIP_12
# 1              Ring    postop       0.275318     1.0   024_Right_BIP_01
# 2              Ring    postop       0.020856     3.0   024_Right_BIP_23
# 3              Ring    postop       0.104155     1.0    024_Left_BIP_12
# 4              Ring    postop       0.050440     2.0    024_Left_BIP_01
# 5              Ring    postop       0.022654     3.0    024_Left_BIP_23
# 6              Ring    postop       0.082890     1.0   025_Right_BIP_12
# 7              Ring    postop       0.064702     2.0   025_Right_BIP_01
# 8              Ring    postop       0.054373     3.0   025_Right_BIP_23
# 9              Ring    postop       0.062511     1.0    025_Left_BIP_12
# 10             Ring    postop       0.054595     2.0    025_Left_BIP_01
# 11             Ring    postop       0.039165     3.0    025_Left_BIP_23
# 12             Ring    postop       0.036942     3.0   026_Right_BIP_12
# 13             Ring    postop       0.080753     1.0   026_Right_BIP_01
# 14             Ring    postop       0.043627     2.0   026_Right_BIP_23
# 15             Ring    postop       0.052237     1.0    026_Left_BIP_12
# 16             Ring    postop       0.035556     3.0    026_Left_BIP_01
# 17             Ring    postop       0.036640     2.0    026_Left_BIP_23
# 18             Ring    postop       0.017699     3.0   029_Right_BIP_12
# 19             Ring    postop       0.023966     1.0   029_Right_BIP_01
# 20             Ring    postop       0.019179     2.0   029_Right_BIP_23
# 21             Ring    postop       0.019714     2.0    029_Left_BIP_12
# 22             Ring    postop       0.023246     1.0    029_Left_BIP_01
# 23             Ring    postop       0.015389     3.0    029_Left_BIP_23
# 24             Ring    postop       0.077876     1.0   030_Right_BIP_12
# 25             Ring    postop       0.033262     3.0   030_Right_BIP_01
# 26             Ring    postop       0.046846     2.0   030_Right_BIP_23
# 27             Ring    postop       0.073042     1.0    030_Left_BIP_12
# 28             Ring    postop       0.034536     2.0    030_Left_BIP_01
# 29             Ring    postop       0.027838     3.0    030_Left_BIP_23
#
#    recording_type_y session_y  averagedPSD_y  rank_y  Difference_rank_x_y  \
# 0              Ring      fu3m       0.070589     2.0                  0.0
# 1              Ring      fu3m       0.791698     1.0                  0.0
# 2              Ring      fu3m       0.060974     3.0                  0.0
# 3              Ring      fu3m       0.441262     1.0                  0.0
# 4              Ring      fu3m       0.134760     2.0                  0.0
# 5              Ring      fu3m       0.073226     3.0                  0.0
# 6              Ring      fu3m       0.241705     3.0                  2.0
# 7              Ring      fu3m       0.320581     1.0                  1.0
# 8              Ring      fu3m       0.288884     2.0                  1.0
# 9              Ring      fu3m       0.192596     2.0                  1.0
# 10             Ring      fu3m       0.232003     1.0                  1.0
# 11             Ring      fu3m       0.102442     3.0                  0.0
# 12             Ring      fu3m       0.050727     2.0                  1.0
# 13             Ring      fu3m       1.541408     1.0                  0.0
# 14             Ring      fu3m       0.046900     3.0                  1.0
# 15             Ring      fu3m       0.106870     1.0                  0.0
# 16             Ring      fu3m       0.072532     3.0                  0.0
# 17             Ring      fu3m       0.078990     2.0                  0.0
# 18             Ring      fu3m       0.383767     1.0                  2.0
# 19             Ring      fu3m       0.278240     2.0                  1.0
# 20             Ring      fu3m       0.200953     3.0                  1.0
# 21             Ring      fu3m       0.268325     1.0                  1.0
# 22             Ring      fu3m       0.126299     2.0                  1.0
# 23             Ring      fu3m       0.091601     3.0                  0.0
# 24             Ring      fu3m       0.435105     1.0                  0.0
# 25             Ring      fu3m       0.165501     3.0                  0.0
# 26             Ring      fu3m       0.270862     2.0                  0.0
# 27             Ring      fu3m       0.234367     1.0                  0.0
# 28             Ring      fu3m       0.066364     3.0                  1.0
# 29             Ring      fu3m       0.105549     2.0                  1.0
#
#     Difference_psdAverage_x_y
# 0                    0.043568
# 1                    0.516380
# 2                    0.040118
# 3                    0.337107
# 4                    0.084320
# 5                    0.050572
# 6                    0.158815
# 7                    0.255879
# 8                    0.234511
# 9                    0.130084
# 10                   0.177409
# 11                   0.063277
# 12                   0.013785
# 13                   1.460654
# 14                   0.003273
# 15                   0.054633
# 16                   0.036976
# 17                   0.042349
# 18                   0.366068
# 19                   0.254274
# 20                   0.181775
# 21                   0.248611
# 22                   0.103053
# 23                   0.076212
# 24                   0.357229
# 25                   0.132239
# 26                   0.224016
# 27                   0.161324
# 28                   0.031828
# 29                   0.077711

# %%
# shuffle within STNs!!
STN_channel_list = list(dataframe["sub_hem_BIPchannel"].unique())
STN_list = []
for STN_channel in STN_channel_list:
    split = STN_channel.split("_")
    STN = "_".join([split[0], split[1]])
    STN_list.append(STN)

STN_list = list(set(STN_list)) # set() gets the unique values from a list
STN_list.sort()

# %%
STN_list
# Out:
# ['024_Left',
#  '024_Right',
#  '025_Left',
#  '025_Right',
#  '026_Left',
#  '026_Right',
#  '029_Left',
#  '029_Right',
#  '030_Left',
#  '030_Right']

# %%
STN_data = {}

for s, STN in enumerate(STN_list):
    data = dataframe.copy()
    STN_data[f"{STN}"] = data.loc[(data["sub_hem_BIPchannel"].str.contains(STN))]


STN_data['029_Left']
# Out:
#    recording_type_x session_x  averagedPSD_x  rank_x sub_hem_BIPchannel  \
# 21             Ring    postop       0.019714     2.0    029_Left_BIP_12
# 22             Ring    postop       0.023246     1.0    029_Left_BIP_01
# 23             Ring    postop       0.015389     3.0    029_Left_BIP_23
#
#    recording_type_y session_y  averagedPSD_y  rank_y  Difference_rank_x_y  \
# 21             Ring      fu3m       0.268325     1.0                  1.0
# 22             Ring      fu3m       0.126299     2.0                  1.0
# 23             Ring      fu3m       0.091601     3.0                  0.0
#
#     Difference_psdAverage_x_y
# 21                   0.248611
# 22                   0.103053
# 23                   0.076212

# %%
STN_data.keys()
# Out:
# dict_keys(['024_Left', '024_Right', '025_Left', '025_Right', '026_Left', '026_Right', '029_Left', '029_Right', '030_Left', '030_Right'])

# %%
import itertools

lists_in_list = [[0,1,2],[1,2,0]]
lists_in_list = list(itertools.chain.from_iterable(lists_in_list))
lists_in_list
# Out:
# [0, 1, 2, 1, 2, 0]
